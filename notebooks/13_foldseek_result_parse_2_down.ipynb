# %% [markdown]
# ## Rice Downregulated Gene Group

# %%
import re
import datetime
import pathlib
import polars as pl # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
from matplotlib.patches import Patch
import seaborn as sns # type: ignore
from upsetplot import UpSet, from_contents # type: ignore

# %%
pl.Config.set_fmt_str_lengths(25)
pl.Config.set_tbl_rows(6)

VERSION = datetime.datetime.now().strftime("%y%m%d")
print(f"Execute Date: {VERSION}")
# Out:
# Execute Date: 250802

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (1) Parameters for papermill

# %%
foldseek_result_tsv = pathlib.Path("../Data/14_foldseek_result/foldseek_output_uniprot_rice_down_9606.tsv")

rice_uniprot_idmapping_tsv = pathlib.Path("../Data/12_rice_uniprot_idmapping/rice_down_idmapping_all.tsv")

water_result_dir_path = "../Data/17_retrieve_sequence_rice_down/rice_down/result_water_rice_down"
needle_result_dir_path = "../Data/17_retrieve_sequence_rice_down/rice_down/result_needle_rice_down"

gene_list_tsv_path = "../Data/07_extract_gene/HN5_genelist_rice_2505/HN5_genes_down_rice.tsv"

togoid_convert_tsv_path = "../Data/18_togoid_convert_rice_down/togoid_convert_rice_down_human.tsv"

query_idmapping_tsv_path = "../Data/19_foldseek_hit_uniprot_idmapping/foldseek_result_rice_down_rice_idmapping_250605.tsv"
target_idmapping_tsv_path = "../Data/19_foldseek_hit_uniprot_idmapping/foldseek_result_rice_down_human_idmapping_250605.tsv"

pan_homology_tsv_path = "../Data/13_rice_pan_homology/rice_down_panhomology_9606_concat.tsv"

# %%
foldseek_result = pl.read_csv(
    foldseek_result_tsv,
    separator='\t'
).drop(
    "taxlineage",
    "qaln",
    "taln",
    "lddtfull"
).sort(
    by=["From", "foldseek hit", "UniProt Accession"], # sort by From, foldseek hit, UniProt Accession, qcov, lddt
    descending=[False, False, False]
).with_columns( # add foldseek hit ID for upset plot
    pl.struct(
        [
            "From",
            "foldseek hit",
            "UniProt Accession"
        ]
    ).rank("dense").alias("hit ID")
).with_columns( # assign label for upset plot
    (pl.lit("foldseek-hit-") + pl.col("hit ID").cast(pl.Utf8)).alias("hit label")
).drop(
    "hit ID"
)

display(foldseek_result)
# Out:
# shape: (13_467, 27)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────┬────────────┬──────────┬───────────┐
# │ From       ┆ UniProt    ┆ foldseek   ┆ evalue    ┆ … ┆ taxid ┆ taxname    ┆ mismatch ┆ hit label │
# │ ---        ┆ Accession  ┆ hit        ┆ ---       ┆   ┆ ---   ┆ ---        ┆ ---      ┆ ---       │
# │ str        ┆ ---        ┆ ---        ┆ f64       ┆   ┆ i64   ┆ str        ┆ i64      ┆ str       │
# │            ┆ str        ┆ str        ┆           ┆   ┆       ┆            ┆          ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════╪════════════╪══════════╪═══════════╡
# │ Os01g01379 ┆ A0A0P0UXR3 ┆ K7EP59     ┆ 0.001585  ┆ … ┆ 9606  ┆ Homo       ┆ 134      ┆ foldseek- │
# │ 50         ┆            ┆            ┆           ┆   ┆       ┆ sapiens    ┆          ┆ hit-1     │
# │ Os01g01796 ┆ B7FAP2     ┆ A0A0G2JMZ5 ┆ 1.9390e-8 ┆ … ┆ 9606  ┆ Homo       ┆ 144      ┆ foldseek- │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆ sapiens    ┆          ┆ hit-2     │
# │ Os01g01796 ┆ Q0JQ63     ┆ A0A0G2JMZ5 ┆ 8.1950e-9 ┆ … ┆ 9606  ┆ Homo       ┆ 141      ┆ foldseek- │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆ sapiens    ┆          ┆ hit-3     │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …     ┆ …          ┆ …        ┆ …         │
# │ Os12g06108 ┆ Q0ILZ7     ┆ O43761     ┆ 0.06753   ┆ … ┆ 9606  ┆ Homo       ┆ 126      ┆ foldseek- │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆ sapiens    ┆          ┆ hit-13465 │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ 0.02451   ┆ … ┆ 9606  ┆ Homo       ┆ 133      ┆ foldseek- │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆ sapiens    ┆          ┆ hit-13466 │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ 0.04982   ┆ … ┆ 9606  ┆ Homo       ┆ 130      ┆ foldseek- │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆ sapiens    ┆          ┆ hit-13467 │
# └────────────┴────────────┴────────────┴───────────┴───┴───────┴────────────┴──────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (2) Structural alignment identical match vs Average lDDT

# %%
foldseek_filter_viz = foldseek_result.to_pandas()
sns.jointplot(
    data=foldseek_filter_viz,
    x="pident", # structural alignment identical match from foldseek result
    y="lddt",
    color="seagreen",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(0,100.5)
plt.ylim(0,1)
plt.xlabel("Structural alignment identical match (%)", fontsize=14)
plt.ylabel("Average lDDT", fontsize=14) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=25, color="black", linestyle=":")
plt.axvline(x=50, color="black", linestyle=":")
plt.axvline(x=75, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(8, 8), dpi=400)
plt.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_pident_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)
plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (3) Parse pairwise alignment result

# %%
def parse_needle_water_result(file_path: str):
    with open(file_path, "r", encoding="utf-8") as file:
        data = file.readlines()
        
    result = {
        "UniProt Accession": None,
        "foldseek hit": None,
        "Length": None,
        "Identity": None,
        "Identity_percent": None,
        "Similarity": None,
        "Similarity_percent": None,
        "Gaps": None,
        "Gaps_percent": None,
        "Score": None
    }
    
    for line in data:
        if line.startswith('# 1:'):
            result['UniProt Accession'] = line.split(':')[1].strip()
        elif line.startswith('# 2:'):
            result['foldseek hit'] = line.split(':')[1].strip()
        elif line.startswith('# Length:'):
            result['Length'] = int(line.split()[2])
        elif line.startswith('# Identity:'):
            result['Identity'] = line.split()[2]
            result['Identity_percent'] = float(re.search(r'\((.*?)%\)', line).group(1))
        elif line.startswith('# Similarity:'):
            result['Similarity'] = line.split()[2]
            result['Similarity_percent'] = float(re.search(r'\((.*?)%\)', line).group(1))
        elif line.startswith('# Gaps:'):
            result['Gaps'] = line.split()[2]
            result['Gaps_percent'] = float(re.search(r'\((.*?)%\)', line).group(1))
        elif line.startswith('# Score:'):
            result['Score'] = float(line.split()[2])
            
    return result

# %%
water_result_dir = pathlib.Path(water_result_dir_path)
needle_result_dir = pathlib.Path(needle_result_dir_path)

# Initialize empty lists to store DataFrames
water_dfs = []
needle_dfs = []

# Collect all water results
for result_file in water_result_dir.glob("*_align.water"):
    parsed_data = parse_needle_water_result(result_file)
    water_dfs.append(pl.DataFrame([parsed_data]))

# Collect all needle results    
for result_file in needle_result_dir.glob("*_align.needle"):
    parsed_data = parse_needle_water_result(result_file)
    needle_dfs.append(pl.DataFrame([parsed_data]))

# Combine all results and sort only if there are results
water_result = (pl.concat(water_dfs, how='vertical')
                .sort(["UniProt Accession", "foldseek hit"]) 
                if water_dfs else pl.DataFrame())

needle_result = (pl.concat(needle_dfs, how='vertical')
                 .sort(["UniProt Accession", "foldseek hit"])
                 if needle_dfs else pl.DataFrame())

display(water_result)
display(needle_result)
# Out:
# shape: (12_212, 10)
# ┌──────────────┬──────────────┬────────┬──────────┬───┬─────────────┬────────┬─────────────┬───────┐
# │ UniProt      ┆ foldseek hit ┆ Length ┆ Identity ┆ … ┆ Similarity_ ┆ Gaps   ┆ Gaps_percen ┆ Score │
# │ Accession    ┆ ---          ┆ ---    ┆ ---      ┆   ┆ percent     ┆ ---    ┆ t           ┆ ---   │
# │ ---          ┆ str          ┆ i64    ┆ str      ┆   ┆ ---         ┆ str    ┆ ---         ┆ f64   │
# │ str          ┆              ┆        ┆          ┆   ┆ f64         ┆        ┆ f64         ┆       │
# ╞══════════════╪══════════════╪════════╪══════════╪═══╪═════════════╪════════╪═════════════╪═══════╡
# │ A0A0N7KD90   ┆ A0A024R6G4   ┆ 502    ┆ 153/502  ┆ … ┆ 49.0        ┆ 38/502 ┆ 7.6         ┆ 545.0 │
# │ A0A0N7KD90   ┆ A0A024RAC7   ┆ 457    ┆ 124/457  ┆ … ┆ 47.5        ┆ 47/457 ┆ 10.3        ┆ 395.0 │
# │ A0A0N7KD90   ┆ A0A087WUF8   ┆ 172    ┆ 44/172   ┆ … ┆ 39.5        ┆ 50/172 ┆ 29.1        ┆ 103.0 │
# │ …            ┆ …            ┆ …      ┆ …        ┆ … ┆ …           ┆ …      ┆ …           ┆ …     │
# │ Q9XHX6       ┆ Q0P5T2       ┆ 104    ┆ 22/104   ┆ … ┆ 31.7        ┆ 41/104 ┆ 39.4        ┆ 28.5  │
# │ V9G2Z0       ┆ G3FDP4       ┆ 227    ┆ 99/227   ┆ … ┆ 57.3        ┆ 6/227  ┆ 2.6         ┆ 562.0 │
# │ V9G2Z0       ┆ Q96PM5       ┆ 241    ┆ 107/241  ┆ … ┆ 57.3        ┆ 6/241  ┆ 2.5         ┆ 597.0 │
# └──────────────┴──────────────┴────────┴──────────┴───┴─────────────┴────────┴─────────────┴───────┘
# shape: (12_212, 10)
# ┌─────────────┬─────────────┬────────┬──────────┬───┬─────────────┬───────────┬────────────┬───────┐
# │ UniProt     ┆ foldseek    ┆ Length ┆ Identity ┆ … ┆ Similarity_ ┆ Gaps      ┆ Gaps_perce ┆ Score │
# │ Accession   ┆ hit         ┆ ---    ┆ ---      ┆   ┆ percent     ┆ ---       ┆ nt         ┆ ---   │
# │ ---         ┆ ---         ┆ i64    ┆ str      ┆   ┆ ---         ┆ str       ┆ ---        ┆ f64   │
# │ str         ┆ str         ┆        ┆          ┆   ┆ f64         ┆           ┆ f64        ┆       │
# ╞═════════════╪═════════════╪════════╪══════════╪═══╪═════════════╪═══════════╪════════════╪═══════╡
# │ A0A0N7KD90  ┆ A0A024R6G4  ┆ 557    ┆ 155/557  ┆ … ┆ 44.9        ┆ 72/557    ┆ 12.9       ┆ 531.0 │
# │ A0A0N7KD90  ┆ A0A024RAC7  ┆ 606    ┆ 137/606  ┆ … ┆ 38.9        ┆ 142/606   ┆ 23.4       ┆ 373.0 │
# │ A0A0N7KD90  ┆ A0A087WUF8  ┆ 540    ┆ 48/540   ┆ … ┆ 13.5        ┆ 404/540   ┆ 74.8       ┆ 97.0  │
# │ …           ┆ …           ┆ …      ┆ …        ┆ … ┆ …           ┆ …         ┆ …          ┆ …     │
# │ Q9XHX6      ┆ Q0P5T2      ┆ 653    ┆ 6/653    ┆ … ┆ 1.1         ┆ 633/653   ┆ 96.9       ┆ 10.0  │
# │ V9G2Z0      ┆ G3FDP4      ┆ 1242   ┆ 101/1242 ┆ … ┆ 10.8        ┆ 1013/1242 ┆ 81.6       ┆ 555.0 │
# │ V9G2Z0      ┆ Q96PM5      ┆ 1247   ┆ 112/1247 ┆ … ┆ 11.6        ┆ 997/1247  ┆ 80.0       ┆ 590.0 │
# └─────────────┴─────────────┴────────┴──────────┴───┴─────────────┴───────────┴────────────┴───────┘

# %%
alignment_result = water_result.join(
    needle_result,
    on=["UniProt Accession", "foldseek hit"],
    how="inner",
    coalesce=True,
    suffix="_needle"
).rename(
    {
        "Length": "Length_water",
        "Identity": "Identity_water",
        "Identity_percent": "Identity_percent_water",
        "Similarity": "Similarity_water",
        "Similarity_percent": "Similarity_percent_water",
        "Gaps": "Gaps_water",
        "Gaps_percent": "Gaps_percent_water",
        "Score": "Score_water"
    }
).select(
    [
        "UniProt Accession",
        "foldseek hit",
        "Length_water",
        "Length_needle",
        "Identity_water",
        "Identity_needle",
        "Identity_percent_water",
        "Identity_percent_needle",
        "Similarity_percent_water",
        "Similarity_percent_needle",
        "Gaps_water",
        "Gaps_percent_water",
        "Gaps_needle",
        "Gaps_percent_needle",
        "Score_water",
        "Score_needle"
    ]
).sort(
    by=["UniProt Accession", "foldseek hit"],
    descending=[False, False]
)

display(alignment_result)
# Out:
# shape: (12_212, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ UniProt   ┆ foldseek  ┆ Length_wa ┆ Length_ne ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ Accession ┆ hit       ┆ ter       ┆ edle      ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ i64       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ A0A0N7KD9 ┆ A0A024R6G ┆ 502       ┆ 557       ┆ … ┆ 72/557    ┆ 12.9      ┆ 545.0     ┆ 531.0    │
# │ 0         ┆ 4         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ A0A0N7KD9 ┆ A0A024RAC ┆ 457       ┆ 606       ┆ … ┆ 142/606   ┆ 23.4      ┆ 395.0     ┆ 373.0    │
# │ 0         ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ A0A0N7KD9 ┆ A0A087WUF ┆ 172       ┆ 540       ┆ … ┆ 404/540   ┆ 74.8      ┆ 103.0     ┆ 97.0     │
# │ 0         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Q9XHX6    ┆ Q0P5T2    ┆ 104       ┆ 653       ┆ … ┆ 633/653   ┆ 96.9      ┆ 28.5      ┆ 10.0     │
# │ V9G2Z0    ┆ G3FDP4    ┆ 227       ┆ 1242      ┆ … ┆ 1013/1242 ┆ 81.6      ┆ 562.0     ┆ 555.0    │
# │ V9G2Z0    ┆ Q96PM5    ┆ 241       ┆ 1247      ┆ … ┆ 997/1247  ┆ 80.0      ┆ 597.0     ┆ 590.0    │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (4) Integrate foldseek result and pairwise alignment result
#
# - In this study, **exclude the ones that are null in pairwise alignment result, which means the current UniProt entry is obsolete**

# %%
join_foldseek = foldseek_result.join(
    alignment_result,
    on=["UniProt Accession", "foldseek hit"],
    how="left",
    coalesce=True
).filter( # filter out null alignment result (this means current UniProt entry is obsolete)
    pl.col("Length_water").is_not_null() & 
    pl.col("Length_needle").is_not_null()
).sort(
    by=["From", "foldseek hit", "UniProt Accession"],
    descending=[False, False, False]
)


print(join_foldseek.group_by(["From"], maintain_order=True).n_unique())
display(join_foldseek)
# Out:
# shape: (167, 41)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ From       ┆ UniProt    ┆ foldseek  ┆ evalue ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ Accession  ┆ hit       ┆ ---    ┆   ┆ le        ┆ ent_needl ┆ er        ┆ dle       │
# │ str        ┆ ---        ┆ ---       ┆ u32    ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---       │
# │            ┆ u32        ┆ u32       ┆        ┆   ┆ u32       ┆ ---       ┆ u32       ┆ u32       │
# │            ┆            ┆           ┆        ┆   ┆           ┆ u32       ┆           ┆           │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ 2          ┆ 63        ┆ 109    ┆ … ┆ 33        ┆ 33        ┆ 30        ┆ 40        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os01g01929 ┆ 1          ┆ 8         ┆ 8      ┆ … ┆ 7         ┆ 7         ┆ 7         ┆ 7         │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os01g02084 ┆ 1          ┆ 3         ┆ 3      ┆ … ┆ 3         ┆ 3         ┆ 3         ┆ 3         │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …         ┆ …      ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Os12g05552 ┆ 2          ┆ 46        ┆ 63     ┆ … ┆ 43        ┆ 41        ┆ 19        ┆ 25        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os12g05555 ┆ 2          ┆ 51        ┆ 73     ┆ … ┆ 47        ┆ 46        ┆ 17        ┆ 25        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os12g06108 ┆ 1          ┆ 5         ┆ 5      ┆ … ┆ 5         ┆ 5         ┆ 5         ┆ 5         │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴───────────┴────────┴───┴───────────┴───────────┴───────────┴───────────┘
# shape: (12_212, 41)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ From      ┆ UniProt   ┆ foldseek  ┆ evalue    ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ Accession ┆ hit       ┆ ---       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆ str       ┆ str       ┆           ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Os01g0179 ┆ B7FAP2    ┆ A0A0G2JMZ ┆ 1.9390e-8 ┆ … ┆ 351/585   ┆ 60.0      ┆ 138.5     ┆ 112.0    │
# │ 600       ┆           ┆ 5         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os01g0179 ┆ Q0JQ63    ┆ A0A0G2JMZ ┆ 8.1950e-9 ┆ … ┆ 351/585   ┆ 60.0      ┆ 138.5     ┆ 112.0    │
# │ 600       ┆           ┆ 5         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ 4.8950e-7 ┆ … ┆ 370/775   ┆ 47.7      ┆ 126.0     ┆ 89.5     │
# │ 600       ┆           ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Os12g0610 ┆ Q0ILZ7    ┆ O43761    ┆ 0.06753   ┆ … ┆ 282/353   ┆ 79.9      ┆ 34.0      ┆ 14.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ 0.02451   ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ 0.04982   ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (5) Create Scatter Plot for all hits (x-axis: Similarity_percent_needle)

# %%
foldseek_filter_viz2 = join_foldseek.to_pandas()

sns.jointplot(
    data=foldseek_filter_viz2,
    x="Similarity_percent_needle",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Global alignment similarity (%)", fontsize=14)
plt.ylabel("Average lDDT", fontsize=14) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=25, color="black", linestyle=":")
plt.axvline(x=50, color="black", linestyle=":")
plt.axvline(x=75, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(5, 5), dpi=300)
plt.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_allplot_similarity_percent_needle_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)


plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (6) Create Scatter Plot for all hits (x-axis: Similarity_percent_water)

# %%
foldseek_filter_viz2 = join_foldseek.to_pandas()

sns.jointplot(
    data=foldseek_filter_viz2,
    x="Similarity_percent_water",
    y="lddt",
    color="darkorange",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(0,100.5)
plt.ylim(0,1)
plt.xlabel("Local alignment similarity (%)", fontsize=14)
plt.ylabel("Average lDDT", fontsize=14) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=25, color="black", linestyle=":")
plt.axvline(x=50, color="black", linestyle=":")
plt.axvline(x=75, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(5, 5), dpi=300)
plt.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_allplot_similarity_percent_water_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (7) Figure that change y-axis to strucutural alignment target coverage

# %%
sns.jointplot(
    data=foldseek_filter_viz2,
    x="Similarity_percent_needle",
    y="tcov",
    color="olive",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1.02)
plt.xlabel("Global alignment similarity(%)", fontsize=14)
plt.ylabel("Structural alignment target coverage", fontsize=14)
plt.axvline(x=25, color="black", linestyle=":")
plt.axvline(x=50, color="black", linestyle=":")
plt.axvline(x=75, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
plt.figure(figsize=(10, 10), dpi=500)
plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (8) Counting foldseek hits in Gene level

# %%
# Calculate the number of foldseek hits in gene level
all_gene_list = pl.read_csv(
    gene_list_tsv_path,
    separator='\t'
).select(
    "From"
).unique()

hit_count = all_gene_list.join(
    join_foldseek,
    on="From",
    how="left",
    coalesce=True
).group_by("From", maintain_order=True).agg(
    (pl.col("foldseek hit").count().alias("target hit count (gene level vs uniprot accession)")),
    (pl.col("foldseek hit").is_null().all().alias("foldseek no hit"))
).sort(
    ["target hit count (gene level vs uniprot accession)"], descending=True
)

display(hit_count)
    
# hit_count.write_csv(
#     "../out/rice_down/foldseek_rice_down_hit_count.tsv",
#     separator='\t'
# )

no_hit_genes_list = hit_count.filter(
    pl.col("foldseek no hit") == True
)

idmapping_list = pl.read_csv(
    rice_uniprot_idmapping_tsv,
    separator='\t'
)
  
no_hit_idmapping_list = no_hit_genes_list.join(
    idmapping_list,
    on="From",
    how="left"
).sort(
    by=["From"],
    descending=[False]
)

print(no_hit_idmapping_list.group_by(["From"], maintain_order=True).n_unique())
display(no_hit_idmapping_list)
# Out:
# shape: (370, 3)
# ┌──────────────┬────────────────────────────┬─────────────────┐
# │ From         ┆ target hit count (gene le… ┆ foldseek no hit │
# │ ---          ┆ ---                        ┆ ---             │
# │ str          ┆ u32                        ┆ bool            │
# ╞══════════════╪════════════════════════════╪═════════════════╡
# │ Os03g0833100 ┆ 322                        ┆ false           │
# │ Os04g0453200 ┆ 318                        ┆ false           │
# │ Os12g0512100 ┆ 304                        ┆ false           │
# │ …            ┆ …                          ┆ …               │
# │ Os07g0516700 ┆ 0                          ┆ true            │
# │ Os03g0842501 ┆ 0                          ┆ true            │
# │ Os11g0153500 ┆ 0                          ┆ true            │
# └──────────────┴────────────────────────────┴─────────────────┘
# shape: (203, 4)
# ┌──────────────┬────────────────────────────┬─────────────────┬───────────────────┐
# │ From         ┆ target hit count (gene le… ┆ foldseek no hit ┆ UniProt Accession │
# │ ---          ┆ ---                        ┆ ---             ┆ ---               │
# │ str          ┆ u32                        ┆ u32             ┆ u32               │
# ╞══════════════╪════════════════════════════╪═════════════════╪═══════════════════╡
# │ Os01g0105300 ┆ 1                          ┆ 1               ┆ 1                 │
# │ Os01g0136300 ┆ 1                          ┆ 1               ┆ 2                 │
# │ Os01g0137950 ┆ 1                          ┆ 1               ┆ 1                 │
# │ …            ┆ …                          ┆ …               ┆ …                 │
# │ Os12g0601800 ┆ 1                          ┆ 1               ┆ 1                 │
# │ Os12g0630100 ┆ 1                          ┆ 1               ┆ 2                 │
# │ Os12g0630200 ┆ 1                          ┆ 1               ┆ 2                 │
# └──────────────┴────────────────────────────┴─────────────────┴───────────────────┘
# shape: (326, 4)
# ┌──────────────┬────────────────────────────┬─────────────────┬───────────────────┐
# │ From         ┆ target hit count (gene le… ┆ foldseek no hit ┆ UniProt Accession │
# │ ---          ┆ ---                        ┆ ---             ┆ ---               │
# │ str          ┆ u32                        ┆ bool            ┆ str               │
# ╞══════════════╪════════════════════════════╪═════════════════╪═══════════════════╡
# │ Os01g0105300 ┆ 0                          ┆ true            ┆ A0A0P0UWX1        │
# │ Os01g0136300 ┆ 0                          ┆ true            ┆ A0A8J8YJH9        │
# │ Os01g0136300 ┆ 0                          ┆ true            ┆ Q5ZC68            │
# │ …            ┆ …                          ┆ …               ┆ …                 │
# │ Os12g0630100 ┆ 0                          ┆ true            ┆ Q2QLS8            │
# │ Os12g0630200 ┆ 0                          ┆ true            ┆ A3CJP3            │
# │ Os12g0630200 ┆ 0                          ┆ true            ┆ Q2QLS7            │
# └──────────────┴────────────────────────────┴─────────────────┴───────────────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (9) Filtering Condition1
#
# - foldseek query coverage ≧ 0.5, foldseek target coverage ≧ 0.5

# %%
condition1 = join_foldseek.filter(
        (pl.col("qcov") >= 0.5) &
        (pl.col("tcov") >= 0.5)
    ).sort(
        by=["From", "foldseek hit", "UniProt Accession"], # sort by From, foldseek hit, UniProt Accession
        descending=[False, False, False]
    )

condition1_rm = condition1.filter(
        (pl.col("qcov") < 0.5) |
        (pl.col("tcov") < 0.5)
    )

print(condition1.group_by(["From"], maintain_order=True).n_unique())
display(condition1)
# Out:
# shape: (152, 41)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ From       ┆ UniProt    ┆ foldseek  ┆ evalue ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ Accession  ┆ hit       ┆ ---    ┆   ┆ le        ┆ ent_needl ┆ er        ┆ dle       │
# │ str        ┆ ---        ┆ ---       ┆ u32    ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---       │
# │            ┆ u32        ┆ u32       ┆        ┆   ┆ u32       ┆ ---       ┆ u32       ┆ u32       │
# │            ┆            ┆           ┆        ┆   ┆           ┆ u32       ┆           ┆           │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ 2          ┆ 46        ┆ 78     ┆ … ┆ 28        ┆ 28        ┆ 24        ┆ 35        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os01g01929 ┆ 1          ┆ 8         ┆ 8      ┆ … ┆ 7         ┆ 7         ┆ 7         ┆ 7         │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os01g02320 ┆ 1          ┆ 47        ┆ 43     ┆ … ┆ 36        ┆ 35        ┆ 36        ┆ 36        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …         ┆ …      ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Os12g05552 ┆ 2          ┆ 20        ┆ 31     ┆ … ┆ 19        ┆ 19        ┆ 12        ┆ 13        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os12g05555 ┆ 2          ┆ 18        ┆ 32     ┆ … ┆ 17        ┆ 17        ┆ 11        ┆ 13        │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# │ Os12g06108 ┆ 1          ┆ 5         ┆ 5      ┆ … ┆ 5         ┆ 5         ┆ 5         ┆ 5         │
# │ 00         ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴───────────┴────────┴───┴───────────┴───────────┴───────────┴───────────┘
# shape: (8_878, 41)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ From      ┆ UniProt   ┆ foldseek  ┆ evalue    ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ Accession ┆ hit       ┆ ---       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆ str       ┆ str       ┆           ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ 4.8950e-7 ┆ … ┆ 370/775   ┆ 47.7      ┆ 126.0     ┆ 89.5     │
# │ 600       ┆           ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os01g0179 ┆ Q0JQ63    ┆ A0A140T9Z ┆ 1.5430e-7 ┆ … ┆ 370/775   ┆ 47.7      ┆ 126.0     ┆ 89.5     │
# │ 600       ┆           ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os01g0179 ┆ B7FAP2    ┆ A3KME6    ┆ 4.5420e-1 ┆ … ┆ 296/657   ┆ 45.1      ┆ 169.0     ┆ 154.0    │
# │ 600       ┆           ┆           ┆ 5         ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Os12g0610 ┆ Q0ILZ7    ┆ O43761    ┆ 0.06753   ┆ … ┆ 282/353   ┆ 79.9      ┆ 34.0      ┆ 14.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ 0.02451   ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ 0.04982   ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (10) Filtering Condition2
#
# - If there are hits with the same target for the same gene-derived UniProt ID, the one with the highest qcov is selected, and if the qcov is the same, the one with the highest lDDT is selected.
# - **Note that in this study, we leave the states with the same foldseek hit even if the rice genes are different.**

# %%
condition2 = condition1.sort(
    by=["qcov", "lddt"],
    descending=[True, True]
).group_by(
    ["From", "foldseek hit"],
    maintain_order=True
).agg(
    pl.all().first()
).sort(
    by=["From", "UniProt Accession", "foldseek hit"],
    descending=[False, False, False]
).select(
    "From",
    "UniProt Accession",
    "foldseek hit",
    "evalue",
    "prob",
    "gapopen",
    "pident",
    "fident",
    "nident",
    "qstart",
    "qend",
    "qlen",
    "tstart",
    "tend",
    "tlen",
    "alnlen",
    "qcov",
    "tcov",
    "lddt",
    "qtmscore",
    "ttmscore",
    "alntmscore",
    "rmsd",
    "taxid",
    "taxname",
    "mismatch",
    "hit label",
    "Length_water",
    "Length_needle",
    "Identity_water",
    "Identity_needle",
    "Identity_percent_water",
    "Identity_percent_needle",
    "Similarity_percent_water",
    "Similarity_percent_needle",
    "Gaps_water",
    "Gaps_percent_water",
    "Gaps_needle",
    "Gaps_percent_needle",
    "Score_water",
    "Score_needle"
)

display(condition2)
# Out:
# shape: (6_367, 41)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ From      ┆ UniProt   ┆ foldseek  ┆ evalue    ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ Accession ┆ hit       ┆ ---       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆ str       ┆ str       ┆           ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ 4.8950e-7 ┆ … ┆ 370/775   ┆ 47.7      ┆ 126.0     ┆ 89.5     │
# │ 600       ┆           ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os01g0179 ┆ B7FAP2    ┆ A7E1U4    ┆ 0.02108   ┆ … ┆ 670/723   ┆ 92.7      ┆ 35.0      ┆ 15.0     │
# │ 600       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os01g0179 ┆ B7FAP2    ┆ A7ISW3    ┆ 0.03849   ┆ … ┆ 670/723   ┆ 92.7      ┆ 35.0      ┆ 15.0     │
# │ 600       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Os12g0610 ┆ Q0ILZ7    ┆ O43761    ┆ 0.06753   ┆ … ┆ 282/353   ┆ 79.9      ┆ 34.0      ┆ 14.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ 0.02451   ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ 0.04982   ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ 800       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (11) Filtering Condition3
#
# - Select hits that can be converted to Ensembl gene id with TogoID API
# - https://togoid.dbcls.jp/

# %%
togoid_convert = pl.read_csv(
    togoid_convert_tsv_path,
    separator='\t'
).rename(
    {
        "uniprot_id" : "foldseek hit"
    }
).filter(
    pl.col("ensembl_gene_id").is_not_null()
).sort(
    by=["foldseek hit"],
    descending=[False]
)

display(togoid_convert)
# Out:
# shape: (5_033, 6)
# ┌──────────────┬───────────────────┬──────────────────┬─────────────────┬─────────┬────────────────┐
# │ foldseek hit ┆ ensembl_protein_i ┆ ensembl_transcri ┆ ensembl_gene_id ┆ hgnc_id ┆ hgnc_symbol_id │
# │ ---          ┆ d                 ┆ pt_id            ┆ ---             ┆ ---     ┆ ---            │
# │ str          ┆ ---               ┆ ---              ┆ str             ┆ i64     ┆ str            │
# │              ┆ str               ┆ str              ┆                 ┆         ┆                │
# ╞══════════════╪═══════════════════╪══════════════════╪═════════════════╪═════════╪════════════════╡
# │ A0A024QZP7   ┆ ENSP00000397973   ┆ ENST00000448257  ┆ ENSG00000170312 ┆ 1722    ┆ CDK1           │
# │ A0A024QZW4   ┆ ENSP00000498054   ┆ ENST00000648987  ┆ ENSG00000124786 ┆ 21601   ┆ SLC35B3        │
# │ A0A024QZW4   ┆ ENSP00000518269   ┆ ENST00000710437  ┆ ENSG00000124786 ┆ 21601   ┆ SLC35B3        │
# │ …            ┆ …                 ┆ …                ┆ …               ┆ …       ┆ …              │
# │ X6RIU2       ┆ ENSP00000409912   ┆ ENST00000442513  ┆ ENSG00000163075 ┆ 33720   ┆ CFAP221        │
# │ X6RLA8       ┆ ENSP00000416709   ┆ ENST00000437579  ┆ ENSG00000107954 ┆ 7761    ┆ NEURL1         │
# │ X6RM59       ┆ ENSP00000476480   ┆ ENST00000610140  ┆ ENSG00000122643 ┆ 17820   ┆ NT5C3A         │
# └──────────────┴───────────────────┴──────────────────┴─────────────────┴─────────┴────────────────┘

# %%
condition3 = condition2.join(
    togoid_convert,
    on="foldseek hit",
    how="left",
    coalesce=True
).drop(
    [
        "ensembl_transcript_id",
        "hgnc_id"
    ]
).filter(
    pl.col("ensembl_gene_id").is_not_null()
).select(
    [
        "hit label",
        "From",
        "UniProt Accession",
        "foldseek hit",
        "ensembl_protein_id",
        "ensembl_gene_id",
        "hgnc_symbol_id",
        "evalue",
        "prob",
        "gapopen",
        "pident",
        "fident",
        "nident",
        "qstart",
        "qend",
        "qlen",
        "tstart",
        "tend",
        "tlen",
        "alnlen",
        "mismatch",
        "qcov",
        "tcov",
        "rmsd",
        "lddt",
        "qtmscore",
        "ttmscore",
        "alntmscore",
        "taxid",
        "taxname",
        "Length_water",
        "Length_needle",
        "Identity_water",
        "Identity_percent_water",
        "Identity_percent_needle",
        "Similarity_percent_water",
        "Similarity_percent_needle",
        "Gaps_water",
        "Gaps_percent_water",
        "Gaps_needle",
        "Gaps_percent_needle",
        "Score_water",
        "Score_needle"
    ]
).sort(
    by=["From", "foldseek hit", "UniProt Accession"], # sort by From, foldseek hit, UniProt Accession (change order)
    descending=[False, False, False]
)

print(condition3.group_by(["From", "UniProt Accession", "foldseek hit"], maintain_order=True).n_unique())
display(condition3)
# Out:
# shape: (3_721, 43)
# ┌────────────┬────────────┬────────────┬───────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ From       ┆ UniProt    ┆ foldseek   ┆ hit   ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ Accession  ┆ hit        ┆ label ┆   ┆ le        ┆ ent_needl ┆ er        ┆ dle       │
# │ str        ┆ ---        ┆ ---        ┆ ---   ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---       │
# │            ┆ str        ┆ str        ┆ u32   ┆   ┆ u32       ┆ ---       ┆ u32       ┆ u32       │
# │            ┆            ┆            ┆       ┆   ┆           ┆ u32       ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ B7FAP2     ┆ A0A140T9Z0 ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os01g01796 ┆ Q0JQ63     ┆ B7Z8Q8     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os01g01796 ┆ B7FAP2     ┆ O60656     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …     ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Os12g06108 ┆ Q0ILZ7     ┆ O43761     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────┴───┴───────────┴───────────┴───────────┴───────────┘
# shape: (7_065, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ … ┆ 370/775   ┆ 47.7      ┆ 126.0     ┆ 89.5     │
# │ hit-4     ┆ 600       ┆           ┆ 0         ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0179 ┆ Q0JQ63    ┆ B7Z8Q8    ┆ … ┆ 237/580   ┆ 40.9      ┆ 151.0     ┆ 132.5    │
# │ hit-34    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O60656    ┆ … ┆ 269/643   ┆ 41.8      ┆ 145.5     ┆ 121.0    │
# │ hit-55    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
hit_count_condition3 = condition3.group_by(
    ["From"],
    maintain_order=True
).agg(
    (pl.col("foldseek hit").count().alias("hit count (gene level)"))
).sort(
    by=["hit count (gene level)"],
    descending=True
)

display(hit_count_condition3)
# Out:
# shape: (147, 2)
# ┌──────────────┬────────────────────────┐
# │ From         ┆ hit count (gene level) │
# │ ---          ┆ ---                    │
# │ str          ┆ u32                    │
# ╞══════════════╪════════════════════════╡
# │ Os04g0453200 ┆ 249                    │
# │ Os12g0512100 ┆ 217                    │
# │ Os01g0613500 ┆ 211                    │
# │ …            ┆ …                      │
# │ Os06g0278000 ┆ 1                      │
# │ Os11g0154900 ┆ 1                      │
# │ Os11g0649600 ┆ 1                      │
# └──────────────┴────────────────────────┘

# %%
foldseek_filter_viz = condition3.select(
    "hit label",
    "From",
    "UniProt Accession",
    "foldseek hit",
    "pident",
    "fident",
    "qcov",
    "tcov",
    "rmsd",
    "lddt",
    "Identity_percent_needle",
    "Identity_percent_water",
    "Similarity_percent_needle",
    "Similarity_percent_water"
).unique(
    subset=["From", "foldseek hit", "UniProt Accession"],
    maintain_order=True
).sort(
    by=["From", "foldseek hit", "UniProt Accession"],
    descending=[False, False, False]
)

display(foldseek_filter_viz)
# Out:
# shape: (3_721, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Identity_ ┆ Identity_ ┆ Similarit ┆ Similari │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ percent_n ┆ percent_w ┆ y_percent ┆ ty_perce │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ eedle     ┆ ater      ┆ _needle   ┆ nt_water │
# │           ┆           ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ … ┆ 15.7      ┆ 23.1      ┆ 25.7      ┆ 33.4     │
# │ hit-4     ┆ 600       ┆           ┆ 0         ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0179 ┆ Q0JQ63    ┆ B7Z8Q8    ┆ … ┆ 16.2      ┆ 26.8      ┆ 28.8      ┆ 40.8     │
# │ hit-34    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O60656    ┆ … ┆ 15.9      ┆ 26.0      ┆ 27.7      ┆ 43.5     │
# │ hit-55    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ O43761    ┆ … ┆ 5.4       ┆ 29.5      ┆ 8.2       ┆ 41.0     │
# │ hit-13465 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 10.4      ┆ 31.0      ┆ 17.5      ┆ 55.2     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ 17.9      ┆ 23.6      ┆ 25.4      ┆ 33.5     │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (12) Calculate median of Similarity_percent_needle and lddt

# %%
median_x = foldseek_filter_viz.select(
    pl.col("Similarity_percent_needle").median().alias("Similarity_percent_needle_median")
).unique().to_series().to_list()[0]

# third quartile of Similarity_percent_needle (x)
third_quartile = foldseek_filter_viz.select(
    pl.col("Similarity_percent_needle").quantile(0.75).alias("third_quartile")
).to_series().to_list()[0]

median_y = foldseek_filter_viz.select(
    pl.col("lddt").median().alias("lddt_median")
).unique().to_series().to_list()[0]

print(median_x, third_quartile, median_y)
# Out:
# 28.4 33.8 0.549

# %%
foldseek_filter_viz_pd = foldseek_filter_viz.to_pandas()

plt.figure(figsize=(8, 8), dpi=500)

sns.jointplot(
    data=foldseek_filter_viz_pd,
    x="Similarity_percent_needle",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Global alignment similarity (%)", fontsize=14)
plt.ylabel("Average lDDT", fontsize=14) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
# plt.axvline(x=25, color="black", linestyle=":")
plt.axvline(x=50, color="black", linestyle=":")
# plt.axvline(x=75, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.axhline(y=color_y, color="black", linestyle=":")
# plt.figure(figsize=(7, 7), dpi=500)
plt.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_filtercondtion3_viz_plot_similarity_percent_needle_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %%
sns.jointplot(
    data=foldseek_filter_viz,
    x="Similarity_percent_needle",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.fill_betweenx(
    y=[median_y, 1],
    x1=-0.5,
    x2=third_quartile,
    color="red",
    alpha=0.1
)

# plt.fill_betweenx(
#     y=[median_y, 1],
#     x1=-0.5,
#     x2=third_quartile,
#     color="orange",
#     alpha=0.1
# )

# plt.fill_betweenx(
#     y=[median_y, 1],
#     x1=third_quartile,
#     x2=100,
#     color="blue",
#     alpha=0.1
# )

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Global alignment similarity (%)", fontsize=14)
plt.ylabel("Average lDDT", fontsize=14) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axhline(y=median_y, color="black", linestyle=":")
plt.axvline(x=third_quartile, color="black", linestyle=":")
# plt.figure(figsize=(8, 8), dpi=500)

plt.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_rep_filtercondtion3_viz_plot_similarity_percent_needle_lddt_{VERSION}.png",
    dpi=500
)

plt.show()

# %%
# top hit example
# https://www.uniprot.org/uniprotkb/P62805/entry
foldseek_filter_viz_top = foldseek_filter_viz.filter(
    (pl.col("lddt") >= 0.9) &
    (pl.col("Similarity_percent_needle") > 90)
)

display(foldseek_filter_viz_top)
# Out:
# shape: (1, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Identity_ ┆ Identity_ ┆ Similarit ┆ Similari │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ percent_n ┆ percent_w ┆ y_percent ┆ ty_perce │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ eedle     ┆ ater      ┆ _needle   ┆ nt_water │
# │           ┆           ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os02g0684 ┆ Q7XUC9    ┆ P62805    ┆ … ┆ 98.1      ┆ 98.1      ┆ 100.0     ┆ 100.0    │
# │ hit-3537  ┆ 500       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (13) Calculate median of Similarity_percent_water and lddt

# %%
median_x_water = foldseek_filter_viz.select(
    pl.col("Similarity_percent_water").median().alias("Similarity_percent_water_median")
).unique().to_series().to_list()[0]

# third quartile of Similarity_percent_water (x)
third_quartile_water = foldseek_filter_viz.select(
    pl.col("Similarity_percent_water").quantile(0.75).alias("third_quartile")
).to_series().to_list()[0]

median_y_water = foldseek_filter_viz.select(
    pl.col("lddt").median().alias("lddt_median")
).unique().to_series().to_list()[0]

print(median_x_water, third_quartile_water, median_y_water)
# Out:
# 38.2 43.0 0.549

# %%
foldseek_filter_viz_pd = foldseek_filter_viz.to_pandas()

plt.figure(figsize=(8, 8), dpi=500)

sns.jointplot(
    data=foldseek_filter_viz_pd,
    x="Similarity_percent_water",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Local alignment similarity (%)", fontsize=14)
plt.ylabel("Average lDDT", fontsize=14) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
# plt.axvline(x=25, color="black", linestyle=":")
plt.axvline(x=50, color="black", linestyle=":")
# plt.axvline(x=75, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.axhline(y=color_y, color="black", linestyle=":")
# plt.figure(figsize=(7, 7), dpi=500)

plt.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_filtercondtion3_viz_plot_similarity_percent_water_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (14) Scatter Plot with boxplot

# %%
g = sns.JointGrid(
    data=foldseek_filter_viz,
    x="Similarity_percent_needle",
    y="lddt",
    height=11,
    ratio=4,
    marginal_ticks=True
)

# plot scatter plot
g.plot_joint(sns.scatterplot, color="steelblue")

# change marginal plot to boxplot
g.plot_marginals(sns.boxplot, color="steelblue")

# set plot settings
g.ax_joint.set_xlim(-0.5, 100)
g.ax_joint.set_ylim(0, 1)
g.ax_joint.set_xlabel("Global alignment similarity(%)", fontsize=14)
g.ax_joint.set_ylabel("Average lDDT", fontsize=14)

# fill range based on median
g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=third_quartile,
    x2=100,
    color="blue",
    alpha=0.1
)

g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=median_x,
    x2=third_quartile,
    color="orange",
    alpha=0.2
)

g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=-0.5,
    x2=median_x,
    color="yellow",
    alpha=0.1
)

g.ax_joint.axvline(x=median_x, color="black", linestyle=":")
g.ax_joint.axhline(y=median_y, color="black", linestyle=":")
g.ax_joint.axvline(x=third_quartile, color="black", linestyle=":")
plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (15) Filtering hit

# %%
# Condition1: LDDT >= median_y & Identity > third_quartile
condition3_filter_1 = condition3.filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") > third_quartile)
)

print(condition3_filter_1.select("From").n_unique())
print(condition3_filter_1.select("From").unique().to_series().to_list())
print(condition3_filter_1.select("hit label").n_unique())
print(condition3_filter_1.select("hit label").unique().to_series().to_list())
display(condition3_filter_1)
# Out:
# 73
# ['Os06g0560000', 'Os07g0258400', 'Os02g0504000', 'Os08g0462900', 'Os03g0237100', 'Os11g0134900', 'Os01g0591300', 'Os12g0194900', 'Os04g0339800', 'Os01g0631900', 'Os07g0292100', 'Os01g0382400', 'Os02g0684500', 'Os03g0634400', 'Os03g0404800', 'Os06g0228500', 'Os09g0424300', 'Os02g0791400', 'Os01g0627400', 'Os12g0512100', 'Os02g0306401', 'Os02g0575200', 'Os10g0144700', 'Os08g0455900', 'Os06g0697600', 'Os02g0226200', 'Os04g0453200', 'Os03g0210200', 'Os01g0232000', 'Os10g0436900', 'Os10g0528300', 'Os10g0527800', 'Os07g0622700', 'Os11g0151500', 'Os05g0592300', 'Os01g0871600', 'Os11g0655900', 'Os01g0192900', 'Os08g0111200', 'Os09g0567500', 'Os01g0854800', 'Os02g0570700', 'Os09g0275400', 'Os12g0441600', 'Os03g0162200', 'Os03g0833100', 'Os08g0547300', 'Os01g0613500', 'Os01g0871500', 'Os01g0382000', 'Os11g0286800', 'Os01g0696800', 'Os04g0587500', 'Os10g0530900', 'Os09g0528700', 'Os10g0456100', 'Os06g0129900', 'Os03g0760200', 'Os05g0113900', 'Os07g0257200', 'Os03g0332100', 'Os08g0101100', 'Os11g0210600', 'Os06g0210000', 'Os12g0123500', 'Os10g0531400', 'Os11g0439600', 'Os07g0129200', 'Os05g0482400', 'Os02g0149900', 'Os10g0165300', 'Os07g0664000', 'Os09g0551600']
# 871
# ['foldseek-hit-12438', 'foldseek-hit-1389', 'foldseek-hit-10909', 'foldseek-hit-4701', 'foldseek-hit-3508', 'foldseek-hit-3488', 'foldseek-hit-5679', 'foldseek-hit-3583', 'foldseek-hit-6967', 'foldseek-hit-6473', 'foldseek-hit-9731', 'foldseek-hit-3590', 'foldseek-hit-3608', 'foldseek-hit-2540', 'foldseek-hit-3595', 'foldseek-hit-13016', 'foldseek-hit-4689', 'foldseek-hit-10059', 'foldseek-hit-925', 'foldseek-hit-8154', 'foldseek-hit-1011', 'foldseek-hit-5068', 'foldseek-hit-1070', 'foldseek-hit-1386', 'foldseek-hit-6047', 'foldseek-hit-6659', 'foldseek-hit-9014', 'foldseek-hit-9711', 'foldseek-hit-2371', 'foldseek-hit-6097', 'foldseek-hit-11320', 'foldseek-hit-9694', 'foldseek-hit-2387', 'foldseek-hit-4008', 'foldseek-hit-1578', 'foldseek-hit-12839', 'foldseek-hit-6048', 'foldseek-hit-3446', 'foldseek-hit-5140', 'foldseek-hit-6654', 'foldseek-hit-3452', 'foldseek-hit-11165', 'foldseek-hit-9607', 'foldseek-hit-3503', 'foldseek-hit-5167', 'foldseek-hit-10143', 'foldseek-hit-351', 'foldseek-hit-1583', 'foldseek-hit-11321', 'foldseek-hit-12442', 'foldseek-hit-6057', 'foldseek-hit-9716', 'foldseek-hit-10800', 'foldseek-hit-12256', 'foldseek-hit-4824', 'foldseek-hit-4405', 'foldseek-hit-1437', 'foldseek-hit-6716', 'foldseek-hit-3605', 'foldseek-hit-12164', 'foldseek-hit-10734', 'foldseek-hit-9597', 'foldseek-hit-12294', 'foldseek-hit-4873', 'foldseek-hit-4771', 'foldseek-hit-10593', 'foldseek-hit-9595', 'foldseek-hit-9132', 'foldseek-hit-5145', 'foldseek-hit-1161', 'foldseek-hit-11181', 'foldseek-hit-5040', 'foldseek-hit-5661', 'foldseek-hit-8754', 'foldseek-hit-12636', 'foldseek-hit-6651', 'foldseek-hit-12461', 'foldseek-hit-347', 'foldseek-hit-9730', 'foldseek-hit-7019', 'foldseek-hit-921', 'foldseek-hit-9705', 'foldseek-hit-10768', 'foldseek-hit-10884', 'foldseek-hit-8696', 'foldseek-hit-9683', 'foldseek-hit-5838', 'foldseek-hit-9589', 'foldseek-hit-3704', 'foldseek-hit-9123', 'foldseek-hit-3728', 'foldseek-hit-3598', 'foldseek-hit-3456', 'foldseek-hit-930', 'foldseek-hit-6637', 'foldseek-hit-3687', 'foldseek-hit-2404', 'foldseek-hit-6441', 'foldseek-hit-3507', 'foldseek-hit-1508', 'foldseek-hit-9588', 'foldseek-hit-4715', 'foldseek-hit-11937', 'foldseek-hit-6649', 'foldseek-hit-12593', 'foldseek-hit-9602', 'foldseek-hit-2370', 'foldseek-hit-6395', 'foldseek-hit-1794', 'foldseek-hit-11237', 'foldseek-hit-3600', 'foldseek-hit-2395', 'foldseek-hit-9955', 'foldseek-hit-10726', 'foldseek-hit-1256', 'foldseek-hit-3447', 'foldseek-hit-6444', 'foldseek-hit-12444', 'foldseek-hit-13160', 'foldseek-hit-8748', 'foldseek-hit-8590', 'foldseek-hit-1189', 'foldseek-hit-10719', 'foldseek-hit-4346', 'foldseek-hit-3546', 'foldseek-hit-1587', 'foldseek-hit-12292', 'foldseek-hit-354', 'foldseek-hit-4692', 'foldseek-hit-2373', 'foldseek-hit-1394', 'foldseek-hit-318', 'foldseek-hit-9604', 'foldseek-hit-10101', 'foldseek-hit-11003', 'foldseek-hit-10589', 'foldseek-hit-10948', 'foldseek-hit-11013', 'foldseek-hit-8771', 'foldseek-hit-1439', 'foldseek-hit-6701', 'foldseek-hit-6808', 'foldseek-hit-1573', 'foldseek-hit-1104', 'foldseek-hit-5825', 'foldseek-hit-8102', 'foldseek-hit-1269', 'foldseek-hit-3664', 'foldseek-hit-1071', 'foldseek-hit-2451', 'foldseek-hit-3499', 'foldseek-hit-3612', 'foldseek-hit-9585', 'foldseek-hit-10793', 'foldseek-hit-10709', 'foldseek-hit-6095', 'foldseek-hit-5070', 'foldseek-hit-9613', 'foldseek-hit-5166', 'foldseek-hit-3983', 'foldseek-hit-10076', 'foldseek-hit-12097', 'foldseek-hit-11114', 'foldseek-hit-1276', 'foldseek-hit-2402', 'foldseek-hit-2432', 'foldseek-hit-7803', 'foldseek-hit-2546', 'foldseek-hit-11019', 'foldseek-hit-12298', 'foldseek-hit-5367', 'foldseek-hit-11298', 'foldseek-hit-6056', 'foldseek-hit-1542', 'foldseek-hit-1289', 'foldseek-hit-3705', 'foldseek-hit-10808', 'foldseek-hit-1297', 'foldseek-hit-7007', 'foldseek-hit-3616', 'foldseek-hit-9661', 'foldseek-hit-3601', 'foldseek-hit-5071', 'foldseek-hit-6625', 'foldseek-hit-6052', 'foldseek-hit-4808', 'foldseek-hit-10784', 'foldseek-hit-6476', 'foldseek-hit- ...
# shape: (1_701, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ P24298    ┆ … ┆ 167/598   ┆ 27.9      ┆ 208.5     ┆ 179.0    │
# │ hit-243   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ P24298    ┆ … ┆ 167/598   ┆ 27.9      ┆ 208.5     ┆ 179.0    │
# │ hit-243   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ Q4AC99    ┆ … ┆ 183/642   ┆ 28.5      ┆ 528.5     ┆ 522.0    │
# │ hit-254   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 84/552    ┆ 15.2      ┆ 481.5     ┆ 474.5    │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 84/552    ┆ 15.2      ┆ 481.5     ┆ 474.5    │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 84/552    ┆ 15.2      ┆ 481.5     ┆ 474.5    │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Condition2: LDDT >= median_y & Identity > median_x
condition3_filter_2 = condition3.filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") > median_x)
)

print(condition3_filter_2.select("From").n_unique())
print(condition3_filter_2.select("From").unique().to_series().to_list())
print(condition3_filter_2.select("hit label").n_unique())
print(condition3_filter_2.select("hit label").unique().to_series().to_list())
display(condition3_filter_2)
# Out:
# 86
# ['Os06g0129900', 'Os01g0382400', 'Os03g0332100', 'Os11g0134900', 'Os11g0286800', 'Os01g0631900', 'Os02g0684500', 'Os03g0162200', 'Os08g0455900', 'Os07g0292100', 'Os01g0232000', 'Os06g0697600', 'Os11g0151500', 'Os03g0210200', 'Os01g0192900', 'Os03g0667300', 'Os01g0279400', 'Os01g0871600', 'Os10g0144700', 'Os06g0228500', 'Os02g0570700', 'Os03g0833100', 'Os12g0123500', 'Os02g0504000', 'Os11g0439600', 'Os02g0575200', 'Os03g0404800', 'Os10g0527800', 'Os02g0791400', 'Os12g0512100', 'Os11g0210600', 'Os09g0275400', 'Os05g0106200', 'Os04g0587500', 'Os01g0696800', 'Os12g0194900', 'Os01g0871500', 'Os10g0456100', 'Os02g0563000', 'Os07g0258400', 'Os04g0339800', 'Os10g0531400', 'Os01g0591300', 'Os10g0436900', 'Os09g0551600', 'Os01g0854800', 'Os12g0441600', 'Os11g0655900', 'Os07g0664000', 'Os08g0101100', 'Os04g0179100', 'Os09g0424300', 'Os02g0226200', 'Os06g0210000', 'Os02g0306401', 'Os08g0462900', 'Os03g0431800', 'Os05g0592300', 'Os07g0561800', 'Os10g0528300', 'Os09g0528700', 'Os08g0111200', 'Os01g0382000', 'Os05g0113900', 'Os06g0560000', 'Os09g0567500', 'Os08g0547800', 'Os08g0189300', 'Os03g0760200', 'Os01g0613500', 'Os04g0453200', 'Os07g0622700', 'Os03g0237100', 'Os10g0165300', 'Os10g0530900', 'Os05g0482400', 'Os07g0129200', 'Os02g0149900', 'Os09g0554200', 'Os07g0257200', 'Os07g0190000', 'Os03g0634400', 'Os08g0547300', 'Os01g0627400', 'Os04g0578600', 'Os07g0524900']
# 1372
# ['foldseek-hit-1475', 'foldseek-hit-800', 'foldseek-hit-8004', 'foldseek-hit-3595', 'foldseek-hit-3385', 'foldseek-hit-3706', 'foldseek-hit-1252', 'foldseek-hit-9014', 'foldseek-hit-12296', 'foldseek-hit-8733', 'foldseek-hit-10059', 'foldseek-hit-6426', 'foldseek-hit-6461', 'foldseek-hit-5136', 'foldseek-hit-3963', 'foldseek-hit-1506', 'foldseek-hit-1484', 'foldseek-hit-363', 'foldseek-hit-10725', 'foldseek-hit-4353', 'foldseek-hit-11003', 'foldseek-hit-12599', 'foldseek-hit-4560', 'foldseek-hit-4331', 'foldseek-hit-5825', 'foldseek-hit-8736', 'foldseek-hit-10793', 'foldseek-hit-9513', 'foldseek-hit-6967', 'foldseek-hit-3444', 'foldseek-hit-354', 'foldseek-hit-5711', 'foldseek-hit-10976', 'foldseek-hit-11010', 'foldseek-hit-2949', 'foldseek-hit-4562', 'foldseek-hit-10131', 'foldseek-hit-10768', 'foldseek-hit-5154', 'foldseek-hit-1578', 'foldseek-hit-3929', 'foldseek-hit-637', 'foldseek-hit-12256', 'foldseek-hit-10861', 'foldseek-hit-5058', 'foldseek-hit-13029', 'foldseek-hit-1248', 'foldseek-hit-12777', 'foldseek-hit-3616', 'foldseek-hit-7502', 'foldseek-hit-3031', 'foldseek-hit-788', 'foldseek-hit-9176', 'foldseek-hit-4122', 'foldseek-hit-3501', 'foldseek-hit-4013', 'foldseek-hit-3992', 'foldseek-hit-8773', 'foldseek-hit-1582', 'foldseek-hit-5135', 'foldseek-hit-12054', 'foldseek-hit-12787', 'foldseek-hit-13137', 'foldseek-hit-5075', 'foldseek-hit-1273', 'foldseek-hit-1016', 'foldseek-hit-9585', 'foldseek-hit-8951', 'foldseek-hit-6439', 'foldseek-hit-9959', 'foldseek-hit-7029', 'foldseek-hit-641', 'foldseek-hit-3926', 'foldseek-hit-11510', 'foldseek-hit-3498', 'foldseek-hit-10978', 'foldseek-hit-1307', 'foldseek-hit-4346', 'foldseek-hit-1556', 'foldseek-hit-11303', 'foldseek-hit-3507', 'foldseek-hit-6885', 'foldseek-hit-13085', 'foldseek-hit-3618', 'foldseek-hit-4133', 'foldseek-hit-8757', 'foldseek-hit-786', 'foldseek-hit-4715', 'foldseek-hit-916', 'foldseek-hit-9608', 'foldseek-hit-1011', 'foldseek-hit-10962', 'foldseek-hit-1044', 'foldseek-hit-785', 'foldseek-hit-10139', 'foldseek-hit-13144', 'foldseek-hit-11181', 'foldseek-hit-3450', 'foldseek-hit-4762', 'foldseek-hit-3605', 'foldseek-hit-1563', 'foldseek-hit-3445', 'foldseek-hit-10957', 'foldseek-hit-4642', 'foldseek-hit-10972', 'foldseek-hit-3473', 'foldseek-hit-6445', 'foldseek-hit-8726', 'foldseek-hit-11410', 'foldseek-hit-12724', 'foldseek-hit-4666', 'foldseek-hit-13158', 'foldseek-hit-11284', 'foldseek-hit-1502', 'foldseek-hit-4160', 'foldseek-hit-6021', 'foldseek-hit-6446', 'foldseek-hit-1032', 'foldseek-hit-13107', 'foldseek-hit-5391', 'foldseek-hit-348', 'foldseek-hit-10949', 'foldseek-hit-2387', 'foldseek-hit-11654', 'foldseek-hit-1579', 'foldseek-hit-4237', 'foldseek-hit-10022', 'foldseek-hit-10317', 'foldseek-hit-1313', 'foldseek-hit-1206', 'foldseek-hit-1243', 'foldseek-hit-11282', 'foldseek-hit-11021', 'foldseek-hit-5534', 'foldseek-hit-1261', 'foldseek-hit-3974', 'foldseek-hit-11013', 'foldseek-hit-9711', 'foldseek-hit-7045', 'foldseek-hit-4365', 'foldseek-hit-12294', 'foldseek-hit-5157', 'foldseek-hit-1540', 'foldseek-hit-3064', 'foldseek-hit-6474', 'foldseek-hit-6073', 'foldseek-hit-11195', 'foldseek-hit-10796', 'foldseek-hit-10050', 'foldseek-hit-8753', 'foldseek-hit-5091', 'foldseek-hit-3453', 'foldseek-hit-11120', 'foldseek-hit-4126', 'foldseek-hit-7803', 'foldseek-hit-4694', 'foldseek-hit-11362', 'foldseek-hit-3694', 'foldseek-hit-11024', 'foldseek-hit-10747', 'foldseek-hit-5160', 'foldseek-hit-12689', 'foldseek-hit-875', 'foldseek-hit-5931', 'foldseek-hit-6631', 'foldseek-hit-4143', 'foldseek-hit-10795', 'foldseek-hit-11154', 'foldseek-hit-3134', 'foldseek-hit-6069', 'foldseek-hit-13170', 'foldseek-hit-10652', 'foldseek-hit-10952', 'foldseek-hit-9612', 'foldseek-hit-845', 'foldseek-hit-12452', 'foldseek-hit-8836', 'foldseek-hit-8748', 'foldseek-hit-10263', 'foldseek-hit-1372', 'foldseek-hit-4333', 'foldseek-hit-3976', 'foldseek-hit-8001', 'foldseek-hit-12458', 'foldseek-hit-11165', 'foldseek-hit-4684', 'foldseek-hit-1486', 'foldseek-hit-4682', 'folds ...
# shape: (2_704, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ P24298    ┆ … ┆ 167/598   ┆ 27.9      ┆ 208.5     ┆ 179.0    │
# │ hit-243   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ P24298    ┆ … ┆ 167/598   ┆ 27.9      ┆ 208.5     ┆ 179.0    │
# │ hit-243   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ Q4AC99    ┆ … ┆ 183/642   ┆ 28.5      ┆ 528.5     ┆ 522.0    │
# │ hit-254   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0512 ┆ Q0IN24    ┆ Q9Y694    ┆ … ┆ 237/649   ┆ 36.5      ┆ 247.0     ┆ 236.5    │
# │ hit-13195 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0512 ┆ Q0IN24    ┆ Q9Y694    ┆ … ┆ 237/649   ┆ 36.5      ┆ 247.0     ┆ 236.5    │
# │ hit-13195 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0512 ┆ Q0IN24    ┆ Q9Y694    ┆ … ┆ 237/649   ┆ 36.5      ┆ 247.0     ┆ 236.5    │
# │ hit-13195 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Condition3: LDDT >= median_y & Identity <= median_x
condition3_filter_3 = condition3.filter(
    ((pl.col("lddt") >= median_y) &
    (pl.col("Similarity_percent_needle") <= median_x)) &
    (~pl.col("From").is_in(condition3_filter_2.select("From").to_series())) & # Exclude Genes in Condition2 (LDDT >= median_y & Identity > median_x)
    (~pl.col("foldseek hit").is_in(condition3_filter_2.select("foldseek hit").to_series()))
)

print(condition3_filter_3.select("From").n_unique())
print(condition3_filter_3.select("From").unique().to_series().to_list())
print(condition3_filter_3.select("hit label").n_unique())
print(condition3_filter_3.select("hit label").unique().to_series().to_list())
display(condition3_filter_3)
# Out:
# 19
# ['Os03g0372600', 'Os06g0718400', 'Os12g0555200', 'Os01g0655500', 'Os04g0381700', 'Os02g0136933', 'Os12g0610800', 'Os04g0468600', 'Os03g0617500', 'Os03g0371000', 'Os07g0179300', 'Os04g0545600', 'Os07g0524200', 'Os04g0400000', 'Os02g0584700', 'Os07g0251200', 'Os05g0475700', 'Os12g0555000', 'Os11g0154900']
# 68
# ['foldseek-hit-2728', 'foldseek-hit-13253', 'foldseek-hit-5488', 'foldseek-hit-2853', 'foldseek-hit-13237', 'foldseek-hit-7700', 'foldseek-hit-4029', 'foldseek-hit-5477', 'foldseek-hit-5474', 'foldseek-hit-5473', 'foldseek-hit-2830', 'foldseek-hit-13467', 'foldseek-hit-5480', 'foldseek-hit-5867', 'foldseek-hit-5476', 'foldseek-hit-2732', 'foldseek-hit-2805', 'foldseek-hit-2891', 'foldseek-hit-1712', 'foldseek-hit-2733', 'foldseek-hit-4190', 'foldseek-hit-5471', 'foldseek-hit-5485', 'foldseek-hit-5857', 'foldseek-hit-13330', 'foldseek-hit-7477', 'foldseek-hit-4057', 'foldseek-hit-3509', 'foldseek-hit-5487', 'foldseek-hit-2818', 'foldseek-hit-13314', 'foldseek-hit-7538', 'foldseek-hit-5468', 'foldseek-hit-5864', 'foldseek-hit-4026', 'foldseek-hit-4188', 'foldseek-hit-5482', 'foldseek-hit-4024', 'foldseek-hit-4018', 'foldseek-hit-6285', 'foldseek-hit-2850', 'foldseek-hit-2854', 'foldseek-hit-4023', 'foldseek-hit-5470', 'foldseek-hit-1693', 'foldseek-hit-4025', 'foldseek-hit-4050', 'foldseek-hit-5855', 'foldseek-hit-2822', 'foldseek-hit-6299', 'foldseek-hit-2802', 'foldseek-hit-4016', 'foldseek-hit-7699', 'foldseek-hit-5479', 'foldseek-hit-7697', 'foldseek-hit-5484', 'foldseek-hit-13466', 'foldseek-hit-5870', 'foldseek-hit-8190', 'foldseek-hit-4043', 'foldseek-hit-12190', 'foldseek-hit-4186', 'foldseek-hit-4187', 'foldseek-hit-6361', 'foldseek-hit-5475', 'foldseek-hit-5486', 'foldseek-hit-2729', 'foldseek-hit-3513']
# shape: (141, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0655 ┆ A0A0P0V63 ┆ H7BXU9    ┆ … ┆ 781/1050  ┆ 74.4      ┆ 69.0      ┆ 52.0     │
# │ hit-1693  ┆ 500       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0655 ┆ Q5SN79    ┆ P53667    ┆ … ┆ 685/991   ┆ 69.1      ┆ 78.0      ┆ 54.0     │
# │ hit-1712  ┆ 500       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0655 ┆ Q5SN79    ┆ P53667    ┆ … ┆ 685/991   ┆ 69.1      ┆ 78.0      ┆ 54.0     │
# │ hit-1712  ┆ 500       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Condition4: LDDT >= median_y & Identity <= third_quartile
condition3_filter_4 = condition3.filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") <= third_quartile) &
    (~pl.col("From").is_in(condition3_filter_1.select("From").to_series())) & # Exclude Genes in Filter Condition1 (LDDT >= median_y & Identity > third_quartile)
    (~pl.col("foldseek hit").is_in(condition3_filter_1.select("foldseek hit").to_series())) # 
)

print(condition3_filter_4.select("From").n_unique())
print(condition3_filter_4.select("From").unique().to_series().to_list())
print(condition3_filter_4.select("hit label").n_unique())
print(condition3_filter_4.select("hit label").unique().to_series().to_list())
display(condition3_filter_4)
# Out:
# 34
# ['Os12g0610800', 'Os07g0190000', 'Os07g0524200', 'Os12g0555200', 'Os02g0584700', 'Os04g0179100', 'Os12g0555000', 'Os06g0718400', 'Os04g0381700', 'Os11g0154900', 'Os08g0189300', 'Os04g0578600', 'Os07g0251200', 'Os03g0431800', 'Os03g0617500', 'Os02g0136933', 'Os07g0524900', 'Os03g0651800', 'Os05g0475700', 'Os01g0284500', 'Os08g0547800', 'Os05g0106200', 'Os03g0667300', 'Os09g0554200', 'Os04g0400000', 'Os02g0563000', 'Os07g0179300', 'Os07g0561800', 'Os03g0371000', 'Os01g0655500', 'Os03g0372600', 'Os04g0468600', 'Os01g0279400', 'Os04g0545600']
# 157
# ['foldseek-hit-4503', 'foldseek-hit-4515', 'foldseek-hit-561', 'foldseek-hit-5479', 'foldseek-hit-4018', 'foldseek-hit-5996', 'foldseek-hit-4186', 'foldseek-hit-5468', 'foldseek-hit-1693', 'foldseek-hit-8318', 'foldseek-hit-10459', 'foldseek-hit-6037', 'foldseek-hit-8225', 'foldseek-hit-8226', 'foldseek-hit-2802', 'foldseek-hit-4025', 'foldseek-hit-6005', 'foldseek-hit-5878', 'foldseek-hit-4043', 'foldseek-hit-9345', 'foldseek-hit-4510', 'foldseek-hit-3278', 'foldseek-hit-6027', 'foldseek-hit-5477', 'foldseek-hit-8337', 'foldseek-hit-4517', 'foldseek-hit-13237', 'foldseek-hit-4024', 'foldseek-hit-4188', 'foldseek-hit-8190', 'foldseek-hit-10457', 'foldseek-hit-8312', 'foldseek-hit-3339', 'foldseek-hit-4029', 'foldseek-hit-7582', 'foldseek-hit-674', 'foldseek-hit-5876', 'foldseek-hit-2733', 'foldseek-hit-4026', 'foldseek-hit-4045', 'foldseek-hit-6018', 'foldseek-hit-8339', 'foldseek-hit-5476', 'foldseek-hit-5992', 'foldseek-hit-5486', 'foldseek-hit-8222', 'foldseek-hit-1712', 'foldseek-hit-3296', 'foldseek-hit-2891', 'foldseek-hit-2854', 'foldseek-hit-5857', 'foldseek-hit-3360', 'foldseek-hit-8344', 'foldseek-hit-6361', 'foldseek-hit-2805', 'foldseek-hit-3276', 'foldseek-hit-621', 'foldseek-hit-9313', 'foldseek-hit-5485', 'foldseek-hit-3265', 'foldseek-hit-4190', 'foldseek-hit-9360', 'foldseek-hit-7699', 'foldseek-hit-6000', 'foldseek-hit-8311', 'foldseek-hit-13467', 'foldseek-hit-8260', 'foldseek-hit-5870', 'foldseek-hit-5470', 'foldseek-hit-8237', 'foldseek-hit-5475', 'foldseek-hit-5474', 'foldseek-hit-5864', 'foldseek-hit-5480', 'foldseek-hit-8223', 'foldseek-hit-572', 'foldseek-hit-3231', 'foldseek-hit-2850', 'foldseek-hit-2732', 'foldseek-hit-5877', 'foldseek-hit-2830', 'foldseek-hit-5293', 'foldseek-hit-6285', 'foldseek-hit-3509', 'foldseek-hit-2853', 'foldseek-hit-9344', 'foldseek-hit-3271', 'foldseek-hit-635', 'foldseek-hit-8235', 'foldseek-hit-9363', 'foldseek-hit-13314', 'foldseek-hit-5867', 'foldseek-hit-4181', 'foldseek-hit-6015', 'foldseek-hit-5484', 'foldseek-hit-7700', 'foldseek-hit-7477', 'foldseek-hit-7593', 'foldseek-hit-676', 'foldseek-hit-4519', 'foldseek-hit-7697', 'foldseek-hit-4507', 'foldseek-hit-13253', 'foldseek-hit-2818', 'foldseek-hit-6029', 'foldseek-hit-637', 'foldseek-hit-4187', 'foldseek-hit-10461', 'foldseek-hit-8982', 'foldseek-hit-6030', 'foldseek-hit-13466', 'foldseek-hit-5482', 'foldseek-hit-4050', 'foldseek-hit-710', 'foldseek-hit-4462', 'foldseek-hit-4057', 'foldseek-hit-9211', 'foldseek-hit-2729', 'foldseek-hit-6299', 'foldseek-hit-5471', 'foldseek-hit-6003', 'foldseek-hit-2728', 'foldseek-hit-653', 'foldseek-hit-5988', 'foldseek-hit-3256', 'foldseek-hit-8303', 'foldseek-hit-5855', 'foldseek-hit-4520', 'foldseek-hit-3343', 'foldseek-hit-2822', 'foldseek-hit-8354', 'foldseek-hit-5973', 'foldseek-hit-4016', 'foldseek-hit-12190', 'foldseek-hit-8338', 'foldseek-hit-5473', 'foldseek-hit-6025', 'foldseek-hit-4508', 'foldseek-hit-8332', 'foldseek-hit-5488', 'foldseek-hit-8355', 'foldseek-hit-6021', 'foldseek-hit-4500', 'foldseek-hit-5994', 'foldseek-hit-8350', 'foldseek-hit-4023', 'foldseek-hit-8227', 'foldseek-hit-13330', 'foldseek-hit-8302', 'foldseek-hit-3197', 'foldseek-hit-7584', 'foldseek-hit-7538', 'foldseek-hit-3513', 'foldseek-hit-8220', 'foldseek-hit-5487', 'foldseek-hit-5991', 'foldseek-hit-8217']
# shape: (298, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0279 ┆ Q8H6D6    ┆ O15403    ┆ … ┆ 540/780   ┆ 69.2      ┆ 98.0      ┆ 70.5     │
# │ hit-561   ┆ 400       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0279 ┆ Q8H6D6    ┆ O15403    ┆ … ┆ 540/780   ┆ 69.2      ┆ 98.0      ┆ 70.5     │
# │ hit-561   ┆ 400       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0279 ┆ Q8H6D6    ┆ O76082    ┆ … ┆ 320/687   ┆ 46.6      ┆ 125.5     ┆ 103.5    │
# │ hit-572   ┆ 400       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (16) Custom Analysis: Assign Domain Information

# %%
# rice domain information
uniprot_info_rice = pl.read_csv(
    query_idmapping_tsv_path,
    separator='\t'
)

domain_info_rice = uniprot_info_rice.select(
    "From",
    "InterPro"
).rename(
    {
        "From": "UniProt Accession",
        "InterPro": "InterPro_rice"
    }
).with_columns(
    pl.col("InterPro_rice").str.strip_suffix(";")
).with_columns(
    pl.col("InterPro_rice").str.split(";").cast(pl.List(pl.Utf8))
)

# human domain information
uniprot_info_human = pl.read_csv(
    target_idmapping_tsv_path,
    separator='\t'
)

domain_info_human = uniprot_info_human.select(
    "From",
    "InterPro"
).rename(
    {
        "From": "foldseek hit",
        "InterPro": "InterPro_human"
    }
).with_columns(
    pl.col("InterPro_human").str.strip_suffix(";")
).with_columns(
    pl.col("InterPro_human").str.split(";").cast(pl.List(pl.Utf8))
)

display(domain_info_rice)
display(domain_info_human)
# Out:
# shape: (255, 2)
# ┌───────────────────┬────────────────────────────┐
# │ UniProt Accession ┆ InterPro_rice              │
# │ ---               ┆ ---                        │
# │ str               ┆ list[str]                  │
# ╞═══════════════════╪════════════════════════════╡
# │ A0A0N7KD90        ┆ ["IPR016161", "IPR016163"… │
# │ A0A0N7KDJ4        ┆ ["IPR012312", "IPR008913"… │
# │ A0A0N7KDK3        ┆ ["IPR034161", "IPR033121"… │
# │ …                 ┆ …                          │
# │ Q9LWR2            ┆ ["IPR023271", "IPR034294"… │
# │ Q9XHX6            ┆ ["IPR032710", "IPR053218"… │
# │ V9G2Z0            ┆ ["IPR012312", "IPR039512"… │
# └───────────────────┴────────────────────────────┘
# shape: (4_931, 2)
# ┌──────────────┬────────────────────────────┐
# │ foldseek hit ┆ InterPro_human             │
# │ ---          ┆ ---                        │
# │ str          ┆ list[str]                  │
# ╞══════════════╪════════════════════════════╡
# │ A0A023PX70   ┆ ["IPR011009", "IPR050198"… │
# │ A0A024CIM4   ┆ ["IPR029058", "IPR050654"… │
# │ A0A024QY88   ┆ ["IPR000742", "IPR007110"… │
# │ …            ┆ …                          │
# │ X6RIU2       ┆ ["IPR029676", "IPR013783"… │
# │ X6RLA8       ┆ ["IPR043136", "IPR037962"… │
# │ X6RM59       ┆ ["IPR036412", "IPR023214"… │
# └──────────────┴────────────────────────────┘

# %%
domain_info = condition3.join(
    domain_info_rice,
    on="UniProt Accession",
    how="left",
    coalesce=True,
    validate="m:m"
).join(
    domain_info_human,
    on="foldseek hit",
    how="left",
    coalesce=True,
    validate="m:m"
).with_columns(
    pl.col("InterPro_rice").list.set_intersection("InterPro_human").alias("InterPro ID intersection"),
    pl.col("InterPro_rice").list.set_intersection("InterPro_human").list.len().alias("InterPro ID intersection count")
).sort(
    by=["InterPro ID intersection count"],
    descending=[True]
).with_columns(
    pl.when(
        (pl.col("InterPro_rice").is_null()) | (pl.col("InterPro_human").is_null())
    ).then(
        pl.lit("missing InterPro entry in rice or human")
    ).when(
        pl.col("InterPro ID intersection count") == 0
    ).then(
        pl.lit("no common InterPro ID")
    ).otherwise(
        pl.lit("have common InterPro ID")
    ).alias("InterPro ID intersection tag")
).sort(
    by=["From", "UniProt Accession", "foldseek hit"],
    descending=[False, False, False]
)

display(domain_info)
# Out:
# shape: (7_065, 48)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ InterPro_ ┆ InterPro  ┆ InterPro  ┆ InterPro │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ human     ┆ ID inters ┆ ID inters ┆ ID inter │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ection    ┆ ection …  ┆ section  │
# │           ┆           ┆ str       ┆ str       ┆   ┆ list[str] ┆ ---       ┆ ---       ┆ …        │
# │           ┆           ┆           ┆           ┆   ┆           ┆ list[str] ┆ u32       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ … ┆ ["IPR0502 ┆ ["IPR0022 ┆ 2         ┆ have     │
# │ hit-4     ┆ 600       ┆           ┆ 0         ┆   ┆ 71", "IPR ┆ 13", "IPR ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002213"…  ┆ 035595"…  ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O60656    ┆ … ┆ ["IPR0502 ┆ ["IPR0022 ┆ 2         ┆ have     │
# │ hit-55    ┆ 600       ┆           ┆           ┆   ┆ 71", "IPR ┆ 13", "IPR ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002213"…  ┆ 035595"…  ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O75310    ┆ … ┆ ["IPR0502 ┆ ["IPR0022 ┆ 2         ┆ have     │
# │ hit-57    ┆ 600       ┆           ┆           ┆   ┆ 71", "IPR ┆ 13", "IPR ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002213"…  ┆ 035595"…  ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ ["IPR0296 ┆ []        ┆ 0         ┆ no       │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆ 73"]      ┆           ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ ["IPR0296 ┆ []        ┆ 0         ┆ no       │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆ 73"]      ┆           ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ ["IPR0297 ┆ []        ┆ 0         ┆ no       │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆ 76"]      ┆           ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (17) Filtering hit for upset plot

# %%
have_domain_info = domain_info.filter(
    (pl.col("InterPro ID intersection tag") == "have common InterPro ID")
)

display(have_domain_info)
# Out:
# shape: (6_095, 48)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ InterPro_ ┆ InterPro  ┆ InterPro  ┆ InterPro │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ human     ┆ ID inters ┆ ID inters ┆ ID inter │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ection    ┆ ection …  ┆ section  │
# │           ┆           ┆ str       ┆ str       ┆   ┆ list[str] ┆ ---       ┆ ---       ┆ …        │
# │           ┆           ┆           ┆           ┆   ┆           ┆ list[str] ┆ u32       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ … ┆ ["IPR0502 ┆ ["IPR0022 ┆ 2         ┆ have     │
# │ hit-4     ┆ 600       ┆           ┆ 0         ┆   ┆ 71", "IPR ┆ 13", "IPR ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002213"…  ┆ 035595"…  ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O60656    ┆ … ┆ ["IPR0502 ┆ ["IPR0022 ┆ 2         ┆ have     │
# │ hit-55    ┆ 600       ┆           ┆           ┆   ┆ 71", "IPR ┆ 13", "IPR ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002213"…  ┆ 035595"…  ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O75310    ┆ … ┆ ["IPR0502 ┆ ["IPR0022 ┆ 2         ┆ have     │
# │ hit-57    ┆ 600       ┆           ┆           ┆   ┆ 71", "IPR ┆ 13", "IPR ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002213"…  ┆ 035595"…  ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0555 ┆ Q2QNS7    ┆ I3L2M9    ┆ … ┆ ["IPR0233 ┆ ["IPR0233 ┆ 1         ┆ have     │
# │ hit-13422 ┆ 500       ┆           ┆           ┆   ┆ 93", "IPR ┆ 93"]      ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 002913"…  ┆           ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os12g0555 ┆ Q2QNS7    ┆ Q9UKL6    ┆ … ┆ ["IPR0419 ┆ ["IPR0233 ┆ 1         ┆ have     │
# │ hit-13458 ┆ 500       ┆           ┆           ┆   ┆ 50", "IPR ┆ 93"]      ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 023393"…  ┆           ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# │ foldseek- ┆ Os12g0555 ┆ Q2QNS7    ┆ Q9UKL6    ┆ … ┆ ["IPR0419 ┆ ["IPR0233 ┆ 1         ┆ have     │
# │ hit-13458 ┆ 500       ┆           ┆           ┆   ┆ 50", "IPR ┆ 93"]      ┆           ┆ common   │
# │           ┆           ┆           ┆           ┆   ┆ 023393"…  ┆           ┆           ┆ InterPro │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ID       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
no_domain_info = domain_info.filter(
    ((pl.col("InterPro ID intersection tag") == "missing InterPro entry in rice or human") |
    (pl.col("InterPro ID intersection tag") == "no common InterPro ID")) &
    (~pl.col("From").is_in(have_domain_info.select("From").to_series()))
).sort(
    by=["lddt"],
    descending=[True]
)

print(no_domain_info.select("From").n_unique())
print(no_domain_info.select("From").unique().to_series().to_list())
# display(no_domain_info)
# Out:
# 21
# ['Os04g0468600', 'Os11g0649600', 'Os04g0400000', 'Os07g0251200', 'Os11g0154900', 'Os05g0551000', 'Os01g0248300', 'Os01g0944700', 'Os01g0940700', 'Os11g0649700', 'Os01g0795200', 'Os07g0524200', 'Os05g0367900', 'Os02g0649900', 'Os12g0610800', 'Os02g0650300', 'Os04g0340300', 'Os06g0278000', 'Os01g0689451', 'Os04g0587500', 'Os03g0431800']

# %%
domain_info_viz = domain_info.select(
    "From",
    "UniProt Accession",
    "foldseek hit",
    "qcov",
    "tcov",
    "rmsd",
    "lddt",
    "Identity_percent_needle",
    "Identity_percent_water",
    "Similarity_percent_needle",
    "Similarity_percent_water",
    "InterPro ID intersection tag"
).unique().sort(
    by=["From"],
    descending=[False]
)

g = sns.JointGrid(
    data=domain_info_viz,
    x="Similarity_percent_needle",
    y="lddt",
    hue="InterPro ID intersection tag",
    height=11,
    dropna=False,
    ratio=4,
    palette="viridis",
    marginal_ticks=True
)
g.ax_joint.set_xlim(-0.5,100)
g.ax_joint.set_ylim(0,1)
g.ax_joint.set_xlabel("Global alignment similarity (%)", fontsize=14)
g.ax_joint.set_ylabel("Average lDDT", fontsize=14)

# g.refline(x=25, color="black", linestyle=":")
# g.refline(x=50, color="black", linestyle=":")
# g.refline(x=75, color="black", linestyle=":")
# g.refline(y=0.5, color="black", linestyle=":")
g.refline(x=third_quartile, color="black", linestyle=":")
g.refline(y=median_y, color="black", linestyle=":")
g.plot(sns.scatterplot, sns.histplot)
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, title='InterPro ID', fontsize=15, title_fontsize=17, markerscale=3)

display(domain_info_viz)
plt.show()
# Out:
# shape: (3_721, 12)
# ┌────────────┬────────────┬────────────┬───────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ From       ┆ UniProt    ┆ foldseek   ┆ qcov  ┆ … ┆ Identity_ ┆ Similarit ┆ Similarit ┆ InterPro  │
# │ ---        ┆ Accession  ┆ hit        ┆ ---   ┆   ┆ percent_w ┆ y_percent ┆ y_percent ┆ ID inters │
# │ str        ┆ ---        ┆ ---        ┆ f64   ┆   ┆ ater      ┆ _needle   ┆ _water    ┆ ection …  │
# │            ┆ str        ┆ str        ┆       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆            ┆       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ B7FAP2     ┆ P16662     ┆ 0.984 ┆ … ┆ 26.9      ┆ 23.3      ┆ 42.0      ┆ have      │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ common    │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ InterPro  │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ ID        │
# │ Os01g01796 ┆ B7FAP2     ┆ P0DTE4     ┆ 0.984 ┆ … ┆ 36.2      ┆ 24.5      ┆ 50.0      ┆ have      │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ common    │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ InterPro  │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ ID        │
# │ Os01g01796 ┆ Q0JQ63     ┆ P19224     ┆ 0.982 ┆ … ┆ 22.1      ┆ 27.1      ┆ 37.9      ┆ have      │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ common    │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ InterPro  │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ ID        │
# │ …          ┆ …          ┆ …          ┆ …     ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Os12g06108 ┆ Q0ILZ7     ┆ A6NGA9     ┆ 0.985 ┆ … ┆ 33.3      ┆ 19.3      ┆ 57.1      ┆ no common │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ InterPro  │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ ID        │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ 0.821 ┆ … ┆ 31.0      ┆ 17.5      ┆ 55.2      ┆ no common │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ InterPro  │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ ID        │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ 0.867 ┆ … ┆ 23.6      ┆ 25.4      ┆ 33.5      ┆ no common │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ InterPro  │
# │            ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆ ID        │
# └────────────┴────────────┴────────────┴───────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
g = sns.JointGrid(
    data=domain_info_viz,
    x="Similarity_percent_needle",
    y="lddt",
    hue="InterPro ID intersection tag",
    height=11,
    dropna=False,
    ratio=4,
    palette="viridis",
    marginal_ticks=True
)
g.ax_joint.set_xlim(-0.5,100.5)
g.ax_joint.set_ylim(0,1)
g.ax_joint.set_xlabel("Global alignment similarity (%)", fontsize=14)
g.ax_joint.set_ylabel("Average lDDT", fontsize=14)

# Fill the area on the joint plot axes before plotting the data points.
# This ensures the shaded area appears in the background.
# Use g.ax_joint.fill_betweenx to target the correct axes.
g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=-0.5,
    x2=third_quartile,
    color="red",
    alpha=0.1
)

# Plot the scatterplot and histograms over the shaded area.
g.plot(sns.scatterplot, sns.histplot)

# Add reference lines over the plot.
g.refline(x=third_quartile, color="black", linestyle=":")
g.refline(y=median_y, color="black", linestyle=":")

handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, title='InterPro ID', fontsize=15, title_fontsize=17, markerscale=3)

g.savefig(
    f"../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_scatterplot_with_domain_info_{VERSION}.png",
    dpi=500
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (18) Custom Analysis: Ensembl pan-homology information

# %%
ensembl_pan_homology = pl.read_csv(
    pan_homology_tsv_path,
    separator='\t'
).rename(
    {
        "target_id": "ensembl_gene_id",
        "target_protein_id": "ensembl_protein_id"
    }
).select(
    "From",
    "method_link_type",
    "type",
    "ensembl_gene_id",
    "ensembl_protein_id"
)

print(ensembl_pan_homology.group_by(["From"], maintain_order=True).n_unique())
display(ensembl_pan_homology)
# Out:
# shape: (99, 5)
# ┌──────────────┬──────────────────┬──────┬─────────────────┬────────────────────┐
# │ From         ┆ method_link_type ┆ type ┆ ensembl_gene_id ┆ ensembl_protein_id │
# │ ---          ┆ ---              ┆ ---  ┆ ---             ┆ ---                │
# │ str          ┆ u32              ┆ u32  ┆ u32             ┆ u32                │
# ╞══════════════╪══════════════════╪══════╪═════════════════╪════════════════════╡
# │ Os01g0179600 ┆ 1                ┆ 1    ┆ 22              ┆ 22                 │
# │ Os01g0192900 ┆ 1                ┆ 1    ┆ 8               ┆ 8                  │
# │ Os01g0216000 ┆ 1                ┆ 1    ┆ 14              ┆ 14                 │
# │ …            ┆ …                ┆ …    ┆ …               ┆ …                  │
# │ Os12g0508500 ┆ 1                ┆ 1    ┆ 2               ┆ 2                  │
# │ Os12g0512100 ┆ 1                ┆ 1    ┆ 14              ┆ 14                 │
# │ Os12g0601800 ┆ 1                ┆ 1    ┆ 10              ┆ 10                 │
# └──────────────┴──────────────────┴──────┴─────────────────┴────────────────────┘
# shape: (979, 5)
# ┌──────────────┬─────────────────────┬────────────────────┬─────────────────┬────────────────────┐
# │ From         ┆ method_link_type    ┆ type               ┆ ensembl_gene_id ┆ ensembl_protein_id │
# │ ---          ┆ ---                 ┆ ---                ┆ ---             ┆ ---                │
# │ str          ┆ str                 ┆ str                ┆ str             ┆ str                │
# ╞══════════════╪═════════════════════╪════════════════════╪═════════════════╪════════════════════╡
# │ Os01g0179600 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000173610 ┆ ENSP00000286604    │
# │ Os01g0179600 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000135226 ┆ ENSP00000334276    │
# │ Os01g0179600 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000213759 ┆ ENSP00000387683    │
# │ …            ┆ …                   ┆ …                  ┆ …               ┆ …                  │
# │ Os12g0601800 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000182158 ┆ ENSP00000329140    │
# │ Os12g0601800 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000118217 ┆ ENSP00000356919    │
# │ Os12g0601800 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000157613 ┆ ENSP00000481956    │
# └──────────────┴─────────────────────┴────────────────────┴─────────────────┴────────────────────┘

# %%
display(condition3)
# Out:
# shape: (7_065, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ A0A140T9Z ┆ … ┆ 370/775   ┆ 47.7      ┆ 126.0     ┆ 89.5     │
# │ hit-4     ┆ 600       ┆           ┆ 0         ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0179 ┆ Q0JQ63    ┆ B7Z8Q8    ┆ … ┆ 237/580   ┆ 40.9      ┆ 151.0     ┆ 132.5    │
# │ hit-34    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O60656    ┆ … ┆ 269/643   ┆ 41.8      ┆ 145.5     ┆ 121.0    │
# │ hit-55    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
ensembl_pan_homology_info = condition3.join(
    ensembl_pan_homology,
    on=["From", "ensembl_protein_id", "ensembl_gene_id"],
    how="left",
    coalesce=True,
    validate="m:m"
).filter(
    (pl.col("method_link_type").is_not_null())
).sort(
    by=["From", "UniProt Accession", "foldseek hit"],
    descending=[False, False, False]
)

# ensembl_pan_homology_info.write_csv(
#     "../out/rice_up/ensembl_pan_homology_info.tsv",
#     separator="\t"
# )

display(ensembl_pan_homology_info)
# Out:
# shape: (480, 45)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Score_wat ┆ Score_nee ┆ method_li ┆ type     │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ er        ┆ dle       ┆ nk_type   ┆ ---      │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O60656    ┆ … ┆ 145.5     ┆ 121.0     ┆ ENSEMBL_O ┆ ortholog │
# │ hit-55    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆ RTHOLOGUE ┆ _many2ma │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ S         ┆ ny       │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O75310    ┆ … ┆ 135.0     ┆ 82.0      ┆ ENSEMBL_O ┆ ortholog │
# │ hit-57    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆ RTHOLOGUE ┆ _many2ma │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ S         ┆ ny       │
# │ foldseek- ┆ Os01g0179 ┆ B7FAP2    ┆ O75795    ┆ … ┆ 137.5     ┆ 96.5      ┆ ENSEMBL_O ┆ ortholog │
# │ hit-59    ┆ 600       ┆           ┆           ┆   ┆           ┆           ┆ RTHOLOGUE ┆ _many2ma │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ S         ┆ ny       │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0512 ┆ Q0IN24    ┆ Q9NRM0    ┆ … ┆ 346.0     ┆ 341.5     ┆ ENSEMBL_O ┆ ortholog │
# │ hit-13183 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆ RTHOLOGUE ┆ _many2ma │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ S         ┆ ny       │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9NY64    ┆ … ┆ 520.5     ┆ 518.5     ┆ ENSEMBL_O ┆ ortholog │
# │ hit-13187 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆ RTHOLOGUE ┆ _many2ma │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ S         ┆ ny       │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 481.5     ┆ 474.5     ┆ ENSEMBL_O ┆ ortholog │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆ RTHOLOGUE ┆ _many2ma │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ S         ┆ ny       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (19) UpSet plot (hit pair count)

# %%
foldseek_contents = {
    "foldseek unique hit pair": condition3["hit label"].unique().sort().to_list(),
    f"average lDDT≧{median_y} & Similarity≦{third_quartile}%": condition3_filter_4["hit label"].unique().sort().to_list(),
    f"average lDDT≧{median_y} & Similarity>{third_quartile}%": condition3_filter_1["hit label"].unique().sort().to_list(),
    "Common InterPro ID": have_domain_info["hit label"].unique().sort().to_list(),
    "Ensembl pan-homology": ensembl_pan_homology_info["hit label"].unique().sort().to_list()
}

for key, value in foldseek_contents.items():
    print(f"{key}: {len(value)}")

upset_data = from_contents(foldseek_contents)

upset_data.to_csv(
    "../Data/21_foldseek_result_upsetplot/foldseek_result_rice_down_upset_data.tsv",
    sep="\t"
)

display(upset_data)
# Out:
# foldseek unique hit pair: 3721
# average lDDT≧0.549 & Similarity≦33.8%: 157
# average lDDT≧0.549 & Similarity>33.8%: 871
# Common InterPro ID: 3280
# Ensembl pan-homology: 466
# /usr/local/lib/python3.11/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
#                                                                                                                                                               id
# foldseek unique hit pair average lDDT≧0.549 & Similarity≦33.8% average lDDT≧0.549 & Similarity>33.8% Common InterPro ID Ensembl pan-homology
# True                     False                                 True                                  True               False                 foldseek-hit-10022
#                                                                False                                 True               False                 foldseek-hit-10025
#                                                                True                                  True               False                 foldseek-hit-10043
#                                                                False                                 True               False                 foldseek-hit-10045
#                                                                True                                  True               False                 foldseek-hit-10046
# ...                                                                                                                                                          ...
#                                                                                                                         False                  foldseek-hit-9957
#                                                                                                                         False                  foldseek-hit-9959
#                                                                                                                         False                  foldseek-hit-9964
#                                                                False                                 True               False                  foldseek-hit-9983
#                                                                True                                  True               False                  foldseek-hit-9992
#
# [3721 rows x 1 columns]

# %%
plt.rc('ytick', labelsize=9)
upset_plot = UpSet(
    upset_data,
    orientation='horizontal',
    show_counts="{:d}",
    subset_size='count',
    include_empty_subsets = False
)

upset_plot.style_subsets(
    present=[f"average lDDT≧{median_y} & Similarity>{third_quartile}%"], 
    facecolor="tomato"
)

upset_plot.style_subsets(
    present=[f"average lDDT≧{median_y} & Similarity≦{third_quartile}%"], 
    facecolor="navy"
)

upset_plot.style_categories(
    "foldseek unique hit pair",
    shading_edgecolor="lightsteelblue",
)

upset_plot.style_categories(
    f"average lDDT≧{median_y} & Similarity≦{third_quartile}%",
    shading_edgecolor="firebrick",
)


fig = plt.figure(figsize=(14, 8), dpi=500)
upset_plot.plot(fig=fig)

fig.savefig(
    "../Data/22_foldseek_plot_result_image/rice_down/foldseek_result_rice_down_upset_plot.png",
    dpi=500
)

plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %%
# Create legend independently
legend_elements = [
    Patch(facecolor="navy", label=f"average lDDT ≧ {median_y} & Similarity ≦ {third_quartile}% (hit of interest)"),
    Patch(facecolor="tomato", label=f"average lDDT ≧ {median_y} & Similarity > {third_quartile}%")
]

fig_leg = plt.figure(figsize=(1.5, 0.5), dpi=500)
ax_leg = fig_leg.add_subplot(111)
ax_leg.legend(handles=legend_elements, loc='center')
ax_leg.axis('off') 
plt.show()

# %%
print(condition3_filter_1.select("hit label").n_unique())
display(condition3_filter_1)
# Out:
# 871
# shape: (1_701, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ P24298    ┆ … ┆ 167/598   ┆ 27.9      ┆ 208.5     ┆ 179.0    │
# │ hit-243   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ P24298    ┆ … ┆ 167/598   ┆ 27.9      ┆ 208.5     ┆ 179.0    │
# │ hit-243   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0192 ┆ A0A0P0UZP ┆ Q4AC99    ┆ … ┆ 183/642   ┆ 28.5      ┆ 528.5     ┆ 522.0    │
# │ hit-254   ┆ 900       ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 84/552    ┆ 15.2      ┆ 481.5     ┆ 474.5    │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 84/552    ┆ 15.2      ┆ 481.5     ┆ 474.5    │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0512 ┆ Q2QPZ5    ┆ Q9UGQ3    ┆ … ┆ 84/552    ┆ 15.2      ┆ 481.5     ┆ 474.5    │
# │ hit-13189 ┆ 100       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
print(condition3_filter_4.select("hit label").n_unique())

display(condition3_filter_4)
# Out:
# 157
# shape: (298, 43)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ hit label ┆ From      ┆ UniProt   ┆ foldseek  ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ ---       ┆ ---       ┆ Accession ┆ hit       ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ foldseek- ┆ Os01g0279 ┆ Q8H6D6    ┆ O15403    ┆ … ┆ 540/780   ┆ 69.2      ┆ 98.0      ┆ 70.5     │
# │ hit-561   ┆ 400       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0279 ┆ Q8H6D6    ┆ O15403    ┆ … ┆ 540/780   ┆ 69.2      ┆ 98.0      ┆ 70.5     │
# │ hit-561   ┆ 400       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os01g0279 ┆ Q8H6D6    ┆ O76082    ┆ … ┆ 320/687   ┆ 46.6      ┆ 125.5     ┆ 103.5    │
# │ hit-572   ┆ 400       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q6ZVK1    ┆ … ┆ 188/308   ┆ 61.0      ┆ 34.5      ┆ 21.5     │
# │ hit-13466 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ foldseek- ┆ Os12g0610 ┆ Q0ILZ7    ┆ Q7Z7N9    ┆ … ┆ 122/268   ┆ 45.5      ┆ 52.5      ┆ 35.5     │
# │ hit-13467 ┆ 800       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (20) Genes of interest

# %%
hnscore_info = pl.read_csv(
    "../Data/07_extract_gene/HN5_genelist_rice_2505/HN5_genes_down_rice.tsv",
    separator="\t"
).select(
    "From",
    "HN5"
)

condition3_filter_4_hnscore = hnscore_info.join(
    condition3_filter_4,
    on="From",
    how="inner",
    coalesce=True,
    validate="m:m"
).sort(
    by=["HN5"],
    descending=[True]
)

condition3_filter_4_hnscore.write_csv(
    "../Data/21_foldseek_result_validate_rice_down/rice_down/rice_down_condition3_filter_4_hnscore.tsv",
    separator="\t"
)

display(condition3_filter_4_hnscore)
# Out:
# shape: (298, 44)
# ┌────────────┬──────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ From       ┆ HN5  ┆ hit label  ┆ UniProt    ┆ … ┆ Gaps_needl ┆ Gaps_perc ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ ---  ┆ ---        ┆ Accession  ┆   ┆ e          ┆ ent_needl ┆ er        ┆ dle       │
# │ str        ┆ i64  ┆ str        ┆ ---        ┆   ┆ ---        ┆ e         ┆ ---       ┆ ---       │
# │            ┆      ┆            ┆ str        ┆   ┆ str        ┆ ---       ┆ f64       ┆ f64       │
# │            ┆      ┆            ┆            ┆   ┆            ┆ f64       ┆           ┆           │
# ╞════════════╪══════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ Os09g05542 ┆ -40  ┆ foldseek-h ┆ A0A0P0XRD9 ┆ … ┆ 107/270    ┆ 39.6      ┆ 169.5     ┆ 142.0     │
# │ 00         ┆      ┆ it-10457   ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Os09g05542 ┆ -40  ┆ foldseek-h ┆ A0A0P0XRD9 ┆ … ┆ 108/271    ┆ 39.9      ┆ 169.5     ┆ 142.0     │
# │ 00         ┆      ┆ it-10459   ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Os09g05542 ┆ -40  ┆ foldseek-h ┆ A0A0P0XRD9 ┆ … ┆ 118/294    ┆ 40.1      ┆ 153.0     ┆ 145.0     │
# │ 00         ┆      ┆ it-10461   ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …    ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ Os04g05786 ┆ -147 ┆ foldseek-h ┆ A0A0P0WE87 ┆ … ┆ 418/816    ┆ 51.2      ┆ 288.5     ┆ 265.5     │
# │ 00         ┆      ┆ it-5877    ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Os04g05786 ┆ -147 ┆ foldseek-h ┆ A0A0P0WE87 ┆ … ┆ 418/816    ┆ 51.2      ┆ 288.5     ┆ 265.5     │
# │ 00         ┆      ┆ it-5877    ┆            ┆   ┆            ┆           ┆           ┆           │
# │ Os04g05786 ┆ -147 ┆ foldseek-h ┆ A0A0P0WE87 ┆ … ┆ 245/631    ┆ 38.8      ┆ 263.0     ┆ 230.5     │
# │ 00         ┆      ┆ it-5878    ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴──────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
