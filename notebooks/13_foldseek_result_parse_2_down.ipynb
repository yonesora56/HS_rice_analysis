# %% [markdown]
# ## Rice Downregulated Gene Group (3Di + AA Goto-Smith-Waterman alignment method result)
#
# - Analysis using protein sequences used for structure prediction in the AlphaFold Structure database
# - [alphafold/sequences.fasta](https://ftp.ebi.ac.uk/pub/databases/alphafold/sequences.fasta)
#
# &nbsp;
#
# ### Note: 20250809
#
# - Figure font size changed to 18
# - Add HN-score information

# %%
import re
import datetime
import pathlib
import polars as pl # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
from matplotlib.patches import Patch
import seaborn as sns # type: ignore
from upsetplot import UpSet, from_contents # type: ignore

# %%
pl.Config.set_fmt_str_lengths(25)
pl.Config.set_tbl_rows(6)

VERSION = datetime.datetime.now().strftime("%y%m%d")
print(f"Execute Date: {VERSION}")

# create directory
pathlib.Path(f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}").mkdir(parents=True, exist_ok=True)
pathlib.Path(f"../Data/20_foldseek_result_validate_rice_down/rice_down/{VERSION}").mkdir(parents=True, exist_ok=True)
# Out:
# Execute Date: 250831

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (1) Parameters for papermill

# %%
foldseek_result_tsv = pathlib.Path("../Data/14_foldseek_result/foldseek_output_uniprot_rice_down_9606_modified.tsv") # please use the result of 12_foldseek_result_parse_1_down.ipynb

rice_uniprot_idmapping_tsv = pathlib.Path("../Data/12_rice_uniprot_idmapping/rice_down_idmapping_all.tsv") # Gene -> UniProt ID correspondence

water_result_dir_path = "../Data/16_retrieve_sequence_rice_down/rice_down/rice_down_rice_human_water" # pairwise alignment result using water
needle_result_dir_path = "../Data/16_retrieve_sequence_rice_down/rice_down/rice_down_rice_human_needle" # pairwise alignment result using needle

gene_list_tsv_path = "../Data/07_extract_gene/HN5_genelist_rice_2505/HN5_genes_down_rice.tsv"

togoid_convert_tsv_path = "../Data/17_togoid_convert/foldseek_hit_rice_down_human_convert_20250809.tsv"

query_idmapping_tsv_path = "../Data/18_foldseek_hit_uniprot_idmapping/20250809/foldseek_result_rice_down_rice_idmapping_250809.tsv" # InterPro domain information retrieval result
target_idmapping_tsv_path = "../Data/18_foldseek_hit_uniprot_idmapping/20250809/foldseek_result_rice_down_human_idmapping_250809.tsv" # InterPro domain information retrieval result

pan_homology_tsv_path = "../Data/13_rice_pan_homology/rice_down_panhomology_9606_concat.tsv" # Pan-homology information from Ensembl

# %%
foldseek_result = pl.read_csv(
    foldseek_result_tsv,
    separator='\t'
).drop(
    "taxlineage",
    "qaln",
    "taln",
    "lddtfull"
).sort(
    by=["From", "foldseek hit", "UniProt Accession"], # sort by From, foldseek hit, UniProt Accession, qcov, lddt
    descending=[False, False, False]
).with_columns( # add foldseek hit ID for upset plot
    pl.struct(
        [
            "From",
            "foldseek hit",
            "UniProt Accession"
        ]
    ).rank("dense").alias("hit ID")
).with_columns( # assign label for upset plot
    (pl.lit("foldseek-hit-") + pl.col("hit ID").cast(pl.Utf8)).alias("hit label")
).drop(
    "hit ID"
)

display(foldseek_result)
# Out:
# shape: (13_467, 28)
# ┌──────────────┬─────┬──────────────┬──────────────┬───┬───────┬─────────┬──────────┬──────────────┐
# │ From         ┆ HN5 ┆ UniProt      ┆ foldseek hit ┆ … ┆ taxid ┆ taxname ┆ mismatch ┆ hit label    │
# │ ---          ┆ --- ┆ Accession    ┆ ---          ┆   ┆ ---   ┆ ---     ┆ ---      ┆ ---          │
# │ str          ┆ i64 ┆ ---          ┆ str          ┆   ┆ i64   ┆ str     ┆ i64      ┆ str          │
# │              ┆     ┆ str          ┆              ┆   ┆       ┆         ┆          ┆              │
# ╞══════════════╪═════╪══════════════╪══════════════╪═══╪═══════╪═════════╪══════════╪══════════════╡
# │ Os01g0137950 ┆ -69 ┆ A0A0P0UXR3   ┆ K7EP59       ┆ … ┆ 9606  ┆ Homo    ┆ 134      ┆ foldseek-hit │
# │              ┆     ┆              ┆              ┆   ┆       ┆ sapiens ┆          ┆ -1           │
# │ Os01g0179600 ┆ -67 ┆ B7FAP2       ┆ A0A0G2JMZ5   ┆ … ┆ 9606  ┆ Homo    ┆ 144      ┆ foldseek-hit │
# │              ┆     ┆              ┆              ┆   ┆       ┆ sapiens ┆          ┆ -2           │
# │ Os01g0179600 ┆ -67 ┆ Q0JQ63       ┆ A0A0G2JMZ5   ┆ … ┆ 9606  ┆ Homo    ┆ 141      ┆ foldseek-hit │
# │              ┆     ┆              ┆              ┆   ┆       ┆ sapiens ┆          ┆ -3           │
# │ …            ┆ …   ┆ …            ┆ …            ┆ … ┆ …     ┆ …       ┆ …        ┆ …            │
# │ Os12g0610800 ┆ -42 ┆ Q0ILZ7       ┆ O43761       ┆ … ┆ 9606  ┆ Homo    ┆ 126      ┆ foldseek-hit │
# │              ┆     ┆              ┆              ┆   ┆       ┆ sapiens ┆          ┆ -13465       │
# │ Os12g0610800 ┆ -42 ┆ Q0ILZ7       ┆ Q6ZVK1       ┆ … ┆ 9606  ┆ Homo    ┆ 133      ┆ foldseek-hit │
# │              ┆     ┆              ┆              ┆   ┆       ┆ sapiens ┆          ┆ -13466       │
# │ Os12g0610800 ┆ -42 ┆ Q0ILZ7       ┆ Q7Z7N9       ┆ … ┆ 9606  ┆ Homo    ┆ 130      ┆ foldseek-hit │
# │              ┆     ┆              ┆              ┆   ┆       ┆ sapiens ┆          ┆ -13467       │
# └──────────────┴─────┴──────────────┴──────────────┴───┴───────┴─────────┴──────────┴──────────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (2) Structural alignment identical match vs Average lDDT

# %%
foldseek_filter_viz = foldseek_result.to_pandas()
sns.jointplot(
    data=foldseek_filter_viz,
    x="pident", # structural alignment identical match from foldseek result
    y="lddt",
    color="midnightblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(0,100.5)
plt.ylim(0,1)
plt.xlabel("Structural alignment identical match (%)", fontsize=18)
plt.ylabel("Average lDDT", fontsize=18) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=20, color="black", linestyle=":")
plt.axvline(x=40, color="black", linestyle=":")
plt.axvline(x=60, color="black", linestyle=":")
plt.axvline(x=80, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(8, 8), dpi=400)
plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_pident_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)
plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (3) Parse pairwise alignment result

# %%
def parse_needle_water_result(file_path: str):
    with open(file_path, "r", encoding="utf-8") as file:
        data = file.readlines()
        
    result = {
        "UniProt Accession": None,
        "foldseek hit": None,
        "Length": None,
        "Identity": None,
        "Identity_percent": None,
        "Similarity": None,
        "Similarity_percent": None,
        "Gaps": None,
        "Gaps_percent": None,
        "Score": None
    }
    
    for line in data:
        if line.startswith('# 1:'):
            result['UniProt Accession'] = line.split(':')[1].strip()
        elif line.startswith('# 2:'):
            result['foldseek hit'] = line.split(':')[1].strip()
        elif line.startswith('# Length:'):
            result['Length'] = int(line.split()[2])
        elif line.startswith('# Identity:'):
            result['Identity'] = line.split()[2]
            result['Identity_percent'] = float(re.search(r'\((.*?)%\)', line).group(1))
        elif line.startswith('# Similarity:'):
            result['Similarity'] = line.split()[2]
            result['Similarity_percent'] = float(re.search(r'\((.*?)%\)', line).group(1))
        elif line.startswith('# Gaps:'):
            result['Gaps'] = line.split()[2]
            result['Gaps_percent'] = float(re.search(r'\((.*?)%\)', line).group(1))
        elif line.startswith('# Score:'):
            result['Score'] = float(line.split()[2])
            
    return result

# %%
water_result_dir = pathlib.Path(water_result_dir_path)
needle_result_dir = pathlib.Path(needle_result_dir_path)

# Initialize empty lists to store DataFrames
water_dfs = []
needle_dfs = []

# Collect all water results
for result_file in water_result_dir.glob("*_align.water"):
    parsed_data = parse_needle_water_result(result_file)
    water_dfs.append(pl.DataFrame([parsed_data]))

# Collect all needle results    
for result_file in needle_result_dir.glob("*_align.needle"):
    parsed_data = parse_needle_water_result(result_file)
    needle_dfs.append(pl.DataFrame([parsed_data]))

# Combine all results and sort only if there are results
water_result = (pl.concat(water_dfs, how='vertical')
                .sort(["UniProt Accession", "foldseek hit"]) 
                if water_dfs else pl.DataFrame()).with_columns(
                    pl.col("UniProt Accession").str.extract(r"AF-(.*?)-F1", 1).alias("UniProt Accession"), # add removing AF- prefix
                    pl.col("foldseek hit").str.extract(r"AF-(.*?)-F1", 1).alias("foldseek hit") # add removing AF- prefix
                )

needle_result = (pl.concat(needle_dfs, how='vertical')
                 .sort(["UniProt Accession", "foldseek hit"])
                 if needle_dfs else pl.DataFrame()).with_columns(
                    pl.col("UniProt Accession").str.extract(r"AF-(.*?)-F1", 1).alias("UniProt Accession"), # add removing AF- prefix
                    pl.col("foldseek hit").str.extract(r"AF-(.*?)-F1", 1).alias("foldseek hit") # add removing AF- prefix
                )

display(water_result)
display(needle_result)
# Out:
# shape: (13_467, 10)
# ┌──────────────┬──────────────┬────────┬──────────┬───┬─────────────┬────────┬─────────────┬───────┐
# │ UniProt      ┆ foldseek hit ┆ Length ┆ Identity ┆ … ┆ Similarity_ ┆ Gaps   ┆ Gaps_percen ┆ Score │
# │ Accession    ┆ ---          ┆ ---    ┆ ---      ┆   ┆ percent     ┆ ---    ┆ t           ┆ ---   │
# │ ---          ┆ str          ┆ i64    ┆ str      ┆   ┆ ---         ┆ str    ┆ ---         ┆ f64   │
# │ str          ┆              ┆        ┆          ┆   ┆ f64         ┆        ┆ f64         ┆       │
# ╞══════════════╪══════════════╪════════╪══════════╪═══╪═════════════╪════════╪═════════════╪═══════╡
# │ A0A0N7KD90   ┆ A0A024R5D8   ┆ 477    ┆ 132/477  ┆ … ┆ 44.7        ┆ 67/477 ┆ 14.0        ┆ 382.0 │
# │ A0A0N7KD90   ┆ A0A024R5K0   ┆ 459    ┆ 130/459  ┆ … ┆ 44.9        ┆ 68/459 ┆ 14.8        ┆ 385.0 │
# │ A0A0N7KD90   ┆ A0A024R6G4   ┆ 502    ┆ 153/502  ┆ … ┆ 49.0        ┆ 38/502 ┆ 7.6         ┆ 545.0 │
# │ …            ┆ …            ┆ …      ┆ …        ┆ … ┆ …           ┆ …      ┆ …           ┆ …     │
# │ Q9XHX6       ┆ Q0P5T2       ┆ 104    ┆ 22/104   ┆ … ┆ 31.7        ┆ 41/104 ┆ 39.4        ┆ 28.5  │
# │ V9G2Z0       ┆ G3FDP4       ┆ 227    ┆ 99/227   ┆ … ┆ 57.3        ┆ 6/227  ┆ 2.6         ┆ 562.0 │
# │ V9G2Z0       ┆ Q96PM5       ┆ 241    ┆ 107/241  ┆ … ┆ 57.3        ┆ 6/241  ┆ 2.5         ┆ 597.0 │
# └──────────────┴──────────────┴────────┴──────────┴───┴─────────────┴────────┴─────────────┴───────┘
# shape: (13_467, 10)
# ┌─────────────┬─────────────┬────────┬──────────┬───┬─────────────┬───────────┬────────────┬───────┐
# │ UniProt     ┆ foldseek    ┆ Length ┆ Identity ┆ … ┆ Similarity_ ┆ Gaps      ┆ Gaps_perce ┆ Score │
# │ Accession   ┆ hit         ┆ ---    ┆ ---      ┆   ┆ percent     ┆ ---       ┆ nt         ┆ ---   │
# │ ---         ┆ ---         ┆ i64    ┆ str      ┆   ┆ ---         ┆ str       ┆ ---        ┆ f64   │
# │ str         ┆ str         ┆        ┆          ┆   ┆ f64         ┆           ┆ f64        ┆       │
# ╞═════════════╪═════════════╪════════╪══════════╪═══╪═════════════╪═══════════╪════════════╪═══════╡
# │ A0A0N7KD90  ┆ A0A024R5D8  ┆ 559    ┆ 134/559  ┆ … ┆ 38.6        ┆ 143/559   ┆ 25.6       ┆ 374.5 │
# │ A0A0N7KD90  ┆ A0A024R5K0  ┆ 541    ┆ 132/541  ┆ … ┆ 38.6        ┆ 144/541   ┆ 26.6       ┆ 377.5 │
# │ A0A0N7KD90  ┆ A0A024R6G4  ┆ 557    ┆ 155/557  ┆ … ┆ 44.9        ┆ 72/557    ┆ 12.9       ┆ 531.0 │
# │ …           ┆ …           ┆ …      ┆ …        ┆ … ┆ …           ┆ …         ┆ …          ┆ …     │
# │ Q9XHX6      ┆ Q0P5T2      ┆ 653    ┆ 6/653    ┆ … ┆ 1.1         ┆ 633/653   ┆ 96.9       ┆ 10.0  │
# │ V9G2Z0      ┆ G3FDP4      ┆ 1242   ┆ 101/1242 ┆ … ┆ 10.8        ┆ 1013/1242 ┆ 81.6       ┆ 555.0 │
# │ V9G2Z0      ┆ Q96PM5      ┆ 1247   ┆ 112/1247 ┆ … ┆ 11.6        ┆ 997/1247  ┆ 80.0       ┆ 590.0 │
# └─────────────┴─────────────┴────────┴──────────┴───┴─────────────┴───────────┴────────────┴───────┘

# %%
alignment_result = water_result.join(
    needle_result,
    on=["UniProt Accession", "foldseek hit"],
    how="inner",
    coalesce=True,
    suffix="_needle"
).rename(
    {
        "Length": "Length_water",
        "Identity": "Identity_water",
        "Identity_percent": "Identity_percent_water",
        "Similarity": "Similarity_water",
        "Similarity_percent": "Similarity_percent_water",
        "Gaps": "Gaps_water",
        "Gaps_percent": "Gaps_percent_water",
        "Score": "Score_water"
    }
).select(
    [
        "UniProt Accession",
        "foldseek hit",
        "Length_water",
        "Length_needle",
        "Identity_water",
        "Identity_needle",
        "Identity_percent_water",
        "Identity_percent_needle",
        "Similarity_percent_water",
        "Similarity_percent_needle",
        "Gaps_water",
        "Gaps_percent_water",
        "Gaps_needle",
        "Gaps_percent_needle",
        "Score_water",
        "Score_needle"
    ]
).sort(
    by=["UniProt Accession", "foldseek hit"],
    descending=[False, False]
)

display(alignment_result)
# Out:
# shape: (13_467, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ UniProt   ┆ foldseek  ┆ Length_wa ┆ Length_ne ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_ne │
# │ Accession ┆ hit       ┆ ter       ┆ edle      ┆   ┆ le        ┆ ent_needl ┆ er        ┆ edle     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ i64       ┆   ┆ str       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ A0A0N7KD9 ┆ A0A024R5D ┆ 477       ┆ 559       ┆ … ┆ 143/559   ┆ 25.6      ┆ 382.0     ┆ 374.5    │
# │ 0         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ A0A0N7KD9 ┆ A0A024R5K ┆ 459       ┆ 541       ┆ … ┆ 144/541   ┆ 26.6      ┆ 385.0     ┆ 377.5    │
# │ 0         ┆ 0         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ A0A0N7KD9 ┆ A0A024R6G ┆ 502       ┆ 557       ┆ … ┆ 72/557    ┆ 12.9      ┆ 545.0     ┆ 531.0    │
# │ 0         ┆ 4         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Q9XHX6    ┆ Q0P5T2    ┆ 104       ┆ 653       ┆ … ┆ 633/653   ┆ 96.9      ┆ 28.5      ┆ 10.0     │
# │ V9G2Z0    ┆ G3FDP4    ┆ 227       ┆ 1242      ┆ … ┆ 1013/1242 ┆ 81.6      ┆ 562.0     ┆ 555.0    │
# │ V9G2Z0    ┆ Q96PM5    ┆ 241       ┆ 1247      ┆ … ┆ 997/1247  ┆ 80.0      ┆ 597.0     ┆ 590.0    │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (4) Integrate foldseek result and pairwise alignment result
#
# - In this study, **exclude the ones that are null in pairwise alignment result, which means the current UniProt entry is obsolete**

# %%
join_foldseek = foldseek_result.join(
    alignment_result,
    on=["UniProt Accession", "foldseek hit"],
    how="left",
    coalesce=True
).filter( # filter out null alignment result (this means current UniProt entry is obsolete)
    pl.col("Length_water").is_not_null() & 
    pl.col("Length_needle").is_not_null()
).sort(
    by=["From", "foldseek hit", "UniProt Accession"],
    descending=[False, False, False]
)


print(join_foldseek.group_by(["From"], maintain_order=True).n_unique())
display(join_foldseek)
# Out:
# shape: (169, 42)
# ┌────────────┬─────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ From       ┆ HN5 ┆ UniProt    ┆ foldseek   ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ --- ┆ Accession  ┆ hit        ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ u32 ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆     ┆ u32        ┆ u32        ┆   ┆ u32        ┆ u32        ┆ u32       ┆ u32       │
# ╞════════════╪═════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Os01g01379 ┆ 1   ┆ 1          ┆ 1          ┆ … ┆ 1          ┆ 1          ┆ 1         ┆ 1         │
# │ 50         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ 1   ┆ 2          ┆ 64         ┆ … ┆ 34         ┆ 34         ┆ 30        ┆ 41        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01929 ┆ 1   ┆ 3          ┆ 99         ┆ … ┆ 114        ┆ 105        ┆ 80        ┆ 110       │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …   ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Os12g05552 ┆ 1   ┆ 2          ┆ 50         ┆ … ┆ 46         ┆ 43         ┆ 19        ┆ 25        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g05555 ┆ 1   ┆ 2          ┆ 55         ┆ … ┆ 49         ┆ 48         ┆ 17        ┆ 25        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ 1   ┆ 1          ┆ 5          ┆ … ┆ 5          ┆ 5          ┆ 5         ┆ 5         │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴─────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘
# shape: (13_467, 42)
# ┌────────────┬─────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ From       ┆ HN5 ┆ UniProt    ┆ foldseek   ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ --- ┆ Accession  ┆ hit        ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ i64 ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆     ┆ str        ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪═════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Os01g01379 ┆ -69 ┆ A0A0P0UXR3 ┆ K7EP59     ┆ … ┆ 362/499    ┆ 72.5       ┆ 113.0     ┆ 99.5      │
# │ 50         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ A0A0G2JMZ5 ┆ … ┆ 351/585    ┆ 60.0       ┆ 138.5     ┆ 112.0     │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ A0A0G2JMZ5 ┆ … ┆ 351/585    ┆ 60.0       ┆ 138.5     ┆ 112.0     │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …   ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ O43761     ┆ … ┆ 282/353    ┆ 79.9       ┆ 34.0      ┆ 14.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ … ┆ 122/268    ┆ 45.5       ┆ 52.5      ┆ 35.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴─────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (5) Create Scatter Plot for all hits (x-axis: Similarity_percent_needle)

# %%
foldseek_filter_viz2 = join_foldseek.to_pandas()

sns.jointplot(
    data=foldseek_filter_viz2,
    x="Similarity_percent_needle",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Global alignment similarity (%)", fontsize=18)
plt.ylabel("Average lDDT", fontsize=18) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=20, color="black", linestyle=":")
plt.axvline(x=40, color="black", linestyle=":")
plt.axvline(x=60, color="black", linestyle=":")
plt.axvline(x=80, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(5, 5), dpi=300)
plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_allplot_similarity_percent_needle_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)


plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (6) Create Scatter Plot for all hits (x-axis: Similarity_percent_water)

# %%
foldseek_filter_viz2 = join_foldseek.to_pandas()

sns.jointplot(
    data=foldseek_filter_viz2,
    x="Similarity_percent_water",
    y="lddt",
    color="darkorange",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(0,100.5)
plt.ylim(0,1)
plt.xlabel("Local alignment similarity (%)", fontsize=18)
plt.ylabel("Average lDDT", fontsize=18) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=20, color="black", linestyle=":")
plt.axvline(x=40, color="black", linestyle=":")
plt.axvline(x=60, color="black", linestyle=":")
plt.axvline(x=80, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(5, 5), dpi=300)
plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_allplot_similarity_percent_water_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (7) Figure that change y-axis to strucutural alignment target coverage

# %%
sns.jointplot(
    data=foldseek_filter_viz2,
    x="Similarity_percent_needle",
    y="tcov",
    color="olive",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1.02)
plt.xlabel("Global alignment similarity(%)", fontsize=18)
plt.ylabel("Structural alignment target coverage", fontsize=18)
plt.axvline(x=20, color="black", linestyle=":")
plt.axvline(x=40, color="black", linestyle=":")
plt.axvline(x=60, color="black", linestyle=":")
plt.axvline(x=80, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")
# plt.figure(figsize=(10, 10), dpi=500)
plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_allplot_similarity_percent_needle_tcov_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (8) Counting foldseek hits in Gene level

# %%
# Calculate the number of foldseek hits in gene level
all_gene_list = pl.read_csv(
    gene_list_tsv_path,
    separator='\t'
).select(
    "From"
).unique()

hit_count = all_gene_list.join(
    join_foldseek,
    on="From",
    how="left",
    coalesce=True
).group_by("From", maintain_order=True).agg(
    (pl.col("foldseek hit").count().alias("target hit count (gene level vs uniprot accession)")),
    (pl.col("foldseek hit").is_null().all().alias("foldseek no hit"))
).sort(
    ["target hit count (gene level vs uniprot accession)"], descending=True
)

display(hit_count)
    
# hit_count.write_csv(
#     "../out/rice_down/foldseek_rice_down_hit_count.tsv",
#     separator='\t'
# )

no_hit_genes_list = hit_count.filter(
    pl.col("foldseek no hit") == True
)

idmapping_list = pl.read_csv(
    rice_uniprot_idmapping_tsv,
    separator='\t'
)
  
no_hit_idmapping_list = no_hit_genes_list.join(
    idmapping_list,
    on="From",
    how="left"
).sort(
    by=["From"],
    descending=[False]
)

print(no_hit_idmapping_list.group_by(["From"], maintain_order=True).n_unique())
display(no_hit_idmapping_list)
# Out:
# shape: (370, 3)
# ┌──────────────┬────────────────────────────┬─────────────────┐
# │ From         ┆ target hit count (gene le… ┆ foldseek no hit │
# │ ---          ┆ ---                        ┆ ---             │
# │ str          ┆ u32                        ┆ bool            │
# ╞══════════════╪════════════════════════════╪═════════════════╡
# │ Os04g0453200 ┆ 361                        ┆ false           │
# │ Os03g0833100 ┆ 345                        ┆ false           │
# │ Os12g0512100 ┆ 343                        ┆ false           │
# │ …            ┆ …                          ┆ …               │
# │ Os03g0322900 ┆ 0                          ┆ true            │
# │ Os03g0751200 ┆ 0                          ┆ true            │
# │ Os11g0241700 ┆ 0                          ┆ true            │
# └──────────────┴────────────────────────────┴─────────────────┘
# shape: (201, 4)
# ┌──────────────┬────────────────────────────┬─────────────────┬───────────────────┐
# │ From         ┆ target hit count (gene le… ┆ foldseek no hit ┆ UniProt Accession │
# │ ---          ┆ ---                        ┆ ---             ┆ ---               │
# │ str          ┆ u32                        ┆ u32             ┆ u32               │
# ╞══════════════╪════════════════════════════╪═════════════════╪═══════════════════╡
# │ Os01g0105300 ┆ 1                          ┆ 1               ┆ 1                 │
# │ Os01g0136300 ┆ 1                          ┆ 1               ┆ 2                 │
# │ Os01g0216000 ┆ 1                          ┆ 1               ┆ 2                 │
# │ …            ┆ …                          ┆ …               ┆ …                 │
# │ Os12g0601800 ┆ 1                          ┆ 1               ┆ 1                 │
# │ Os12g0630100 ┆ 1                          ┆ 1               ┆ 2                 │
# │ Os12g0630200 ┆ 1                          ┆ 1               ┆ 2                 │
# └──────────────┴────────────────────────────┴─────────────────┴───────────────────┘
# shape: (323, 4)
# ┌──────────────┬────────────────────────────┬─────────────────┬───────────────────┐
# │ From         ┆ target hit count (gene le… ┆ foldseek no hit ┆ UniProt Accession │
# │ ---          ┆ ---                        ┆ ---             ┆ ---               │
# │ str          ┆ u32                        ┆ bool            ┆ str               │
# ╞══════════════╪════════════════════════════╪═════════════════╪═══════════════════╡
# │ Os01g0105300 ┆ 0                          ┆ true            ┆ A0A0P0UWX1        │
# │ Os01g0136300 ┆ 0                          ┆ true            ┆ A0A8J8YJH9        │
# │ Os01g0136300 ┆ 0                          ┆ true            ┆ Q5ZC68            │
# │ …            ┆ …                          ┆ …               ┆ …                 │
# │ Os12g0630100 ┆ 0                          ┆ true            ┆ Q2QLS8            │
# │ Os12g0630200 ┆ 0                          ┆ true            ┆ A3CJP3            │
# │ Os12g0630200 ┆ 0                          ┆ true            ┆ Q2QLS7            │
# └──────────────┴────────────────────────────┴─────────────────┴───────────────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (9) Filtering Condition1
#
# - foldseek query coverage ≧ 0.5, foldseek target coverage ≧ 0.5

# %%
condition1 = join_foldseek.filter(
        (pl.col("qcov") >= 0.5) &
        (pl.col("tcov") >= 0.5)
    ).sort(
        by=["From", "foldseek hit", "UniProt Accession"], # sort by From, foldseek hit, UniProt Accession
        descending=[False, False, False]
    )

condition1_rm = condition1.filter(
        (pl.col("qcov") < 0.5) |
        (pl.col("tcov") < 0.5)
    )

print(condition1.group_by(["From"], maintain_order=True).n_unique())
display(condition1)
# Out:
# shape: (153, 42)
# ┌────────────┬─────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ From       ┆ HN5 ┆ UniProt    ┆ foldseek   ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ --- ┆ Accession  ┆ hit        ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ u32 ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆     ┆ u32        ┆ u32        ┆   ┆ u32        ┆ u32        ┆ u32       ┆ u32       │
# ╞════════════╪═════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ 1   ┆ 2          ┆ 47         ┆ … ┆ 29         ┆ 29         ┆ 24        ┆ 36        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01929 ┆ 1   ┆ 3          ┆ 95         ┆ … ┆ 110        ┆ 101        ┆ 75        ┆ 106       │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g02320 ┆ 1   ┆ 1          ┆ 50         ┆ … ┆ 38         ┆ 36         ┆ 39        ┆ 39        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …   ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Os12g05552 ┆ 1   ┆ 2          ┆ 21         ┆ … ┆ 19         ┆ 19         ┆ 12        ┆ 13        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g05555 ┆ 1   ┆ 2          ┆ 19         ┆ … ┆ 18         ┆ 18         ┆ 11        ┆ 13        │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ 1   ┆ 1          ┆ 5          ┆ … ┆ 5          ┆ 5          ┆ 5         ┆ 5         │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴─────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘
# shape: (9_865, 42)
# ┌────────────┬─────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ From       ┆ HN5 ┆ UniProt    ┆ foldseek   ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ --- ┆ Accession  ┆ hit        ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ i64 ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆     ┆ str        ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪═════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ A0A140T9Z0 ┆ … ┆ 370/775    ┆ 47.7       ┆ 126.0     ┆ 89.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ A0A140T9Z0 ┆ … ┆ 370/775    ┆ 47.7       ┆ 126.0     ┆ 89.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ A0A1W2PQJ2 ┆ … ┆ 296/576    ┆ 51.4       ┆ 48.0      ┆ 3.0       │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …   ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ O43761     ┆ … ┆ 282/353    ┆ 79.9       ┆ 34.0      ┆ 14.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ … ┆ 122/268    ┆ 45.5       ┆ 52.5      ┆ 35.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴─────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (10) Filtering Condition2
#
# - If there are hits with the same target for the same gene-derived UniProt ID, the one with the highest qcov is selected, and if the qcov is the same, the one with the highest lDDT is selected.
# - **Note that in this study, we leave the states with the same foldseek hit even if the rice genes are different.**

# %%
condition2 = condition1.sort(
    by=["qcov", "lddt"],
    descending=[True, True]
).group_by(
    ["From", "foldseek hit"],
    maintain_order=True
).agg(
    pl.all().first()
).sort(
    by=["From", "UniProt Accession", "foldseek hit"],
    descending=[False, False, False]
).select(
    "From",
    "HN5", # add HN-score column
    "UniProt Accession",
    "foldseek hit",
    "evalue",
    "prob",
    "gapopen",
    "pident",
    "fident",
    "nident",
    "qstart",
    "qend",
    "qlen",
    "tstart",
    "tend",
    "tlen",
    "alnlen",
    "qcov",
    "tcov",
    "lddt",
    "qtmscore",
    "ttmscore",
    "alntmscore",
    "rmsd",
    "taxid",
    "taxname",
    "mismatch",
    "hit label",
    "Length_water",
    "Length_needle",
    "Identity_water",
    "Identity_needle",
    "Identity_percent_water",
    "Identity_percent_needle",
    "Similarity_percent_water",
    "Similarity_percent_needle",
    "Gaps_water",
    "Gaps_percent_water",
    "Gaps_needle",
    "Gaps_percent_needle",
    "Score_water",
    "Score_needle"
)

display(condition2)
# Out:
# shape: (7_026, 42)
# ┌────────────┬─────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ From       ┆ HN5 ┆ UniProt    ┆ foldseek   ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ --- ┆ Accession  ┆ hit        ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ i64 ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆     ┆ str        ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪═════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ A0A140T9Z0 ┆ … ┆ 370/775    ┆ 47.7       ┆ 126.0     ┆ 89.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ A0A1W2PQJ2 ┆ … ┆ 296/576    ┆ 51.4       ┆ 48.0      ┆ 3.0       │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ A7E1U4     ┆ … ┆ 670/723    ┆ 92.7       ┆ 35.0      ┆ 15.0      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …   ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ O43761     ┆ … ┆ 282/353    ┆ 79.9       ┆ 34.0      ┆ 14.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ … ┆ 122/268    ┆ 45.5       ┆ 52.5      ┆ 35.5      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴─────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (11) Filtering Condition3
#
# - Select hits that can be converted to Ensembl gene id and HGNC Gene nomenclature with TogoID API
# - https://togoid.dbcls.jp/

# %%
togoid_convert = pl.read_csv(
    togoid_convert_tsv_path,
    separator='\t'
).rename(
    {
        "uniprot_id" : "foldseek hit"
    }
).filter(
    pl.col("ensembl_gene_id").is_not_null() &
    pl.col("hgnc_symbol_id").is_not_null() # add HGNC Gene nomenclature information filtering condition
).sort(
    by=["foldseek hit"],
    descending=[False]
)

display(togoid_convert)
# Out:
# shape: (5_020, 6)
# ┌──────────────┬───────────────────┬──────────────────┬─────────────────┬─────────┬────────────────┐
# │ foldseek hit ┆ ensembl_protein_i ┆ ensembl_transcri ┆ ensembl_gene_id ┆ hgnc_id ┆ hgnc_symbol_id │
# │ ---          ┆ d                 ┆ pt_id            ┆ ---             ┆ ---     ┆ ---            │
# │ str          ┆ ---               ┆ ---              ┆ str             ┆ i64     ┆ str            │
# │              ┆ str               ┆ str              ┆                 ┆         ┆                │
# ╞══════════════╪═══════════════════╪══════════════════╪═════════════════╪═════════╪════════════════╡
# │ A0A024QZP7   ┆ ENSP00000397973   ┆ ENST00000448257  ┆ ENSG00000170312 ┆ 1722    ┆ CDK1           │
# │ A0A024QZW4   ┆ ENSP00000498054   ┆ ENST00000648987  ┆ ENSG00000124786 ┆ 21601   ┆ SLC35B3        │
# │ A0A024QZW4   ┆ ENSP00000518269   ┆ ENST00000710437  ┆ ENSG00000124786 ┆ 21601   ┆ SLC35B3        │
# │ …            ┆ …                 ┆ …                ┆ …               ┆ …       ┆ …              │
# │ X6RIU2       ┆ ENSP00000409912   ┆ ENST00000442513  ┆ ENSG00000163075 ┆ 33720   ┆ CFAP221        │
# │ X6RLA8       ┆ ENSP00000416709   ┆ ENST00000437579  ┆ ENSG00000107954 ┆ 7761    ┆ NEURL1         │
# │ X6RM59       ┆ ENSP00000476480   ┆ ENST00000610140  ┆ ENSG00000122643 ┆ 17820   ┆ NT5C3A         │
# └──────────────┴───────────────────┴──────────────────┴─────────────────┴─────────┴────────────────┘

# %%
condition3 = condition2.join(
    togoid_convert,
    on="foldseek hit",
    how="left",
    coalesce=True
).drop(
    [
        "ensembl_transcript_id",
        "hgnc_id"
    ]
).filter(
    pl.col("ensembl_gene_id").is_not_null() &
    pl.col("hgnc_symbol_id").is_not_null() # add HGNC Gene nomenclature information filtering condition
).select(
    [
        "hit label",
        "From",
        "HN5", # add HN-score column
        "UniProt Accession",
        "foldseek hit",
        "ensembl_protein_id",
        "ensembl_gene_id",
        "hgnc_symbol_id",
        "evalue",
        "prob",
        "gapopen",
        "pident",
        "fident",
        "nident",
        "qstart",
        "qend",
        "qlen",
        "tstart",
        "tend",
        "tlen",
        "alnlen",
        "mismatch",
        "qcov",
        "tcov",
        "rmsd",
        "lddt",
        "qtmscore",
        "ttmscore",
        "alntmscore",
        "taxid",
        "taxname",
        "Length_water",
        "Length_needle",
        "Identity_water",
        "Identity_percent_water",
        "Identity_percent_needle",
        "Similarity_percent_water",
        "Similarity_percent_needle",
        "Gaps_water",
        "Gaps_percent_water",
        "Gaps_needle",
        "Gaps_percent_needle",
        "Score_water",
        "Score_needle"
    ]
).sort(
    by=["From", "foldseek hit", "UniProt Accession"], # sort by From, foldseek hit, UniProt Accession (change order)
    descending=[False, False, False]
)

print(condition3.group_by(["From", "UniProt Accession", "foldseek hit"], maintain_order=True).n_unique())
display(condition3)
# Out:
# shape: (3_708, 44)
# ┌────────────┬────────────┬────────────┬───────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ From       ┆ UniProt    ┆ foldseek   ┆ hit   ┆ … ┆ Gaps_need ┆ Gaps_perc ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ Accession  ┆ hit        ┆ label ┆   ┆ le        ┆ ent_needl ┆ er        ┆ dle       │
# │ str        ┆ ---        ┆ ---        ┆ ---   ┆   ┆ ---       ┆ e         ┆ ---       ┆ ---       │
# │            ┆ str        ┆ str        ┆ u32   ┆   ┆ u32       ┆ ---       ┆ u32       ┆ u32       │
# │            ┆            ┆            ┆       ┆   ┆           ┆ u32       ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ B7FAP2     ┆ A0A140T9Z0 ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os01g01796 ┆ Q0JQ63     ┆ B7Z8Q8     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os01g01796 ┆ B7FAP2     ┆ O60656     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …     ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Os12g06108 ┆ Q0ILZ7     ┆ O43761     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q6ZVK1     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# │ Os12g06108 ┆ Q0ILZ7     ┆ Q7Z7N9     ┆ 1     ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1         │
# │ 00         ┆            ┆            ┆       ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────┴───┴───────────┴───────────┴───────────┴───────────┘
# shape: (7_103, 44)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 370/775    ┆ 47.7       ┆ 126.0     ┆ 89.5      │
# │ it-4       ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ … ┆ 237/580    ┆ 40.9       ┆ 151.0     ┆ 132.5     │
# │ it-34      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 269/643    ┆ 41.8       ┆ 145.5     ┆ 121.0     │
# │ it-55      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 122/268    ┆ 45.5       ┆ 52.5      ┆ 35.5      │
# │ it-13467   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
hit_count_condition3 = condition3.group_by(
    ["From"],
    maintain_order=True
).agg(
    (pl.col("foldseek hit").count().alias("hit count (gene level)"))
).sort(
    by=["hit count (gene level)"],
    descending=True
)

display(hit_count_condition3)
# Out:
# shape: (147, 2)
# ┌──────────────┬────────────────────────┐
# │ From         ┆ hit count (gene level) │
# │ ---          ┆ ---                    │
# │ str          ┆ u32                    │
# ╞══════════════╪════════════════════════╡
# │ Os04g0453200 ┆ 248                    │
# │ Os12g0512100 ┆ 215                    │
# │ Os01g0613500 ┆ 211                    │
# │ …            ┆ …                      │
# │ Os06g0278000 ┆ 1                      │
# │ Os11g0154900 ┆ 1                      │
# │ Os11g0649600 ┆ 1                      │
# └──────────────┴────────────────────────┘

# %%
foldseek_filter_viz = condition3.select(
    "hit label",
    "From",
    "HN5", # add HN-score column
    "UniProt Accession",
    "foldseek hit",
    "pident",
    "fident",
    "qcov",
    "tcov",
    "rmsd",
    "lddt",
    "Identity_percent_needle",
    "Identity_percent_water",
    "Similarity_percent_needle",
    "Similarity_percent_water"
).unique(
    subset=["From", "foldseek hit", "UniProt Accession"],
    maintain_order=True
).sort(
    by=["From", "foldseek hit", "UniProt Accession"],
    descending=[False, False, False]
)

display(foldseek_filter_viz)
# Out:
# shape: (3_708, 15)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Identity_p ┆ Identity_p ┆ Similarit ┆ Similarit │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ ercent_nee ┆ ercent_wat ┆ y_percent ┆ y_percent │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ dle        ┆ er         ┆ _needle   ┆ _water    │
# │            ┆            ┆     ┆ str        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆            ┆   ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 15.7       ┆ 23.1       ┆ 25.7      ┆ 33.4      │
# │ it-4       ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ … ┆ 16.2       ┆ 26.8       ┆ 28.8      ┆ 40.8      │
# │ it-34      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 15.9       ┆ 26.0       ┆ 27.7      ┆ 43.5      │
# │ it-55      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 5.4        ┆ 29.5       ┆ 8.2       ┆ 41.0      │
# │ it-13465   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 10.4       ┆ 31.0       ┆ 17.5      ┆ 55.2      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 17.9       ┆ 23.6       ┆ 25.4      ┆ 33.5      │
# │ it-13467   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (12) Calculate median of Similarity_percent_needle and lddt

# %%
median_x = foldseek_filter_viz.select(
    pl.col("Similarity_percent_needle").median().alias("Similarity_percent_needle_median")
).unique().to_series().to_list()[0]

# third quartile of Similarity_percent_needle (x)
third_quartile = foldseek_filter_viz.select(
    pl.col("Similarity_percent_needle").quantile(0.75).alias("third_quartile")
).to_series().to_list()[0]

median_y = foldseek_filter_viz.select(
    pl.col("lddt").median().alias("lddt_median")
).unique().to_series().to_list()[0]

print(median_x, third_quartile, median_y)
# Out:
# 28.4 33.8 0.5483

# %%
foldseek_filter_viz_pd = foldseek_filter_viz.to_pandas()

plt.figure(figsize=(8, 8), dpi=500)

sns.jointplot(
    data=foldseek_filter_viz_pd,
    x="Similarity_percent_needle",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Global alignment similarity (%)", fontsize=18)
plt.ylabel("Average lDDT", fontsize=18) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=20, color="black", linestyle=":")
plt.axvline(x=40, color="black", linestyle=":")
plt.axvline(x=60, color="black", linestyle=":")
plt.axvline(x=80, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")

plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_filtercondtion3_viz_plot_similarity_percent_needle_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %%
sns.jointplot(
    data=foldseek_filter_viz,
    x="Similarity_percent_needle",
    y="lddt",
    color="steelblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.fill_betweenx(
    y=[median_y, 1],
    x1=-0.5,
    x2=third_quartile,
    color="red",
    alpha=0.1
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Global alignment similarity (%)", fontsize=18)
plt.ylabel("Average lDDT", fontsize=18) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axhline(y=median_y, color="black", linestyle=":")
plt.axvline(x=third_quartile, color="black", linestyle=":")
# plt.figure(figsize=(8, 8), dpi=500)

plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_rep_filtercondtion3_viz_plot_similarity_percent_needle_lddt_{VERSION}.png",
    dpi=500
)

plt.show()

# %%
# top hit example
# https://www.uniprot.org/uniprotkb/P62805/entry
foldseek_filter_viz_top = foldseek_filter_viz.filter(
    (pl.col("lddt") >= 0.9) &
    (pl.col("Similarity_percent_needle") > 90)
)

display(foldseek_filter_viz_top)
# Out:
# shape: (1, 15)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Identity_p ┆ Identity_p ┆ Similarit ┆ Similarit │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ ercent_nee ┆ ercent_wat ┆ y_percent ┆ y_percent │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ dle        ┆ er         ┆ _needle   ┆ _water    │
# │            ┆            ┆     ┆ str        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆            ┆   ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os02g06845 ┆ -54 ┆ Q7XUC9     ┆ … ┆ 98.1       ┆ 98.1       ┆ 100.0     ┆ 100.0     │
# │ it-3537    ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (13) Calculate median of Similarity_percent_water and lddt

# %%
median_x_water = foldseek_filter_viz.select(
    pl.col("Similarity_percent_water").median().alias("Similarity_percent_water_median")
).unique().to_series().to_list()[0]

# third quartile of Similarity_percent_water (x)
third_quartile_water = foldseek_filter_viz.select(
    pl.col("Similarity_percent_water").quantile(0.75).alias("third_quartile")
).to_series().to_list()[0]

median_y_water = foldseek_filter_viz.select(
    pl.col("lddt").median().alias("lddt_median")
).unique().to_series().to_list()[0]

print(median_x_water, third_quartile_water, median_y_water)
# Out:
# 38.2 42.9 0.5483

# %%
foldseek_filter_viz_pd = foldseek_filter_viz.to_pandas()

plt.figure(figsize=(8, 8), dpi=500)

sns.jointplot(
    data=foldseek_filter_viz_pd,
    x="Similarity_percent_water",
    y="lddt",
    color="deepskyblue",
    height=11,
    ratio=4,
    marginal_ticks=True
)

plt.xlim(-0.5,100.5)
plt.ylim(0,1)
plt.xlabel("Local alignment similarity (%)", fontsize=18)
plt.ylabel("Average lDDT", fontsize=18) # see foldseek github https://github.com/steineggerlab/foldseek?tab=readme-ov-file#output-search
plt.axvline(x=20, color="black", linestyle=":")
plt.axvline(x=40, color="black", linestyle=":")
plt.axvline(x=60, color="black", linestyle=":")
plt.axvline(x=80, color="black", linestyle=":")
plt.axhline(y=0.5, color="black", linestyle=":")

plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_filtercondtion3_viz_plot_similarity_percent_water_lddt_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (14) Scatter Plot with boxplot

# %%
g = sns.JointGrid(
    data=foldseek_filter_viz,
    x="Similarity_percent_needle",
    y="lddt",
    height=11,
    ratio=4,
    marginal_ticks=True
)

# plot scatter plot
g.plot_joint(sns.scatterplot, color="steelblue")

# change marginal plot to boxplot
g.plot_marginals(sns.boxplot, color="steelblue")

# set plot settings
g.ax_joint.set_xlim(-0.5, 100)
g.ax_joint.set_ylim(0, 1)
g.ax_joint.set_xlabel("Global alignment similarity(%)", fontsize=18)
g.ax_joint.set_ylabel("Average lDDT", fontsize=18)

# fill range based on median
g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=third_quartile,
    x2=100,
    color="blue",
    alpha=0.1
)

g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=median_x,
    x2=third_quartile,
    color="orange",
    alpha=0.2
)

g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=-0.5,
    x2=median_x,
    color="yellow",
    alpha=0.1
)

g.ax_joint.axvline(x=median_x, color="black", linestyle=":")
g.ax_joint.axhline(y=median_y, color="black", linestyle=":")
g.ax_joint.axvline(x=third_quartile, color="black", linestyle=":")

plt.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_filtercondtion3_viz_plot_similarity_percent_needle_lddt_with_boxplot_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (15) Filtering hit

# %%
# Condition1: LDDT >= median_y & Identity > third_quartile
condition3_filter_1 = condition3.filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") > third_quartile)
)

print(condition3_filter_1.select("From").n_unique())
print(condition3_filter_1.select("From").unique().to_series().to_list())
print(condition3_filter_1.select("hit label").n_unique())
print(condition3_filter_1.select("hit label").unique().to_series().to_list())
display(condition3_filter_1)
# Out:
# 73
# ['Os07g0622700', 'Os07g0292100', 'Os10g0530900', 'Os01g0192900', 'Os04g0339800', 'Os09g0528700', 'Os03g0210200', 'Os05g0592300', 'Os06g0560000', 'Os01g0613500', 'Os07g0257200', 'Os10g0144700', 'Os01g0232000', 'Os03g0404800', 'Os01g0591300', 'Os11g0439600', 'Os08g0462900', 'Os08g0455900', 'Os01g0871500', 'Os12g0441600', 'Os01g0871600', 'Os11g0151500', 'Os11g0655900', 'Os10g0531400', 'Os03g0162200', 'Os03g0760200', 'Os06g0210000', 'Os07g0129200', 'Os02g0684500', 'Os02g0306401', 'Os05g0113900', 'Os01g0382000', 'Os12g0194900', 'Os02g0504000', 'Os06g0129900', 'Os11g0286800', 'Os01g0631900', 'Os01g0696800', 'Os01g0382400', 'Os04g0587500', 'Os03g0332100', 
-hit-1584', 'foldseek-hit-1299', 'foldseek-hit-6821', 'foldseek-hit-1362', 'foldseek-hit-3449', 'foldseek-hit-6434', 'foldseek-hit-6627', 'foldseek-hit-12114', 'foldseek-hit-11224', 'foldseek-hit-12204', 'foldseek-hit-2370', 'foldseek-hit-3462', 'foldseek-hit-2375', 'foldseek-hit-10050', 'foldseek-hit-13151', 'foldseek-hit-13190', 'foldseek-hit-11338', 'foldseek-hit-11252', 'foldseek-hit-11591', 'foldseek-hit-3458', 'foldseek-hit-6078', 'foldseek-hit-12761', 'foldseek-hit-13068', 'foldseek-hit-11418', 'foldseek-hit-11166', 'foldseek-hit-12587', 'foldseek-hit-7804', 'foldseek-hit-1189', 'foldseek-hit-1301', 'foldseek-hit-916', 'foldseek-hit-1556', 'foldseek-hit-12155', 'foldseek-hit-6473', 'foldsee ...
# shape: (2_705, 44)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01929 ┆ -40 ┆ Q9FU17     ┆ … ┆ 183/580    ┆ 31.6       ┆ 168.0     ┆ 157.5     │
# │ it-222     ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01929 ┆ -40 ┆ Q9FU17     ┆ … ┆ 127/521    ┆ 24.4       ┆ 204.0     ┆ 198.5     │
# │ it-240     ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01929 ┆ -40 ┆ O24220     ┆ … ┆ 163/560    ┆ 29.1       ┆ 204.0     ┆ 180.0     │
# │ it-244     ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g05121 ┆ -40 ┆ Q0IN24     ┆ … ┆ 237/649    ┆ 36.5       ┆ 247.0     ┆ 236.5     │
# │ it-13195   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g05121 ┆ -40 ┆ Q0IN24     ┆ … ┆ 237/649    ┆ 36.5       ┆ 247.0     ┆ 236.5     │
# │ it-13195   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g05121 ┆ -40 ┆ Q0IN24     ┆ … ┆ 237/649    ┆ 36.5       ┆ 247.0     ┆ 236.5     │
# │ it-13195   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
# Condition3: LDDT >= median_y & Identity <= median_x
condition3_filter_3 = condition3.filter(
    ((pl.col("lddt") >= median_y) &
    (pl.col("Similarity_percent_needle") <= median_x)) &
    (~pl.col("From").is_in(condition3_filter_2.select("From").to_series())) & # Exclude Genes in Condition2 (LDDT >= median_y & Identity > median_x)
    (~pl.col("foldseek hit").is_in(condition3_filter_2.select("foldseek hit").to_series()))
)

print(condition3_filter_3.select("From").n_unique())
print(condition3_filter_3.select("From").unique().to_series().to_list())
print(condition3_filter_3.select("hit label").n_unique())
print(condition3_filter_3.select("hit label").unique().to_series().to_list())
display(condition3_filter_3)
# Out:
# 18
# ['Os07g0179300', 'Os11g0154900', 'Os04g0545600', 'Os01g0655500', 'Os02g0136933', 'Os06g0718400', 'Os12g0555200', 'Os07g0524200', 'Os03g0371000', 'Os03g0617500', 'Os05g0475700', 'Os07g0251200', 'Os04g0381700', 'Os04g0468600', 'Os03g0372600', 'Os12g0610800', 'Os04g0400000', 'Os12g0555000']
# 65
# ['foldseek-hit-5470', 'foldseek-hit-4187', 'foldseek-hit-5482', 'foldseek-hit-7538', 'foldseek-hit-4026', 'foldseek-hit-4023', 'foldseek-hit-2818', 'foldseek-hit-4029', 'foldseek-hit-2891', 'foldseek-hit-13466', 'foldseek-hit-5474', 'foldseek-hit-4016', 'foldseek-hit-5475', 'foldseek-hit-4018', 'foldseek-hit-8190', 'foldseek-hit-5477', 'foldseek-hit-5479', 'foldseek-hit-2853', 'foldseek-hit-5870', 'foldseek-hit-4024', 'foldseek-hit-7699', 'foldseek-hit-5867', 'foldseek-hit-2733', 'foldseek-hit-2732', 'foldseek-hit-5487', 'foldseek-hit-7697', 'foldseek-hit-13314', 'foldseek-hit-13253', 'foldseek-hit-4057', 'foldseek-hit-6361', 'foldseek-hit-5476', 'foldseek-hit-5484', 'foldseek-hit-2850', 'foldseek-hit-13237', 'foldseek-hit-13467', 'foldseek-hit-2728', 'foldseek-hit-5480', 'foldseek-hit-2805', 'foldseek-hit-1712', 'foldseek-hit-4025', 'foldseek-hit-5486', 'foldseek-hit-5857', 'foldseek-hit-7700', 'foldseek-hit-6285', 'foldseek-hit-2854', 'foldseek-hit-5864', 'foldseek-hit-12190', 'foldseek-hit-5471', 'foldseek-hit-4190', 'foldseek-hit-5485', 'foldseek-hit-5855', 'foldseek-hit-4188', 'foldseek-hit-5468', 'foldseek-hit-2822', 'foldseek-hit-5473', 'foldseek-hit-4043', 'foldseek-hit-1693', 'foldseek-hit-2729', 'foldseek-hit-6299', 'foldseek-hit-13330', 'foldseek-hit-2830', 'foldseek-hit-4186', 'foldseek-hit-5488', 'foldseek-hit-2802', 'foldseek-hit-7477']
# shape: (136, 44)
# ┌────────────┬────────────┬──────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5  ┆ UniProt    ┆ … ┆ Gaps_needl ┆ Gaps_perc ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ ---        ┆ ---  ┆ Accession  ┆   ┆ e          ┆ ent_needl ┆ er        ┆ dle       │
# │ str        ┆ str        ┆ i64  ┆ ---        ┆   ┆ ---        ┆ e         ┆ ---       ┆ ---       │
# │            ┆            ┆      ┆ str        ┆   ┆ str        ┆ ---       ┆ f64       ┆ f64       │
# │            ┆            ┆      ┆            ┆   ┆            ┆ f64       ┆           ┆           │
# ╞════════════╪════════════╪══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g06555 ┆ -107 ┆ A0A0P0V637 ┆ … ┆ 781/1050   ┆ 74.4      ┆ 69.0      ┆ 52.0      │
# │ it-1693    ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os01g06555 ┆ -107 ┆ Q5SN79     ┆ … ┆ 685/991    ┆ 69.1      ┆ 78.0      ┆ 54.0      │
# │ it-1712    ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os01g06555 ┆ -107 ┆ Q5SN79     ┆ … ┆ 685/991    ┆ 69.1      ┆ 78.0      ┆ 54.0      │
# │ it-1712    ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …    ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g06108 ┆ -42  ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0      ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42  ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0      ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42  ┆ Q0ILZ7     ┆ … ┆ 122/268    ┆ 45.5      ┆ 52.5      ┆ 35.5      │
# │ it-13467   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴──────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
# Condition4: LDDT >= median_y & Identity <= third_quartile
condition3_filter_4 = condition3.filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") <= third_quartile) &
    (~pl.col("From").is_in(condition3_filter_1.select("From").to_series())) & # Exclude Genes in Filter Condition1 (LDDT >= median_y & Identity > third_quartile)
    (~pl.col("foldseek hit").is_in(condition3_filter_1.select("foldseek hit").to_series())) # 
)

print(condition3_filter_4.select("From").n_unique())
print(condition3_filter_4.select("From").unique().to_series().to_list())
print(condition3_filter_4.select("hit label").n_unique())
print(condition3_filter_4.select("hit label").unique().to_series().to_list())
display(condition3_filter_4)
# Out:
# 34
# ['Os02g0136933', 'Os08g0189300', 'Os08g0547800', 'Os03g0431800', 'Os04g0578600', 'Os01g0279400', 'Os04g0381700', 'Os07g0179300', 'Os04g0468600', 'Os07g0251200', 'Os03g0372600', 'Os03g0651800', 'Os02g0563000', 'Os11g0154900', 'Os02g0584700', 'Os04g0545600', 'Os07g0561800', 'Os12g0610800', 'Os07g0524900', 'Os07g0190000', 'Os03g0667300', 'Os04g0400000', 'Os03g0371000', 'Os07g0524200', 'Os05g0475700', 'Os09g0554200', 'Os12g0555200', 'Os01g0655500', 'Os05g0106200', 'Os06g0718400', 'Os03g0617500', 'Os01g0284500', 'Os04g0179100', 'Os12g0555000']
# 157
foldseek-hit-8338', 'foldseek-hit-9360', 'foldseek-hit-6005', 'foldseek-hit-676', 'foldseek-hit-5474', 'foldseek-hit-9313', 'foldseek-hit-5994', 'foldseek-hit-4187', 'foldseek-hit-2854', 'foldseek-hit-6018', 'foldseek-hit-3265', 'foldseek-hit-674', 'foldseek-hit-710', 'foldseek-hit-8303', 'foldseek-hit-6285', 'foldseek-hit-2830', 'foldseek-hit-8226', 'foldseek-hit-2733', 'foldseek-hit-4519', 'foldseek-hit-10457', 'foldseek-hit-5475', 'foldseek-hit-5485', 'foldseek-hit-635', 'foldseek-hit-3513', 'foldseek-hit-4023', 'foldseek-hit-5988', 'foldseek-hit-8225', 'foldseek-hit-4057', 'foldseek-hit-7697', 'foldseek-hit-8355', 'foldseek-hit-561', 'foldseek-hit-8318', 'foldseek-hit-6030', 'foldseek-hit-10461', 'foldseek-hit-5864', 'foldseek-hit-653', 'foldseek-hit-2853', 'foldseek-hit-3360']
# shape: (298, 44)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g02794 ┆ -57 ┆ Q8H6D6     ┆ … ┆ 540/780    ┆ 69.2       ┆ 98.0      ┆ 70.5      │
# │ it-561     ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g02794 ┆ -57 ┆ Q8H6D6     ┆ … ┆ 540/780    ┆ 69.2       ┆ 98.0      ┆ 70.5      │
# │ it-561     ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g02794 ┆ -57 ┆ Q8H6D6     ┆ … ┆ 320/687    ┆ 46.6       ┆ 125.5     ┆ 103.5     │
# │ it-572     ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 122/268    ┆ 45.5       ┆ 52.5      ┆ 35.5      │
# │ it-13467   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (16) Custom Analysis: Assign Domain Information

# %%
# rice domain information
uniprot_info_rice = pl.read_csv(
    query_idmapping_tsv_path,
    separator='\t'
)

domain_info_rice = uniprot_info_rice.select(
    "From",
    "InterPro"
).rename(
    {
        "From": "UniProt Accession",
        "InterPro": "InterPro_rice"
    }
).with_columns(
    pl.col("InterPro_rice").str.strip_suffix(";")
).with_columns(
    pl.col("InterPro_rice").str.split(";").cast(pl.List(pl.Utf8))
)

# human domain information
uniprot_info_human = pl.read_csv(
    target_idmapping_tsv_path,
    separator='\t'
)

domain_info_human = uniprot_info_human.select(
    "From",
    "InterPro"
).rename(
    {
        "From": "foldseek hit",
        "InterPro": "InterPro_human"
    }
).with_columns(
    pl.col("InterPro_human").str.strip_suffix(";")
).with_columns(
    pl.col("InterPro_human").str.split(";").cast(pl.List(pl.Utf8))
)

display(domain_info_rice)
display(domain_info_human)
# Out:
# shape: (255, 2)
# ┌───────────────────┬────────────────────────────┐
# │ UniProt Accession ┆ InterPro_rice              │
# │ ---               ┆ ---                        │
# │ str               ┆ list[str]                  │
# ╞═══════════════════╪════════════════════════════╡
# │ A3C6R3            ┆ ["IPR010987", "IPR036282"… │
# │ Q2R0L2            ┆ ["IPR011707", "IPR001117"… │
# │ A2ZWV5            ┆ ["IPR001461", "IPR034161"… │
# │ …                 ┆ …                          │
# │ Q7F7C9            ┆ ["IPR032710", "IPR053218"… │
# │ Q6YSF8            ┆ ["IPR018244", "IPR014044"… │
# │ Q5ZBR8            ┆ ["IPR000209", "IPR036852"… │
# └───────────────────┴────────────────────────────┘
# shape: (4_931, 2)
# ┌──────────────┬────────────────────────────┐
# │ foldseek hit ┆ InterPro_human             │
# │ ---          ┆ ---                        │
# │ str          ┆ list[str]                  │
# ╞══════════════╪════════════════════════════╡
# │ A0A7I2V532   ┆ ["IPR038765", "IPR013201"… │
# │ Q08257       ┆ ["IPR013149", "IPR013154"… │
# │ C6ZRJ6       ┆ ["IPR013558", "IPR009071"… │
# │ …            ┆ …                          │
# │ B4DMF0       ┆ ["IPR008928", "IPR012341"… │
# │ Q3KPF3       ┆ ["IPR001128", "IPR017972"… │
# │ Q8WUW2       ┆ ["IPR004552", "IPR002123"… │
# └──────────────┴────────────────────────────┘

# %%
domain_info = condition3.join(
    domain_info_rice,
    on="UniProt Accession",
    how="left",
    coalesce=True,
    validate="m:m"
).join(
    domain_info_human,
    on="foldseek hit",
    how="left",
    coalesce=True,
    validate="m:m"
).with_columns(
    pl.col("InterPro_rice").list.set_intersection("InterPro_human").alias("InterPro ID intersection"),
    pl.col("InterPro_rice").list.set_intersection("InterPro_human").list.len().alias("InterPro ID intersection count")
).sort(
    by=["InterPro ID intersection count"],
    descending=[True]
).with_columns(
    pl.when(
        (pl.col("InterPro_rice").is_null()) | (pl.col("InterPro_human").is_null())
    ).then(
        pl.lit("missing InterPro entry in rice or human")
    ).when(
        pl.col("InterPro ID intersection count") == 0
    ).then(
        pl.lit("no common InterPro ID")
    ).otherwise(
        pl.lit("have common InterPro ID")
    ).alias("InterPro ID intersection tag")
).sort(
    by=["From", "UniProt Accession", "foldseek hit"],
    descending=[False, False, False]
)

display(domain_info)
# Out:
# shape: (7_103, 49)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ InterPro_h ┆ InterPro   ┆ InterPro  ┆ InterPro  │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ uman       ┆ ID interse ┆ ID inters ┆ ID inters │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ction      ┆ ection …  ┆ ection …  │
# │            ┆            ┆     ┆ str        ┆   ┆ list[str]  ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆            ┆   ┆            ┆ list[str]  ┆ u32       ┆ str       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ ["IPR05027 ┆ ["IPR00221 ┆ 2         ┆ have      │
# │ it-4       ┆ 00         ┆     ┆            ┆   ┆ 1", "IPR00 ┆ 3", "IPR03 ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2213"…     ┆ 5595"…     ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ ["IPR05027 ┆ ["IPR00221 ┆ 2         ┆ have      │
# │ it-55      ┆ 00         ┆     ┆            ┆   ┆ 1", "IPR00 ┆ 3", "IPR03 ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2213"…     ┆ 5595"…     ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ ["IPR05027 ┆ ["IPR00221 ┆ 2         ┆ have      │
# │ it-57      ┆ 00         ┆     ┆            ┆   ┆ 1", "IPR00 ┆ 3", "IPR03 ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2213"…     ┆ 5595"…     ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ ["IPR02967 ┆ []         ┆ 0         ┆ no common │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆ 3"]        ┆            ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ ["IPR02967 ┆ []         ┆ 0         ┆ no common │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆ 3"]        ┆            ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ ["IPR02977 ┆ []         ┆ 0         ┆ no common │
# │ it-13467   ┆ 00         ┆     ┆            ┆   ┆ 6"]        ┆            ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (17) Filtering hit for upset plot

# %%
have_domain_info = domain_info.filter(
    (pl.col("InterPro ID intersection tag") == "have common InterPro ID")
)

display(have_domain_info)
# Out:
# shape: (6_144, 49)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ InterPro_h ┆ InterPro   ┆ InterPro  ┆ InterPro  │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ uman       ┆ ID interse ┆ ID inters ┆ ID inters │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ction      ┆ ection …  ┆ ection …  │
# │            ┆            ┆     ┆ str        ┆   ┆ list[str]  ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆            ┆   ┆            ┆ list[str]  ┆ u32       ┆ str       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ ["IPR05027 ┆ ["IPR00221 ┆ 2         ┆ have      │
# │ it-4       ┆ 00         ┆     ┆            ┆   ┆ 1", "IPR00 ┆ 3", "IPR03 ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2213"…     ┆ 5595"…     ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ ["IPR05027 ┆ ["IPR00221 ┆ 2         ┆ have      │
# │ it-55      ┆ 00         ┆     ┆            ┆   ┆ 1", "IPR00 ┆ 3", "IPR03 ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2213"…     ┆ 5595"…     ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ ["IPR05027 ┆ ["IPR00221 ┆ 2         ┆ have      │
# │ it-57      ┆ 00         ┆     ┆            ┆   ┆ 1", "IPR00 ┆ 3", "IPR03 ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2213"…     ┆ 5595"…     ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g05555 ┆ -62 ┆ Q2QNS7     ┆ … ┆ ["IPR02339 ┆ ["IPR02339 ┆ 1         ┆ have      │
# │ it-13422   ┆ 00         ┆     ┆            ┆   ┆ 3", "IPR00 ┆ 3"]        ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 2913"…     ┆            ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os12g05555 ┆ -62 ┆ Q2QNS7     ┆ … ┆ ["IPR04195 ┆ ["IPR02339 ┆ 1         ┆ have      │
# │ it-13458   ┆ 00         ┆     ┆            ┆   ┆ 0", "IPR02 ┆ 3"]        ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 3393"…     ┆            ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ foldseek-h ┆ Os12g05555 ┆ -62 ┆ Q2QNS7     ┆ … ┆ ["IPR04195 ┆ ["IPR02339 ┆ 1         ┆ have      │
# │ it-13458   ┆ 00         ┆     ┆            ┆   ┆ 0", "IPR02 ┆ 3"]        ┆           ┆ common    │
# │            ┆            ┆     ┆            ┆   ┆ 3393"…     ┆            ┆           ┆ InterPro  │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
no_domain_info = domain_info.filter(
    ((pl.col("InterPro ID intersection tag") == "missing InterPro entry in rice or human") |
    (pl.col("InterPro ID intersection tag") == "no common InterPro ID")) &
    (~pl.col("From").is_in(have_domain_info.select("From").to_series()))
).sort(
    by=["lddt"],
    descending=[True]
)

print(no_domain_info.select("From").n_unique())
print(no_domain_info.select("From").unique().to_series().to_list())
# display(no_domain_info)
# Out:
# 21
# ['Os05g0367900', 'Os06g0278000', 'Os04g0400000', 'Os04g0468600', 'Os11g0649600', 'Os07g0251200', 'Os01g0689451', 'Os01g0248300', 'Os12g0610800', 'Os05g0551000', 'Os02g0650300', 'Os11g0649700', 'Os01g0944700', 'Os11g0154900', 'Os04g0340300', 'Os01g0940700', 'Os01g0795200', 'Os02g0649900', 'Os03g0431800', 'Os04g0587500', 'Os07g0524200']

# %%
domain_info_viz = domain_info.select(
    "From",
    "HN5", # add HN-score information
    "UniProt Accession",
    "foldseek hit",
    "qcov",
    "tcov",
    "rmsd",
    "lddt",
    "Identity_percent_needle",
    "Identity_percent_water",
    "Similarity_percent_needle",
    "Similarity_percent_water",
    "InterPro ID intersection tag"
).unique().sort(
    by=["From"],
    descending=[False]
)

g = sns.JointGrid(
    data=domain_info_viz,
    x="Similarity_percent_needle",
    y="lddt",
    hue="InterPro ID intersection tag",
    height=11,
    dropna=False,
    ratio=4,
    palette="viridis",
    marginal_ticks=True
)
g.ax_joint.set_xlim(-0.5,100)
g.ax_joint.set_ylim(0,1)
g.ax_joint.set_xlabel("Global alignment similarity (%)", fontsize=18)
g.ax_joint.set_ylabel("Average lDDT", fontsize=18)

g.refline(x=third_quartile, color="black", linestyle=":")
g.refline(y=median_y, color="black", linestyle=":")
g.plot(sns.scatterplot, sns.histplot)
handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, title='InterPro ID', fontsize=15, title_fontsize=17, markerscale=3)

display(domain_info_viz)
plt.show()
# Out:
# shape: (3_708, 13)
# ┌────────────┬─────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ From       ┆ HN5 ┆ UniProt    ┆ foldseek   ┆ … ┆ Identity_p ┆ Similarity ┆ Similarit ┆ InterPro  │
# │ ---        ┆ --- ┆ Accession  ┆ hit        ┆   ┆ ercent_wat ┆ _percent_n ┆ y_percent ┆ ID inters │
# │ str        ┆ i64 ┆ ---        ┆ ---        ┆   ┆ er         ┆ eedle      ┆ _water    ┆ ection …  │
# │            ┆     ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆     ┆            ┆            ┆   ┆ f64        ┆ f64        ┆ f64       ┆ str       │
# ╞════════════╪═════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ Q3SY77     ┆ … ┆ 25.4       ┆ 26.0       ┆ 42.7      ┆ have      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ common    │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ InterPro  │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ P54855     ┆ … ┆ 25.1       ┆ 27.4       ┆ 42.0      ┆ have      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ common    │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ InterPro  │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ P22309     ┆ … ┆ 24.5       ┆ 27.9       ┆ 41.7      ┆ have      │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ common    │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ InterPro  │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ …          ┆ …   ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ A6NGA9     ┆ … ┆ 33.3       ┆ 19.3       ┆ 57.1      ┆ no common │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ InterPro  │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ O43761     ┆ … ┆ 29.5       ┆ 8.2        ┆ 41.0      ┆ no common │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ InterPro  │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# │ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ O43760     ┆ … ┆ 29.7       ┆ 13.0       ┆ 45.9      ┆ no common │
# │ 00         ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ InterPro  │
# │            ┆     ┆            ┆            ┆   ┆            ┆            ┆           ┆ ID        │
# └────────────┴─────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
g = sns.JointGrid(
    data=domain_info_viz,
    x="Similarity_percent_needle",
    y="lddt",
    hue="InterPro ID intersection tag",
    height=11,
    dropna=False,
    ratio=4,
    palette="viridis",
    marginal_ticks=True
)
g.ax_joint.set_xlim(-0.5,100.5)
g.ax_joint.set_ylim(0,1)
g.ax_joint.set_xlabel("Global alignment similarity (%)", fontsize=18)
g.ax_joint.set_ylabel("Average lDDT", fontsize=18)

# Fill the area on the joint plot axes before plotting the data points.
# This ensures the shaded area appears in the background.
# Use g.ax_joint.fill_betweenx to target the correct axes.
g.ax_joint.fill_betweenx(
    y=[median_y, 1],
    x1=-0.5,
    x2=third_quartile,
    color="red",
    alpha=0.1
)

# Plot the scatterplot and histograms over the shaded area.
g.plot(sns.scatterplot, sns.histplot)

# Add reference lines over the plot.
g.refline(x=third_quartile, color="black", linestyle=":")
g.refline(y=median_y, color="black", linestyle=":")

handles, labels = g.ax_joint.get_legend_handles_labels()
g.ax_joint.legend(handles=handles, labels=labels, title='InterPro ID', fontsize=15, title_fontsize=17, markerscale=3)

g.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_scatterplot_with_domain_info_{VERSION}.png",
    dpi=500
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (18) Custom Analysis: Ensembl pan-homology information

# %%
ensembl_pan_homology = pl.read_csv(
    pan_homology_tsv_path,
    separator='\t'
).rename(
    {
        "target_id": "ensembl_gene_id",
        "target_protein_id": "ensembl_protein_id"
    }
).select(
    "From",
    "method_link_type",
    "type",
    "ensembl_gene_id",
    "ensembl_protein_id"
)

print(ensembl_pan_homology.group_by(["From"], maintain_order=True).n_unique())
display(ensembl_pan_homology)
# Out:
# shape: (99, 5)
# ┌──────────────┬──────────────────┬──────┬─────────────────┬────────────────────┐
# │ From         ┆ method_link_type ┆ type ┆ ensembl_gene_id ┆ ensembl_protein_id │
# │ ---          ┆ ---              ┆ ---  ┆ ---             ┆ ---                │
# │ str          ┆ u32              ┆ u32  ┆ u32             ┆ u32                │
# ╞══════════════╪══════════════════╪══════╪═════════════════╪════════════════════╡
# │ Os01g0179600 ┆ 1                ┆ 1    ┆ 22              ┆ 22                 │
# │ Os01g0192900 ┆ 1                ┆ 1    ┆ 8               ┆ 8                  │
# │ Os01g0216000 ┆ 1                ┆ 1    ┆ 14              ┆ 14                 │
# │ …            ┆ …                ┆ …    ┆ …               ┆ …                  │
# │ Os12g0508500 ┆ 1                ┆ 1    ┆ 2               ┆ 2                  │
# │ Os12g0512100 ┆ 1                ┆ 1    ┆ 14              ┆ 14                 │
# │ Os12g0601800 ┆ 1                ┆ 1    ┆ 10              ┆ 10                 │
# └──────────────┴──────────────────┴──────┴─────────────────┴────────────────────┘
# shape: (979, 5)
# ┌──────────────┬─────────────────────┬────────────────────┬─────────────────┬────────────────────┐
# │ From         ┆ method_link_type    ┆ type               ┆ ensembl_gene_id ┆ ensembl_protein_id │
# │ ---          ┆ ---                 ┆ ---                ┆ ---             ┆ ---                │
# │ str          ┆ str                 ┆ str                ┆ str             ┆ str                │
# ╞══════════════╪═════════════════════╪════════════════════╪═════════════════╪════════════════════╡
# │ Os01g0179600 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000173610 ┆ ENSP00000286604    │
# │ Os01g0179600 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000135226 ┆ ENSP00000334276    │
# │ Os01g0179600 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000213759 ┆ ENSP00000387683    │
# │ …            ┆ …                   ┆ …                  ┆ …               ┆ …                  │
# │ Os12g0601800 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000182158 ┆ ENSP00000329140    │
# │ Os12g0601800 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000118217 ┆ ENSP00000356919    │
# │ Os12g0601800 ┆ ENSEMBL_ORTHOLOGUES ┆ ortholog_many2many ┆ ENSG00000157613 ┆ ENSP00000481956    │
# └──────────────┴─────────────────────┴────────────────────┴─────────────────┴────────────────────┘

# %%
display(condition3)
# Out:
# shape: (7_103, 44)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Gaps_needl ┆ Gaps_perce ┆ Score_wat ┆ Score_nee │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ e          ┆ nt_needle  ┆ er        ┆ dle       │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆     ┆ str        ┆   ┆ str        ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 370/775    ┆ 47.7       ┆ 126.0     ┆ 89.5      │
# │ it-4       ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ Q0JQ63     ┆ … ┆ 237/580    ┆ 40.9       ┆ 151.0     ┆ 132.5     │
# │ it-34      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 269/643    ┆ 41.8       ┆ 145.5     ┆ 121.0     │
# │ it-55      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 188/308    ┆ 61.0       ┆ 34.5      ┆ 21.5      │
# │ it-13466   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# │ foldseek-h ┆ Os12g06108 ┆ -42 ┆ Q0ILZ7     ┆ … ┆ 122/268    ┆ 45.5       ┆ 52.5      ┆ 35.5      │
# │ it-13467   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
ensembl_pan_homology_info = condition3.join(
    ensembl_pan_homology,
    on=["From", "ensembl_protein_id", "ensembl_gene_id"],
    how="left",
    coalesce=True,
    validate="m:m"
).filter(
    (pl.col("method_link_type").is_not_null())
).sort(
    by=["From", "UniProt Accession", "foldseek hit"],
    descending=[False, False, False]
)

# ensembl_pan_homology_info.write_csv(
#     "../out/rice_up/ensembl_pan_homology_info.tsv",
#     separator="\t"
# )

display(ensembl_pan_homology_info)
# Out:
# shape: (483, 46)
# ┌────────────┬────────────┬─────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5 ┆ UniProt    ┆ … ┆ Score_wate ┆ Score_need ┆ method_li ┆ type      │
# │ ---        ┆ ---        ┆ --- ┆ Accession  ┆   ┆ r          ┆ le         ┆ nk_type   ┆ ---       │
# │ str        ┆ str        ┆ i64 ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ str       │
# │            ┆            ┆     ┆ str        ┆   ┆ f64        ┆ f64        ┆ str       ┆           │
# ╞════════════╪════════════╪═════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 145.5      ┆ 121.0      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-55      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆ S         ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 135.0      ┆ 82.0       ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-57      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆ S         ┆           │
# │ foldseek-h ┆ Os01g01796 ┆ -67 ┆ B7FAP2     ┆ … ┆ 137.5      ┆ 96.5       ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-59      ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆ S         ┆           │
# │ …          ┆ …          ┆ …   ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ foldseek-h ┆ Os12g05121 ┆ -40 ┆ Q0IN24     ┆ … ┆ 346.0      ┆ 341.5      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-13183   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆ S         ┆           │
# │ foldseek-h ┆ Os12g05121 ┆ -40 ┆ Q2QPZ5     ┆ … ┆ 520.5      ┆ 518.5      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-13187   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆ S         ┆           │
# │ foldseek-h ┆ Os12g05121 ┆ -40 ┆ Q2QPZ5     ┆ … ┆ 481.5      ┆ 474.5      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-13189   ┆ 00         ┆     ┆            ┆   ┆            ┆            ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆     ┆            ┆   ┆            ┆            ┆ S         ┆           │
# └────────────┴────────────┴─────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (19) UpSet plot (hit pair count)
#
# - LS-HS: Low sequnence similarity but High structural similarity
# - HS-HS: High sequnence similarity but High structural similarity
#
# &nbsp;
#
# ### Note: 2025-08-10
#
# - contents list
#
# ```python
# foldseek_contents = {
#     "foldseek unique hit pair": condition3["hit label"].unique().sort().to_list(),
#     f"Unique LS-HS hit pair": condition3_filter_4["hit label"].unique().sort().to_list(),
#     f"HS-HS hit pair": condition3_filter_1["hit label"].unique().sort().to_list(),
#     "Common InterPro ID": have_domain_info["hit label"].unique().sort().to_list(),
#     "Ensembl pan-homology": ensembl_pan_homology_info["hit label"].unique().sort().to_list()
# }
# ```

# %%
foldseek_contents = {
    "foldseek unique hit pair": condition3["hit label"].unique().sort().to_list(),
    f"Unique LS-HS hit pair": condition3_filter_4["hit label"].unique().sort().to_list(),
    f"HS-HS hit pair": condition3_filter_1["hit label"].unique().sort().to_list(),
    "Common InterPro ID": have_domain_info["hit label"].unique().sort().to_list(),
    "Ensembl pan-homology": ensembl_pan_homology_info["hit label"].unique().sort().to_list()
}

for key, value in foldseek_contents.items():
    print(f"{key}: {len(value)}")

upset_data = from_contents(foldseek_contents)

upset_data.to_csv(
    "../Data/19_foldseek_result_upsetplot/foldseek_result_rice_down_upset_data.tsv",
    sep="\t"
)

display(upset_data)
# Out:
# foldseek unique hit pair: 3708
# Unique LS-HS hit pair: 157
# HS-HS hit pair: 862
# Common InterPro ID: 3276
# Ensembl pan-homology: 469
# /usr/local/lib/python3.11/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
#                                                                                                                        id
# foldseek unique hit pair Unique LS-HS hit pair HS-HS hit pair Common InterPro ID Ensembl pan-homology
# True                     False                 True           True               False                 foldseek-hit-10022
#                                                False          True               False                 foldseek-hit-10025
#                                                True           True               False                 foldseek-hit-10043
#                                                False          True               False                 foldseek-hit-10045
#                                                True           True               False                 foldseek-hit-10046
# ...                                                                                                                   ...
#                                                                                  False                  foldseek-hit-9957
#                                                                                  False                  foldseek-hit-9959
#                                                                                  False                  foldseek-hit-9964
#                                                False          True               False                  foldseek-hit-9983
#                                                True           True               False                  foldseek-hit-9992
#
# [3708 rows x 1 columns]

# %%
plt.rc('ytick', labelsize=9)
upset_plot = UpSet(
    upset_data,
    orientation='horizontal',
    show_counts="{:d}",
    subset_size='count',
    include_empty_subsets = False
)

upset_plot.style_subsets(
    present=[f"HS-HS hit pair"], 
    facecolor="tomato"
)

upset_plot.style_subsets(
    present=[f"Unique LS-HS hit pair"], 
    facecolor="navy"
)

# upset_plot.style_categories(
#     "foldseek unique hit pair",
#     shading_edgecolor="lightsteelblue",
# )

upset_plot.style_categories(
    f"average lDDT≧{median_y} & Similarity≦{third_quartile}%",
    shading_edgecolor="firebrick",
)


fig = plt.figure(figsize=(14, 8), dpi=500)
upset_plot.plot(fig=fig)

fig.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_upset_plot_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /usr/local/lib/python3.11/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %%
# Create legend independently
legend_elements = [
    Patch(facecolor="navy", label=f"Unique LS-HS hit pair: average lDDT ≧ {median_y} & Similarity ≦ {third_quartile}%"),
    Patch(facecolor="tomato", label=f"HS-HS hit pair: average lDDT ≧ {median_y} & Similarity > {third_quartile}%")
]

fig_leg = plt.figure(figsize=(1.5, 0.5), dpi=500)
ax_leg = fig_leg.add_subplot(111)
ax_leg.legend(handles=legend_elements, loc='center')
ax_leg.axis('off') 

fig_leg.savefig(
    f"../Data/21_foldseek_plot_result_image/rice_down/{VERSION}/foldseek_result_rice_down_legend_filtercondtion3_legend_{VERSION}.png",
    dpi=500,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## (20) Genes of interest

# %%
# display(condition3)

domain_info_select = domain_info.select(
    "hit label",
    "From",
    "HN5",
    "UniProt Accession",
    "foldseek hit",
    "ensembl_protein_id",
    "ensembl_gene_id",
    "hgnc_symbol_id",
    "InterPro_rice",
    "InterPro_human",
    "InterPro ID intersection",
    "InterPro ID intersection count",
    "InterPro ID intersection tag"
).unique()

condition3_domain_panhomology_info = condition3.join(
    domain_info_select,
    on=["hit label", "From", "HN5", "UniProt Accession", "foldseek hit", "ensembl_protein_id", "ensembl_gene_id", "hgnc_symbol_id"],
    how="inner",
    coalesce=True
).filter(
    (pl.col("InterPro ID intersection tag").is_not_null())
).join(
    ensembl_pan_homology,
    on=["From", "ensembl_protein_id", "ensembl_gene_id"],
    how="left",
    coalesce=True
).sort(
    by=["HN5", "From", "UniProt Accession", "foldseek hit"],
    descending=[True, False, False, False]
).with_columns(
    pl.col("InterPro_rice").list.eval(pl.element().cast(pl.Utf8)).list.join(",").alias("InterPro_rice"),
    pl.col("InterPro_human").list.eval(pl.element().cast(pl.Utf8)).list.join(",").alias("InterPro_human"),
    pl.col("InterPro ID intersection").list.eval(pl.element().cast(pl.Utf8)).list.join(",").alias("InterPro ID intersection")
)

condition3_domain_panhomology_info.write_csv(
    f"../Data/20_foldseek_result_validate_rice_down/rice_down/{VERSION}/foldseek_result_rice_down_domain_panhomology_info_filtercondtion3_{VERSION}.tsv",
    separator="\t"
)

display(condition3_domain_panhomology_info)
# Out:
# shape: (7_103, 51)
# ┌─────────────┬─────────────┬──────┬─────────────┬───┬────────────┬────────────┬────────────┬──────┐
# │ hit label   ┆ From        ┆ HN5  ┆ UniProt     ┆ … ┆ InterPro   ┆ InterPro   ┆ method_lin ┆ type │
# │ ---         ┆ ---         ┆ ---  ┆ Accession   ┆   ┆ ID interse ┆ ID interse ┆ k_type     ┆ ---  │
# │ str         ┆ str         ┆ i64  ┆ ---         ┆   ┆ ction …    ┆ ction …    ┆ ---        ┆ str  │
# │             ┆             ┆      ┆ str         ┆   ┆ ---        ┆ ---        ┆ str        ┆      │
# │             ┆             ┆      ┆             ┆   ┆ u32        ┆ str        ┆            ┆      │
# ╞═════════════╪═════════════�
seek-hit-10628', 'foldseek-hit-5170', 'foldseek-hit-1554', 'foldseek-hit-11174', 'foldseek-hit-12461', 'foldseek-hit-1539', 'foldseek-hit-8768', 'foldseek-hit-6641', 'foldseek-hit-3503', 'foldseek-hit-10139', 'foldseek-hit-3089', 'foldseek-hit-9140', 'foldseek-hit-7019', 'foldseek-hit-10716', 'foldseek-hit-1528', 'foldseek-hit-12396', 'foldseek-hit-10734', 'foldseek-hit-3605', 'foldseek-hit-3729', 'foldseek-hit-6078', 'foldseek-hit-5369', 'foldseek-hit-6898', 'foldseek-hit-2371', 'foldseek-hit-6394', 'foldseek-hit-3598', 'foldseek-hit-10985', 'foldseek-hit-1423', 'foldseek-hit-5711', 'foldseek-hit-1240', 'foldseek-hit-7050', 'foldseek-hit-1486', 'foldseek-hit-9478', 'foldseek-hit-11347', 'foldseek-hit-6629', 'foldseek-hit-4012', 'foldseek-hit-351', 'foldseek-hit-1389', 'foldseek-hit-11447', 'foldseek-hit-11418', 'foldseek-hit-1385', 'foldseek-hit-10051', 'foldseek-hit-9132', 'foldseek-hit-10742', 'foldseek-hit-3616', 'foldseek-hit-11173', 'foldseek-hit-4703', 'foldseek-hit-1578', 'foldseek-hit-3620', 'foldseek-hit-4644', 'foldseek-hit-10725', 'foldseek-hit-9472', 'foldseek-hit-3456', 'foldseek-hit-3454', 'foldseek-hit-10792', 'foldseek-hit-11430', 'foldseek-hit-1540', 'foldseek-hit-6466', 'foldseek-hit-3384', 'foldseek-hit-10831', 'foldseek-hit-1289', 'foldseek-hit-6436', 'foldseek ...
# shape: (1_698, 51)
# ┌────────────┬────────────┬──────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5  ┆ UniProt    ┆ … ┆ InterPro   ┆ InterPro  ┆ method_li ┆ type      │
# │ ---        ┆ ---        ┆ ---  ┆ Accession  ┆   ┆ ID interse ┆ ID inters ┆ nk_type   ┆ ---       │
# │ str        ┆ str        ┆ i64  ┆ ---        ┆   ┆ ction …    ┆ ection …  ┆ ---       ┆ str       │
# │            ┆            ┆      ┆ str        ┆   ┆ ---        ┆ ---       ┆ str       ┆           │
# │            ┆            ┆      ┆            ┆   ┆ u32        ┆ str       ┆           ┆           │
# ╞════════════╪════════════╪══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g01929 ┆ -40  ┆ O24220     ┆ … ┆ 4          ┆ have      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-244     ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆ S         ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os01g01929 ┆ -40  ┆ O24220     ┆ … ┆ 4          ┆ have      ┆ null      ┆ null      │
# │ it-244     ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os01g01929 ┆ -40  ┆ Q9FU17     ┆ … ┆ 5          ┆ have      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-240     ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆ S         ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ …          ┆ …          ┆ …    ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ foldseek-h ┆ Os07g02584 ┆ -171 ┆ A0A0P0X4D2 ┆ … ┆ 1          ┆ have      ┆ null      ┆ null      │
# │ it-8004    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os07g02584 ┆ -171 ┆ A0A0P0X4D2 ┆ … ┆ 1          ┆ have      ┆ null      ┆ null      │
# │ it-8004    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os07g02584 ┆ -171 ┆ Q0D7E4     ┆ … ┆ 1          ┆ have      ┆ null      ┆ null      │
# │ it-7916    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# └────────────┴────────────┴──────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
# Condition4: LDDT >= median_y & Identity <= third_quartile
condition3_filter_4_tsv = condition3_domain_panhomology_info.filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") <= third_quartile) &
    (~pl.col("From").is_in(condition3_filter_1_tsv.select("From").to_series())) & # Exclude Genes in Filter Condition1 (LDDT >= median_y & Identity > third_quartile)
    (~pl.col("foldseek hit").is_in(condition3_filter_1_tsv.select("foldseek hit").to_series())) # 
)

print(condition3_filter_4_tsv.select("From").n_unique())
print(condition3_filter_4_tsv.select("From").unique().to_series().to_list())
print(condition3_filter_4_tsv.select("hit label").n_unique())
print(condition3_filter_4_tsv.select("hit label").unique().to_series().to_list())
display(condition3_filter
12190', 'foldseek-hit-6003', 'foldseek-hit-6018', 'foldseek-hit-5484', 'foldseek-hit-8337', 'foldseek-hit-4519', 'foldseek-hit-8355', 'foldseek-hit-5992', 'foldseek-hit-8237', 'foldseek-hit-8982', 'foldseek-hit-7697', 'foldseek-hit-8217', 'foldseek-hit-6029', 'foldseek-hit-8222', 'foldseek-hit-13314', 'foldseek-hit-5470', 'foldseek-hit-4510', 'foldseek-hit-4503', 'foldseek-hit-5988', 'foldseek-hit-6015', 'foldseek-hit-4462', 'foldseek-hit-6285', 'foldseek-hit-2891', 'foldseek-hit-4181', 'foldseek-hit-3276', 'foldseek-hit-5473', 'foldseek-hit-4045', 'foldseek-hit-676', 'foldseek-hit-8344', 'foldseek-hit-4024', 'foldseek-hit-2822', 'foldseek-hit-5475', 'foldseek-hit-710', 'foldseek-hit-8354', 'foldseek-hit-5485', 'foldseek-hit-2830', 'foldseek-hit-13330', 'foldseek-hit-13467', 'foldseek-hit-3360', 'foldseek-hit-3271', 'foldseek-hit-5482', 'foldseek-hit-4188', 'foldseek-hit-7538', 'foldseek-hit-2853', 'foldseek-hit-674', 'foldseek-hit-4057', 'foldseek-hit-621', 'foldseek-hit-9345', 'foldseek-hit-5876', 'foldseek-hit-6361', 'foldseek-hit-4018', 'foldseek-hit-4517', 'foldseek-hit-5870', 'foldseek-hit-3256', 'foldseek-hit-6037', 'foldseek-hit-8303', 'foldseek-hit-4026']
# shape: (298, 51)
# ┌────────────┬────────────┬──────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5  ┆ UniProt    ┆ … ┆ InterPro   ┆ InterPro  ┆ method_li ┆ type      │
# │ ---        ┆ ---        ┆ ---  ┆ Accession  ┆   ┆ ID interse ┆ ID inters ┆ nk_type   ┆ ---       │
# │ str        ┆ str        ┆ i64  ┆ ---        ┆   ┆ ction …    ┆ ection …  ┆ ---       ┆ str       │
# │            ┆            ┆      ┆ str        ┆   ┆ ---        ┆ ---       ┆ str       ┆           │
# │            ┆            ┆      ┆            ┆   ┆ u32        ┆ str       ┆           ┆           │
# ╞════════════╪════════════╪══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ 2          ┆ have      ┆ null      ┆ null      │
# │ it-10457   ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ 2          ┆ have      ┆ null      ┆ null      │
# │ it-10459   ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ 2          ┆ have      ┆ null      ┆ null      │
# │ it-10461   ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ …          ┆ …          ┆ …    ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ 6          ┆ have      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-5877    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆ S         ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ 6          ┆ have      ┆ null      ┆ null      │
# │ it-5877    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ 6          ┆ have      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-5878    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆ S         ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# └────────────┴────────────┴──────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## Confirm whether genes are included in the enrichment analysis
#
# - see Supplementary Table S6 in figshare

# %%
enrichment_rice_down = pl.read_csv(
    "../Data/09_goatools/result/rice_go_enrichment_down_modified.tsv",
    separator="\t"
)

enrichment_expanded = enrichment_rice_down.with_columns([
    # split study_items into individual genes
    pl.col("study_items").str.split(", ").alias("gene_list")
]).explode("gene_list").select([
    pl.col("gene_list").alias("From"),
    pl.col("# GO").alias("go_term"),
    pl.col("name").alias("term_name")
])

gene_enrichment_summary = enrichment_expanded.group_by("From").agg([
    pl.col("go_term").str.concat(delimiter=", ").alias("enriched_go_terms"),
    pl.col("term_name").str.concat(delimiter=", ").alias("enriched_term_names")
])

display(enrichment_rice_down)
display(gene_enrichment_summary)
# Out:
# shape: (17, 11)
# ┌────────────┬─────┬────────────┬──────────────┬───┬───────┬─────────────┬──────────┬──────────────┐
# │ # GO       ┆ NS  ┆ enrichment ┆ name         ┆ … ┆ depth ┆ study_count ┆ p_fdr_bh ┆ study_items  │
# │ ---        ┆ --- ┆ ---        ┆ ---          ┆   ┆ ---   ┆ ---         ┆ ---      ┆ ---          │
# │ str        ┆ str ┆ str        ┆ str          ┆   ┆ i64   ┆ i64         ┆ f64      ┆ str          │
# ╞════════════╪═════╪════════════╪══════════════╪═══╪═══════╪═════════════╪══════════╪══════════════╡
# │ GO:0006879 ┆ BP  ┆ e          ┆ intracellula ┆ … ┆ 6     ┆ 7           ┆ 0.000231 ┆ Os01g0689451 │
# │            ┆     ┆            ┆ r iron ion   ┆   ┆       ┆             ┆          ┆ ,            │
# │            ┆     ┆            ┆ ho…          ┆   ┆       ┆             ┆          ┆ Os02g064990… │
# │ GO:0006826 ┆ BP  ┆ e          ┆ iron ion     ┆ … ┆ 8     ┆ 6           ┆ 0.000678 ┆ Os02g0649900 │
# │            ┆     ┆            ┆ transport    ┆   ┆       ┆             ┆          ┆ ,            │
# │            ┆     ┆            ┆              ┆   ┆       ┆             ┆          ┆ Os02g065030… │
# │ GO:0060586 ┆ BP  ┆ e          ┆ multicellula ┆ … ┆ 5     ┆ 5           ┆ 0.003002 ┆ Os01g0689451 │
# │            ┆     ┆            ┆ r            ┆   ┆       ┆             ┆          ┆ ,            │
# │            ┆     ┆            ┆ organismal-… ┆   ┆       ┆             ┆          ┆ Os03g066730… │
# │ …          ┆ …   ┆ …          ┆ …            ┆ … ┆ …     ┆ …           ┆ …        ┆ …            │
# │ GO:0005506 ┆ MF  ┆ e          ┆ iron ion     ┆ … ┆ 7     ┆ 16          ┆ 0.002767 ┆ Os01g0627400 │
# │            ┆     ┆            ┆ binding      ┆   ┆       ┆             ┆          ┆ ,            │
# │            ┆     ┆            ┆              ┆   ┆       ┆             ┆          ┆ Os01g085480… │
# │ GO:0016491 ┆ MF  ┆ e          ┆ oxidoreducta ┆ … ┆ 2     ┆ 34          ┆ 0.006561 ┆ Os01g0591300 │
# │            ┆     ┆            ┆ se activity  ┆   ┆       ┆             ┆          ┆ ,            │
# │            ┆     ┆            ┆              ┆   ┆       ┆             ┆          ┆ Os01g062740… │
# │ GO:0010333 ┆ MF  ┆ e          ┆ terpene      ┆ … ┆ 5     ┆ 5           ┆ 0.008206 ┆ Os02g0121700 │
# │            ┆     ┆            ┆ synthase     ┆   ┆       ┆             ┆          ┆ ,            │
# │            ┆     ┆            ┆ activity     ┆   ┆       ┆             ┆          ┆ Os02g057110… │
# └────────────┴─────┴────────────┴──────────────┴───┴───────┴─────────────┴──────────┴──────────────┘
# shape: (69, 3)
# ┌──────────────┬────────────────────────────┬────────────────────────────┐
# │ From         ┆ enriched_go_terms          ┆ enriched_term_names        │
# │ ---          ┆ ---                        ┆ ---                        │
# │ str          ┆ str                        ┆ str                        │
# ╞══════════════╪════════════════════════════╪════════════════════════════╡
# │ Os03g0261100 ┆ GO:0005576                 ┆ extracellular region       │
# │ Os07g0258400 ┆ GO:0006879, GO:0006826, G… ┆ intracellular iron ion ho… │
# │ Os02g0561100 ┆ GO:0016491                 ┆ oxidoreductase activity    │
# │ …            ┆ …                          ┆ …                          │
# │ Os01g0952000 ┆ GO:0005576, GO:0048046     ┆ extracellular region, apo… │
# │ Os03g0237100 ┆ GO:0016491                 ┆ oxidoreductase activity    │
# │ Os05g0499300 ┆ GO:0005576, GO:0020037, G… ┆ extracellular region, hem… │
# └──────────────┴────────────────────────────┴────────────────────────────┘

# %%
# combine enrichment result with condition3_filter_4_tsv
condition3_filter_4_enriched = condition3_filter_4_tsv.join(
    gene_enrichment_summary,
    left_on="From",
    right_on="From",
    how="left"
).with_columns([
    # check whether there is enrichment result
    pl.col("enriched_go_terms").is_not_null().alias("enrichment_result"),
    # if null, replace with empty string
    pl.col("enriched_go_terms").fill_null("").alias("enriched_go_terms"),
    pl.col("enriched_term_names").fill_null("").alias("enriched_term_names")
]).drop(
    "enriched_term_names"
)

display(condition3_filter_4_enriched)
# Out:
# shape: (298, 53)
# ┌────────────┬────────────┬──────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5  ┆ UniProt    ┆ … ┆ method_lin ┆ type      ┆ enriched_ ┆ enrichmen │
# │ ---        ┆ ---        ┆ ---  ┆ Accession  ┆   ┆ k_type     ┆ ---       ┆ go_terms  ┆ t_result  │
# │ str        ┆ str        ┆ i64  ┆ ---        ┆   ┆ ---        ┆ str       ┆ ---       ┆ ---       │
# │            ┆            ┆      ┆ str        ┆   ┆ str        ┆           ┆ str       ┆ bool      │
# ╞════════════╪════════════╪══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ null       ┆ null      ┆           ┆ false     │
# │ it-10457   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ null       ┆ null      ┆           ┆ false     │
# │ it-10459   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ null       ┆ null      ┆           ┆ false     │
# │ it-10461   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …    ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ ENSEMBL_OR ┆ ortholog_ ┆ GO:001649 ┆ true      │
# │ it-5877    ┆ 00         ┆      ┆            ┆   ┆ THOLOGUES  ┆ many2many ┆ 1         ┆           │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ null       ┆ null      ┆ GO:001649 ┆ true      │
# │ it-5877    ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆ 1         ┆           │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ ENSEMBL_OR ┆ ortholog_ ┆ GO:001649 ┆ true      │
# │ it-5878    ┆ 00         ┆      ┆            ┆   ┆ THOLOGUES  ┆ many2many ┆ 1         ┆           │
# └────────────┴────────────┴──────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ## Concordant Hit Pair with the Foldseek-TM method

# %%
foldseek_tm_result = pl.read_csv(
    "../Data/20_foldseek_result_validate_rice_down/rice_down_tmalign/250811/foldseek_result_rice_down_tmalign_domain_panhomology_info_filtercondtion3_filter4_250811.tsv",
    separator="\t"
).filter(
    (pl.col("lddt") >= median_y) & (pl.col("Similarity_percent_needle") <= third_quartile) # set as same unique LS-HS hit pair condition
)

display(foldseek_tm_result)
# Out:
# shape: (472, 51)
# ┌────────────┬────────────┬──────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5  ┆ UniProt    ┆ … ┆ InterPro   ┆ InterPro  ┆ method_li ┆ type      │
# │ ---        ┆ ---        ┆ ---  ┆ Accession  ┆   ┆ ID interse ┆ ID inters ┆ nk_type   ┆ ---       │
# │ str        ┆ str        ┆ i64  ┆ ---        ┆   ┆ ction …    ┆ ection …  ┆ ---       ┆ str       │
# │            ┆            ┆      ┆ str        ┆   ┆ ---        ┆ ---       ┆ str       ┆           │
# │            ┆            ┆      ┆            ┆   ┆ i64        ┆ str       ┆           ┆           │
# ╞════════════╪════════════╪══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os01g08138 ┆ -40  ┆ A0A0N7KDY3 ┆ … ┆ 2          ┆ have      ┆ ENSEMBL_O ┆ ortholog_ │
# │ it-2607    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆ RTHOLOGUE ┆ many2many │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆ S         ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os01g08138 ┆ -40  ┆ A0A0N7KDY3 ┆ … ┆ 2          ┆ have      ┆ null      ┆ null      │
# │ it-2607    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ foldseek-h ┆ Os01g08138 ┆ -40  ┆ A0A0N7KDY3 ┆ … ┆ 2          ┆ have      ┆ null      ┆ null      │
# │ it-2607    ┆ 00         ┆      ┆            ┆   ┆            ┆ common    ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# │ …          ┆ …          ┆ …    ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ foldseek-h ┆ Os01g09528 ┆ -173 ┆ A0A0P0VCZ9 ┆ … ┆ null       ┆ missing   ┆ null      ┆ null      │
# │ it-3080    ┆ 00         ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ entry in… ┆           ┆           │
# │ foldseek-h ┆ Os01g09528 ┆ -173 ┆ A0A0P0VCZ9 ┆ … ┆ null       ┆ missing   ┆ null      ┆ null      │
# │ it-3082    ┆ 00         ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ entry in… ┆           ┆           │
# │ foldseek-h ┆ Os01g09528 ┆ -173 ┆ Q0JFZ0     ┆ … ┆ 0          ┆ no common ┆ null      ┆ null      │
# │ it-3040    ┆ 00         ┆      ┆            ┆   ┆            ┆ InterPro  ┆           ┆           │
# │            ┆            ┆      ┆            ┆   ┆            ┆ ID        ┆           ┆           │
# └────────────┴────────────┴──────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
def check_concordance_with_tm_method(condition_df, tm_result_df):
    """
    Check concordance between condition3_filter_4_enriched and foldseek_tm_result
    based on multiple column combinations
    
    Args:
        condition_df: condition3_filter_4_enriched dataframe
        tm_result_df: foldseek_tm_result dataframe
    
    Returns:
        Enhanced dataframe with foldseek_tm_method boolean column
    """
    
    # Define the key columns for comparison
    key_columns = [
        "From", 
        "UniProt Accession", 
        "foldseek hit", 
        "ensembl_protein_id", 
        "ensembl_gene_id", 
        "hgnc_symbol_id"
    ]
    
    # Create a composite key for condition3_filter_4_enriched
    condition_with_key = condition_df.with_columns(
        pl.concat_str([
            pl.col("From"),
            pl.col("UniProt Accession"), 
            pl.col("foldseek hit"),
            pl.col("ensembl_protein_id"),
            pl.col("ensembl_gene_id"),
            pl.col("hgnc_symbol_id")
        ], separator="|||").alias("composite_key")
    )
    
    # Create a composite key for foldseek_tm_result
    tm_result_keys = tm_result_df.select([
        pl.concat_str([
            pl.col("From"),
            pl.col("UniProt Accession"), 
            pl.col("foldseek hit"),
            pl.col("ensembl_protein_id"),
            pl.col("ensembl_gene_id"),
            pl.col("hgnc_symbol_id")
        ], separator="|||").alias("tm_composite_key")
    ]).unique()
    
    # Check if each composite key exists in the TM-align results
    result_df = condition_with_key.with_columns(
        pl.col("composite_key").is_in(
            tm_result_keys.select("tm_composite_key").to_series()
        ).alias("foldseek_tm_method")
    ).drop("composite_key")
    
    return result_df

# %%
condition3_filter_4_with_tm = check_concordance_with_tm_method(
    condition3_filter_4_enriched, 
    foldseek_tm_result
)

display(condition3_filter_4_with_tm)
# Out:
# shape: (298, 54)
# ┌────────────┬────────────┬──────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ hit label  ┆ From       ┆ HN5  ┆ UniProt    ┆ … ┆ type       ┆ enriched_ ┆ enrichmen ┆ foldseek_ │
# │ ---        ┆ ---        ┆ ---  ┆ Accession  ┆   ┆ ---        ┆ go_terms  ┆ t_result  ┆ tm_method │
# │ str        ┆ str        ┆ i64  ┆ ---        ┆   ┆ str        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆      ┆ str        ┆   ┆            ┆ str       ┆ bool      ┆ bool      │
# ╞════════════╪════════════╪══════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ null       ┆           ┆ false     ┆ false     │
# │ it-10457   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ null       ┆           ┆ false     ┆ false     │
# │ it-10459   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ foldseek-h ┆ Os09g05542 ┆ -40  ┆ A0A0P0XRD9 ┆ … ┆ null       ┆           ┆ false     ┆ false     │
# │ it-10461   ┆ 00         ┆      ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …    ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ ortholog_m ┆ GO:001649 ┆ true      ┆ false     │
# │ it-5877    ┆ 00         ┆      ┆            ┆   ┆ any2many   ┆ 1         ┆           ┆           │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ null       ┆ GO:001649 ┆ true      ┆ false     │
# │ it-5877    ┆ 00         ┆      ┆            ┆   ┆            ┆ 1         ┆           ┆           │
# │ foldseek-h ┆ Os04g05786 ┆ -147 ┆ A0A0P0WE87 ┆ … ┆ ortholog_m ┆ GO:001649 ┆ true      ┆ false     │
# │ it-5878    ┆ 00         ┆      ┆            ┆   ┆ any2many   ┆ 1         ┆           ┆           │
# └────────────┴────────────┴──────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
condition3_filter_4_with_tm.write_csv(
    f"../Data/20_foldseek_result_validate_rice_down/rice_down/{VERSION}/foldseek_result_rice_down_domain_panhomology_info_filtercondtion3_filter4_{VERSION}.tsv",
    separator="\t"
)
